# %%
# define the environment path 
import os
local_cobrakbase_path = os.path.join('C:', 'Users', 'Andrew Freiburger','Documents','Argonne','cobrakbase')
os.environ["HOME"] = local_cobrakbase_path

# import the KBase
import cobrakbase
with open("/Users/afreiburger/Documents/kbase_token.txt") as token_file:
# with open("C:/Users/Andrew Freiburger/Documents/Argonne/kbase_token.txt") as token_file:
    kbase_api = cobrakbase.KBaseAPI(token_file.readline())
# Out:
# modelseedpy 0.2.2
# cobrakbase 0.3.1

# %%
models = [kbase_api.get_from_ws(mdl, 175377) for mdl in ["Rhizobium_sp._CF142_2510917030.fna.RAST.mdl", "Pantoea_sp._YR343_2511231025.fna.RAST.mdl",
                                                         "Pseudomonas_sp._GM17_2511231006.fna.RAST.mdl", "Streptomyces_mirabilis_YR139_2582581314.fna.RAST.mdl"]
                                                         ] if "models" not in locals() else models
r2a = kbase_api.get_from_ws("R2A_edition_003", 175377)

# %%
# %run scores.py

fluxes, mets = CommScores.report_generation(models, environments=r2a, kbase_obj=kbase_api)
# Out:
# modelseedpy_freiburgermsu 0.2.2
# The minimal flux media for Streptomyces_mirabilis_YR139_2582581314.fna.RAST.mdl consists of 32 compounds and a 2684.5111061393122 total influx, with a growth value of 70.62333478562519
# The minimal flux media for Pseudomonas_sp._GM17_2511231006.fna.RAST.mdl consists of 45 compounds and a 4727.374865587154 total influx, with a growth value of 82.61277856295993
# The minimal flux media for Pantoea_sp._YR343_2511231025.fna.RAST.mdl consists of 40 compounds and a 3319.7356730867027 total influx, with a growth value of 93.06480403074262
# The minimal flux media for Rhizobium_sp._CF142_2510917030.fna.RAST.mdl consists of 31 compounds and a 4179.260829569995 total influx, with a growth value of 58.34675810455973
# The minimal media of all members:
# {'Streptomyces_mirabilis_YR139_2582581314.fna.RAST.mdl': {'media': {'EX_cpd00276_e0': 69.53712170979307, 'EX_cpd00058_e0': 0.11300020737415192, 'EX_cpd00080_e0': 46.679879433726434, 'EX_cpd00254_e0': 0.11300020737415192, 'EX_cpd00209_e0': 671.1171739228888, 'EX_cpd00132_e0': 13.689321428511029, 'EX_cpd00324_e0': 14.466795303518335, 'EX_cpd00007_e0': 126.07293299655737, 'EX_cpd00205_e0': 0.11300020737415192, 'EX_cpd00129_e0': 550.8220951726172, 'EX_cpd00048_e0': 0.11300020737415195, 'EX_cpd01017_e0': 8.675387492189425e-13, 'EX_cpd15604_e0': 25.58780036415707, 'EX_cpd00322_e0': 16.48178259066796, 'EX_cpd00051_e0': 16.815707475377188, 'EX_cpd15606_e0': 8.338734369517141, 'EX_cpd00264_e0': 0.11300020737415192, 'EX_cpd00149_e0': 0.11300020737415192, 'EX_cpd00028_e0': 0.11300020737415192, 'EX_cpd00030_e0': 0.11300020737415195, 'EX_cpd00063_e0': 0.11300020737415195, 'EX_cpd10516_e0': 0.11300020737415183, 'EX_cpd11590_e0': 1.3355364581549172e-25, 'EX_cpd00220_e0': 0.22600041474829466, 'EX_cpd00099_e0': 0.11300020737415192, 'EX_cpd11584_e0': 5.40288074118617, 'EX_cpd00118_e0': 0.11300020737415192, 'EX_cpd15605_e0': 10.532582119053938, 'EX_cpd00076_e0': 975.1682595691234, 'EX_cpd00034_e0': 0.11300020737415192, 'EX_cpd00307_e0': 131.87703541725523, 'EX_cpd10515_e0': 0.22600041474830387}}, 'Pseudomonas_sp._GM17_2511231006.fna.RAST.mdl': {'media': {'EX_cpd00069_e0': 9.754368270138384, 'EX_cpd00142_e0': 500.78217331320917, 'EX_cpd00393_e0': 0.3965514148137968, 'EX_cpd00058_e0': 0.1321838049379322, 'EX_cpd00066_e0': 12.320656861345226, 'EX_cpd00080_e0': 1000.0, 'EX_cpd00065_e0': 3.7636588683071874, 'EX_cpd00209_e0': 408.84098536799695, 'EX_cpd00254_e0': 0.1321838049379322, 'EX_cpd00214_e0': 13.25079773633858, 'EX_cpd00309_e0': 9.595646118888544, 'EX_cpd00007_e0': 140.29679987298405, 'EX_cpd00162_e0': 49.73420873442687, 'EX_cpd00205_e0': 0.1321838049379322, 'EX_cpd15560_e0': 3.81542060694289e-12, 'EX_cpd00064_e0': 0.1321838049379322, 'EX_cpd00048_e0': 3.268697947232053e-17, 'EX_cpd00281_e0': 0.26436760987586444, 'EX_cpd00051_e0': 19.670443519265863, 'EX_cpd00355_e0': 0.26436760987585584, 'EX_cpd00033_e0': 76.11296925305597, 'EX_cpd00264_e0': 0.1321838049379322, 'EX_cpd00054_e0': 24.931692491498264, 'EX_cpd00149_e0': 0.1321838049379322, 'EX_cpd00028_e0': 0.1321838049379322, 'EX_cpd00268_e0': 6.600298111077488, 'EX_cpd00030_e0': 0.1321838049379322, 'EX_cpd00063_e0': 0.1321838049379322, 'EX_cpd00107_e0': 29.93173986776376, 'EX_cpd10516_e0': 0.13218380493793225, 'EX_cpd00136_e0': 0.1321838049379322, 'EX_cpd00179_e0': 34.48668246765109, 'EX_cpd01080_e0': 16.39265771368963, 'EX_cpd00039_e0': 22.759484288536857, 'EX_cpd00099_e0': 0.1321838049379322, 'EX_cpd00130_e0': 548.9942317151706, 'EX_cpd00082_e0': 14.343575499478396, 'EX_cpd00311_e0': 10.963840193814349, 'EX_cpd01914_e0': 10.322467721958335, 'EX_cpd00023_e0': 753.7311109704366, 'EX_cpd00071_e0': 986.3756126718787, 'EX_cpd00034_e0': 0.1321838049379322, 'EX_cpd00119_e0': 6.320106401496974, 'EX_cpd00307_e0': 14.19061384810801, 'EX_cpd10515_e0': 0.2643676098758644}}, 'Pantoea_sp._YR343_2511231025.fna.RAST.mdl': {'media': {'EX_cpd00069_e0': 10.839566555906094, 'EX_cpd03847_e0': 14.927265684975595, 'EX_cpd00235_e0': 999.9999999999999, 'EX_cpd00058_e0': 0.1489074706912487, 'EX_cpd00066_e0': 13.879444999628834, 'EX_cpd00080_e0': 61.215194106758034, 'EX_cpd00065_e0': 4.23983046098172, 'EX_cpd00254_e0': 0.14890747069124868, 'EX_cpd00132_e0': 18.03927865945996, 'EX_cpd00654_e0': 15.98598570128028, 'EX_cpd00305_e0': 0.1489074706912029, 'EX_cpd00128_e0': 10.809670624043589, 'EX_cpd00309_e0': 12.79768865253343, 'EX_cpd00324_e0': 11.628448435802131, 'EX_cpd00007_e0': 354.66511230699314, 'EX_cpd00205_e0': 0.1489074706912487, 'EX_cpd00048_e0': 6.537395894464105e-17, 'EX_cpd15604_e0': 33.71865168497725, 'EX_cpd00051_e0': 22.159113918715775, 'EX_cpd00355_e0': 0.29781494138262193, 'EX_cpd00264_e0': 0.1489074706912487, 'EX_cpd00644_e0': 0.2978149413824625, 'EX_cpd00149_e0': 0.14890747069124868, 'EX_cpd00028_e0': 0 ...
#
# Examining the 6 model pairs
# The ID rxn02201_c0 is changed with 1 to create the final ID rxn02201_c1
# The ID rxn07431_c0 is changed with 1 to create the final ID rxn07431_c1
# The ID rxn00836_c0 is changed with 1 to create the final ID rxn00836_c1
# The ID rxn00364_c0 is changed with 1 to create the final ID rxn00364_c1
# The ID rxn05561_c0 is changed with 1 to create the final ID rxn05561_c1
# The ID rxn03408_c0 is changed with 1 to create the final ID rxn03408_c1
# The ID rxn02177_c0 is changed with 1 to create the final ID rxn02177_c1
# The ID rxn05250_c0 is changed with 1 to create the final ID rxn05250_c1
# The ID rxn00646_c0 is changed with 1 to create the final ID rxn00646_c1
# The ID rxn05440_c0 is changed with 1 to create the final ID rxn05440_c1
# The ID rxn01673_c0 is changed with 1 to create the final ID rxn01673_c1
# The ID rxn05625_c0 is changed with 1 to create the final ID rxn05625_c1
# The ID rxn02360_c0 is changed with 1 to create the final ID rxn02360_c1
# The ID rxn02342_c0 is changed with 1 to create the final ID rxn02342_c1
# The ID rxn01452_c0 is changed with 1 to create the final ID rxn01452_c1
# The ID rxn00022_c0 is changed with 1 to create the final ID rxn00022_c1
# The ID rxn02000_c0 is changed with 1 to create the final ID rxn02000_c1
# The ID rxn03239_c0 is changed with 1 to create the final ID rxn03239_c1
# The ID rxn03534_c0 is changed with 1 to create the final ID rxn03534_c1
# The ID rxn02632_c0 is changed with 1 to create the final ID rxn02632_c1
# The ID rxn00322_c0 is changed with 1 to create the final ID rxn00322_c1
# The ID rxn05457_c0 is changed with 1 to create the final ID rxn05457_c1
# The ID rxn00107_c0 is changed with 1 to create the final ID rxn00107_c1
# The ID rxn08934_c0 is changed with 1 to create the final ID rxn08934_c1
# The ID rxn12008_c0 is changed with 1 to create the final ID rxn12008_c1
# The ID rxn00199_c0 is changed with 1 to create the final ID rxn00199_c1
# The ID rxn01358_c0 is changed with 1 to create the final ID rxn01358_c1
# The ID rxn03433_c0 is changed with 1 to create the final ID rxn03433_c1
# The ID rxn10231_c0 is changed with 1 to create the final ID rxn10231_c1
# The ID rxn01867_c0 is changed with 1 to create the final ID rxn01867_c1
# The ID rxn12637_c0 is changed with 1 to create the final ID rxn12637_c1
# The ID rxn09240_c0 is changed with 1 to create the final ID rxn09240_c1
# The ID rxn00172_c0 is changed with 1 to create the final ID rxn00172_c1
# The ID rxn01219_c0 is changed with 1 to create the final ID rxn01219_c1
# The ID rxn00800_c0 is changed with 1 to create the final ID rxn00800_c1
# The ID rxn08333_c0 is changed with 1 to create the final ID rxn08333_c1
# The ID rxn01705_c0 is changed with 1 to create the final ID rxn01705_c1
# The ID rxn09177_c0 is changed with 1 to create the final ID rxn09177_c1
# The ID rxn00211_c0 is changed with 1 to create the final ID rxn00211_c1
# The ID rxn00179_c0 is changed with 1 to create the final ID rxn00179_c1
# The ID rxn02945_c0 is changed with 1 to create the final ID rxn02945_c1
# The ID rxn00587_c0 is changed with 1 to create the final ID rxn00587_c1
# The ID rxn01210_c0 is changed with 1 to create the final ID rxn01210_c1
# The ID rxn00192_c0 is changed with 1 to create the final ID rxn00192_c1
# The ID rxn01218_c0 is changed with 1 to create the final ID rxn01218_c1
# The ID rxn03360_c0 is changed with 1 to create the final ID rxn03360_c1
# The ID rxn00509_c0 is changed with 1 to create the final ID rxn00509_c1
# The ID rxn00962_c0 is changed with 1 to create the final ID rxn00962_c1
# The ID rxn05654_c0 is changed with 1 to create the final ID rxn05654_c1
# The ID rxn01199_c0 is changed with 1 to create the final ID rxn01199_c1
# The ID rxn00545_c0 is changed with 1 to create the final ID rxn00545_c1
# The ID rxn08807_c0 is changed with 1 to create the final ID rxn08807_c1
# The ID rxn05614_c0 is changed with 1 to create the final ID rxn05614_c1
# The ID rxn01663_c0 is changed with 1 to create the final ID rxn01663_c1
# The ID rxn02316_c0 is changed with 1 to create the final ID rxn02316_c1
# The ID rxn10344_c0 is changed with 1 to create the final ID rxn10344_c1
# The ID rxn02320_c0 is changed with 1 to create the final ID rxn02320_c1
# The ID rxn03384_c0 is changed with 1 to create the final ID rxn03384_c1
# The ID rxn05167_c0 is changed with 1 to create the final ID rxn05167_c1
# The ID rxn02504_c0 is changed with 1 to create the final ID rxn02504_c1
# The ID rxn04082_c0 is changed with 1 to create the final ID rxn04082_c1
# The ID rxn04996_c0 is changed with 1 to create the final ID rxn04996_c1
# The ID rxn00262_c0 is changed with 1 to create the final ID rxn00262_c1
# The ID rxn03039_c0 is changed with 1 to create the final ID rxn03039_c1
# The ID rxn10262_c0 is changed with 1 to create the final ID rxn10262_c1
# The ID rxn10126_c0 is changed with 1 to create the final ID rxn10126_c1
# The ID rxn04048_c0 is changed with 1 to create the final ID rxn04048_c1
# The ID rxn08084_c0 is changed with 1 to create the final ID rxn08084_c1
# The ID rxn10225_c0 is changed with 1 to create the final ID rxn10225_c1
# The ID rxn01486_c0 is changed with 1 to create the final ID rxn01486_c1
# The ID rxn00898_c0 is changed with 1 to create the final ID rxn00898_c1
# The ID rxn05444_c0 is changed with 1 to create the final ID rxn05444_c1
# The ID rxn05040_c0 is changed with 1 to create the final ID rxn05040_c1
# The ID rxn00890_c0 is changed with 1 to create the final ID rxn00890_c1
# The ID rxn01636_c0 is changed with 1 to create the final ID rxn01636_c1
# The ID rxn01598_c0 is changed with 1 to create the final ID rxn01598_c1
# The ID rxn02090_c0 is changed with 1 to create the final ID rxn02090_c1
# The ID rxn08556_c0 is changed with 1 to create the final ID rxn08556_c1
# The ID rxn01843_c0 is changed with 1 to create the final ID rxn01843_c1
# The ID rxn00816_c0 is changed with 1 to create the final ID rxn00816_c1
# The ID rxn02988_c0 is changed with 1 to create the final ID rxn02988_c1
# The ID rxn04792_c0 is changed with 1 to create the final ID rxn04792_c1
# The ID rxn01021_c0 is changed with 1 to create the final ID rxn01021_c1
# The ID rxn00165_c0 is changed with 1 to create the final ID rxn00165_c1
# The ID rxn10228_c0 is changed with 1 to create the final ID rxn10228_c1
# The ID rxn05542_c0 is changed with 1 to create the final ID rxn05542_c1
# The ID rxn00539_c0 is changed with 1 to create the final ID rxn00539_c1
# The ID rxn01121_c0 is changed with 1 to create the final ID rxn01121_c1
# The ID rxn00001_c0 is changed with 1 to create the final ID rxn00001_c1
# The ID rxn05545_c0 is changed with 1 to create the final ID rxn05545_c1
# The ID rxn08895_c0 is changed with 1 to create the final ID rxn08895_c1
# The ID rxn11268_c0 is changed with 1 to create the final ID rxn11268_c1
# The ID rxn00710_c0 is changed with 1 to create the final ID rxn00710_c1
# The ID rxn01114_c0 is changed with 1 to create the final ID rxn01114_c1
# The ID rxn02305_c0 is changed with 1 to create the final ID rxn02305_c1
# The ID rxn02885_c0 is changed with 1 to create the final ID rxn02885_c1
# The ID rxn08817_c0 is changed with 1 to create the final ID rxn08817_c1
# The ID rxn00910_c0 is changed with 1 to create the final ID rxn00910_c1
# The ID rxn00953_c0 is changed with 1 to create the final ID rxn00953_c1
# The ID rxn01129_c0 is changed with 1 to create the final ID rxn01129_c1
# The ID rxn05541_c0 is changed with 1 to create the final ID rxn05541_c1
# The ID rxn00717_c0 is changed with 1 to create the final ID rxn00717_c1
# The ID rxn05647_c0 is changed with 1 to create the final ID rxn05647_c1
# The ID rxn01297_c0 is changed with 1 to create the final ID rxn01297_c1
# The ID rxn01962_c0 is changed with 1 to create the final ID rxn01962_c1
# The ID rxn01682_c0 is changed with 1 to create the final ID rxn01682_c1
# The ID rxn08796_c0 is changed with 1 to create the final ID rxn08796_c1
# The ID rxn08941_c0 is changed with 1 to create the final ID rxn08941_c1
# The ID rxn06493_c0 is changed with 1 to create the final ID rxn06493_c1
# The ID rxn12846_c0 is changed with 1 to create the final ID rxn12846_c1
# The ID rxn00337_c0 is changed with 1 to create the final ID rxn00337_c1
# The ID rxn08308_c0 is changed with 1 to create the final ID rxn08308_c1
# The ID rxn01930_c0 is changed with 1 to create the final ID rxn01930_c1
# The ID rxn00208_c0 is changed with 1 to create the final ID rxn00208_c1
# The ID rxn08823_c0 is changed with 1 to create the final ID rxn08823_c1
# The ID rxn05031_c0 is changed with 1 to create the final ID rxn05031_c1
# The ID rxn05434_c0 is changed with 1 to create the final ID rxn05434_c1
# The ID rxn05346_c0 is changed with 1 to create the final ID rxn05346_c1
# The ID rxn00867_c0 is changed with 1 to create the final ID rxn00867_c1
# The ID rxn00452_c0 is changed with 1 to create the final ID rxn00452_c1
# The ID rxn03248_c0 is changed with 1 to create the final ID rxn03248_c1
# The ID rxn08127_c0 is changed with 1 to create the final ID rxn08127_c1
# The ID rxn05516_c0 is changed with 1 to create the final ID rxn05516_c1
# The ID rxn00416_c0 is changed with 1 to create the final ID rxn00416_c1
# The ID rxn02270_c0 is changed with 1 to create the final ID rxn02270_c1
# The ID rxn09206_c0 is changed with 1 to create the final ID rxn09206_c1
# The ID rxn01729_c0 is changed with 1 to create the final ID rxn01729_c1
# The ID rxn01134_c0 is changed with 1 to create the final ID rxn01134_c1
# The ID rxn02376_c0 is changed with 1 to create the final ID rxn02376_c1
# The ID rxn08017_c0 is changed with 1 to create the final ID rxn08017_c1
# The ID rxn05598_c0 is changed with 1 to create the final ID rxn05598_c1
# The ID rxn02279_c0 is changed with 1 to create the final ID rxn02279_c1
# The ID rxn09209_c0 is changed with 1 to create the final ID rxn09209_c1
# The ID rxn00526_c0 is changed with 1 to create the final ID rxn00526_c1
# The ID rxn12512_c0 is changed with 1 to create the final ID rxn12512_c1
# The ID rxn08669_c0 is changed with 1 to create the final ID rxn08669_c1
# The ID rxn00902_c0 is changed with 1 to create the final ID rxn00902_c1
# The ID rxn00449_c0 is changed with 1 to create the final ID rxn00449_c1
# The ID rxn06672_c0 is changed with 1 to create the final ID rxn06672_c1
# The ID rxn01739_c0 is changed with 1 to create the final ID rxn01739_c1
# The ID rxn02400_c0 is changed with 1 to create the final ID rxn02400_c1
# The ID rxn01268_c0 is changed with 1 to create the final ID rxn01268_c1
# The ID rxn00361_c0 is changed with 1 to create the final ID rxn00361_c1
# The ID rxn02679_c0 is changed with 1 to create the final ID rxn02679_c1
# The ID rxn07434_c0 is changed with 1 to create the final ID rxn07434_c1
# The ID rxn01974_c0 is changed with 1 to create the final ID rxn01974_c1
# The ID rxn01640_c0 is changed with 1 to create the final ID rxn01640_c1
# The ID rxn00242_c0 is changed with 1 to create the final ID rxn00242_c1
# The ID rxn12641_c0 is changed with 1 to create the final ID rxn12641_c1
# The ID rxn00568_c0 is changed with 1 to create the final ID rxn00568_c1
# The ID rxn08971_c0 is changed with 1 to create the final ID rxn08971_c1
# The ID rxn01635_c0 is changed with 1 to create the final ID rxn01635_c1
# The ID rxn08471_c0 is changed with 1 to create the final ID rxn08471_c1
# The ID rxn03057_c0 is changed with 1 to create the final ID rxn03057_c1
# The ID rxn04384_c0 is changed with 1 to create the final ID rxn04384_c1
# The ID rxn00060_c0 is changed with 1 to create the final ID rxn00060_c1
# The ID rxn00225_c0 is changed with 1 to create the final ID rxn00225_c1
# The ID rxn05350_c0 is changed with 1 to create the final ID rxn05350_c1
# The ID rxn09198_c0 is changed with 1 to create the final ID rxn09198_c1
# The ID rxn08838_c0 is changed with 1 to create the final ID rxn08838_c1
# The ID rxn00148_c0 is changed with 1 to create the final ID rxn00148_c1
# The ID rxn01102_c0 is changed with 1 to create the final ID rxn01102_c1
# The ID rxn10197_c0 is changed with 1 to create the final ID rxn10197_c1
# The ID rxn05569_c0 is changed with 1 to create the final ID rxn05569_c1
# The ID rxn00100_c0 is changed with 1 to create the final ID rxn00100_c1
# The ID rxn02842_c0 is changed with 1 to create the final ID rxn02842_c1
# The ID rxn00514_c0 is changed with 1 to create the final ID rxn00514_c1
# The ID rxn00789_c0 is changed with 1 to create the final ID rxn00789_c1
# The ID rxn03436_c0 is changed with 1 to create the final ID rxn03436_c1
# The ID rxn05560_c0 is changed with 1 to create the final ID rxn05560_c1
# The ID rxn05437_c0 is changed with 1 to create the final ID rxn05437_c1
# The ID rxn05158_c0 is changed with 1 to create the final ID rxn05158_c1
# The ID rxn08976_c0 is changed with 1 to create the final ID rxn08976_c1
# The ID rxn00781_c0 is changed with 1 to create the final ID rxn00781_c1
# The ID rxn05319_c0 is changed with 1 to create the final ID rxn05319_c1
# The ID rxn00881_c0 is changed with 1 to create the final ID rxn00881_c1
# The ID rxn01355_c0 is changed with 1 to create the final ID rxn01355_c1
# The ID rxn00383_c0 is changed with 1 to create the final ID rxn00383_c1
# The ID rxn00292_c0 is changed with 1 to create the final ID rxn00292_c1
# The ID rxn08336_c0 is changed with 1 to create the final ID rxn08336_c1
# The ID rxn05401_c0 is changed with 1 to create the final ID rxn05401_c1
# The ID rxn02264_c0 is changed with 1 to create the final ID rxn02264_c1
# The ID rxn09202_c0 is changed with 1 to create the final ID rxn09202_c1
# The ID rxn01451_c0 is changed with 1 to create the final ID rxn01451_c1
# The ID rxn03903_c0 is changed with 1 to create the final ID rxn03903_c1
# The ID rxn00097_c0 is changed with 1 to create the final ID rxn00097_c1
# The ID rxn02212_c0 is changed with 1 to create the final ID rxn02212_c1
# The ID rxn00191_c0 is changed with 1 to create the final ID rxn00191_c1
# The ID rxn00695_c0 is changed with 1 to create the final ID rxn00695_c1
# The ID rxn00250_c0 is changed with 1 to create the final ID rxn00250_c1
# The ID rxn05324_c0 is changed with 1 to create the final ID rxn05324_c1
# The ID rxn10481_c0 is changed with 1 to create the final ID rxn10481_c1
# The ID rxn03535_c0 is changed with 1 to create the final ID rxn03535_c1
# The ID rxn00692_c0 is changed with 1 to create the final ID rxn00692_c1
# The ID rxn00311_c0 is changed with 1 to create the final ID rxn00311_c1
# The ID rxn01492_c0 is changed with 1 to create the final ID rxn01492_c1
# The ID rxn00802_c0 is changed with 1 to create the final ID rxn00802_c1
# The ID rxn08440_c0 is changed with 1 to create the final ID rxn08440_c1
# The ID rxn02160_c0 is changed with 1 to create the final ID rxn02160_c1
# The ID rxn08802_c0 is changed with 1 to create the final ID rxn08802_c1
# The ID rxn02315_c0 is changed with 1 to create the final ID rxn02315_c1
# The ID rxn01825_c0 is changed with 1 to create the final ID rxn01825_c1
# The ID rxn10230_c0 is changed with 1 to create the final ID rxn10230_c1
# The ID rxn02720_c0 is changed with 1 to create the final ID rxn02720_c1
# The ID rxn00913_c0 is changed with 1 to create the final ID rxn00913_c1
# The ID rxn01997_c0 is changed with 1 to create the final ID rxn01997_c1
# The ID rxn08809_c0 is changed with 1 to create the final ID rxn08809_c1
# The ID rxn00460_c0 is changed with 1 to create the final ID rxn00460_c1
# The ID rxn00171_c0 is changed with 1 to create the final ID rxn00171_c1
# The ID rxn03958_c0 is changed with 1 to create the final ID rxn03958_c1
# The ID rxn00178_c0 is changed with 1 to create the final ID rxn00178_c1
# The ID rxn03264_c0 is changed with 1 to create the final ID rxn03264_c1
# The ID rxn01362_c0 is changed with 1 to create the final ID rxn01362_c1
# The ID rxn03174_c0 is changed with 1 to create the final ID rxn03174_c1
# The ID rxn05161_c0 is changed with 1 to create the final ID rxn05161_c1
# The ID rxn00549_c0 is changed with 1 to create the final ID rxn00549_c1
# The ID rxn01022_c0 is changed with 1 to create the final ID rxn01022_c1
# The ID rxn05418_c0 is changed with 1 to create the final ID rxn05418_c1
# The ID rxn00506_c0 is changed with 1 to create the final ID rxn00506_c1
# The ID rxn01894_c0 is changed with 1 to create the final ID rxn01894_c1
# The ID rxn10060_c0 is changed with 1 to create the final ID rxn10060_c1
# The ID rxn02933_c0 is changed with 1 to create the final ID rxn02933_c1
# The ID rxn00727_c0 is changed with 1 to create the final ID rxn00727_c1
# The ID rxn05617_c0 is changed with 1 to create the final ID rxn05617_c1
# The ID rxn12638_c0 is changed with 1 to create the final ID rxn12638_c1
# The ID rxn01354_c0 is changed with 1 to create the final ID rxn01354_c1
# The ID rxn02268_c0 is changed with 1 to create the final ID rxn02268_c1
# The ID rxn00305_c0 is changed with 1 to create the final ID rxn00305_c1
# The ID rxn01445_c0 is changed with 1 to create the final ID rxn01445_c1
# The ID rxn05248_c0 is changed with 1 to create the final ID rxn05248_c1
# The ID rxn00612_c0 is changed with 1 to create the final ID rxn00612_c1
# The ID rxn08766_c0 is changed with 1 to create the final ID rxn08766_c1
# The ID rxn05539_c0 is changed with 1 to create the final ID rxn05539_c1
# The ID rxn08841_c0 is changed with 1 to create the final ID rxn08841_c1
# The ID rxn05461_c0 is changed with 1 to create the final ID rxn05461_c1
# The ID rxn03586_c0 is changed with 1 to create the final ID rxn03586_c1
# The ID rxn02159_c0 is changed with 1 to create the final ID rxn02159_c1
# The ID rxn05571_c0 is changed with 1 to create the final ID rxn05571_c1
# The ID rxn10222_c0 is changed with 1 to create the final ID rxn10222_c1
# The ID rxn00269_c0 is changed with 1 to create the final ID rxn00269_c1
# The ID rxn10263_c0 is changed with 1 to create the final ID rxn10263_c1
# The ID rxn02791_c0 is changed with 1 to create the final ID rxn02791_c1
# The ID rxn05466_c0 is changed with 1 to create the final ID rxn05466_c1
# The ID rxn08814_c0 is changed with 1 to create the final ID rxn08814_c1
# The ID rxn00004_c0 is changed with 1 to create the final ID rxn00004_c1
# The ID rxn00917_c0 is changed with 1 to create the final ID rxn00917_c1
# The ID rxn08078_c0 is changed with 1 to create the final ID rxn08078_c1
# The ID rxn08845_c0 is changed with 1 to create the final ID rxn08845_c1
# The ID rxn00395_c0 is changed with 1 to create the final ID rxn00395_c1
# The ID rxn01292_c0 is changed with 1 to create the final ID rxn01292_c1
# The ID rxn00375_c0 is changed with 1 to create the final ID rxn00375_c1
# The ID rxn00300_c0 is changed with 1 to create the final ID rxn00300_c1
# The ID rxn01925_c0 is changed with 1 to create the final ID rxn01925_c1
# The ID rxn08792_c0 is changed with 1 to create the final ID rxn08792_c1
# The ID rxn02798_c0 is changed with 1 to create the final ID rxn02798_c1
# The ID rxn00999_c0 is changed with 1 to create the final ID rxn00999_c1
# The ID rxn05174_c0 is changed with 1 to create the final ID rxn05174_c1
# The ID rxn08799_c0 is changed with 1 to create the final ID rxn08799_c1
# The ID rxn05585_c0 is changed with 1 to create the final ID rxn05585_c1
# The ID rxn00433_c0 is changed with 1 to create the final ID rxn00433_c1
# The ID rxn03023_c0 is changed with 1 to create the final ID rxn03023_c1
# The ID rxn03419_c0 is changed with 1 to create the final ID rxn03419_c1
# The ID rxn00679_c0 is changed with 1 to create the final ID rxn00679_c1
# The ID rxn01516_c0 is changed with 1 to create the final ID rxn01516_c1
# The ID rxn00758_c0 is changed with 1 to create the final ID rxn00758_c1
# The ID rxn00638_c0 is changed with 1 to create the final ID rxn00638_c1
# The ID rxn09111_c0 is changed with 1 to create the final ID rxn09111_c1
# The ID rxn01746_c0 is changed with 1 to create the final ID rxn01746_c1
# The ID rxn00471_c0 is changed with 1 to create the final ID rxn00471_c1
# The ID rxn05607_c0 is changed with 1 to create the final ID rxn05607_c1
# The ID rxn05595_c0 is changed with 1 to create the final ID rxn05595_c1
# The ID rxn05348_c0 is changed with 1 to create the final ID rxn05348_c1
# The ID rxn05435_c0 is changed with 1 to create the final ID rxn05435_c1
# The ID rxn03245_c0 is changed with 1 to create the final ID rxn03245_c1
# The ID rxn01504_c0 is changed with 1 to create the final ID rxn01504_c1
# The ID rxn00907_c0 is changed with 1 to create the final ID rxn00907_c1
# The ID rxn05458_c0 is changed with 1 to create the final ID rxn05458_c1
# The ID rxn02404_c0 is changed with 1 to create the final ID rxn02404_c1
# The ID rxn01644_c0 is changed with 1 to create the final ID rxn01644_c1
# The ID rxn02911_c0 is changed with 1 to create the final ID rxn02911_c1
# The ID rxn10067_c0 is changed with 1 to create the final ID rxn10067_c1
# The ID rxn01280_c0 is changed with 1 to create the final ID rxn01280_c1
# The ID rxn05581_c0 is changed with 1 to create the final ID rxn05581_c1
# The ID rxn05450_c0 is changed with 1 to create the final ID rxn05450_c1
# The ID rxn12847_c0 is changed with 1 to create the final ID rxn12847_c1
# The ID rxn05410_c0 is changed with 1 to create the final ID rxn05410_c1
# The ID rxn05443_c0 is changed with 1 to create the final ID rxn05443_c1
# The ID rxn09114_c0 is changed with 1 to create the final ID rxn09114_c1
# The ID rxn05535_c0 is changed with 1 to create the final ID rxn05535_c1
# The ID rxn09188_c0 is changed with 1 to create the final ID rxn09188_c1
# The ID rxn08822_c0 is changed with 1 to create the final ID rxn08822_c1
# The ID rxn05345_c0 is changed with 1 to create the final ID rxn05345_c1
# The ID rxn02071_c0 is changed with 1 to create the final ID rxn02071_c1
# The ID rxn01522_c0 is changed with 1 to create the final ID rxn01522_c1
# The ID rxn00336_c0 is changed with 1 to create the final ID rxn00336_c1
# The ID rxn05422_c0 is changed with 1 to create the final ID rxn05422_c1
# The ID rxn03891_c0 is changed with 1 to create the final ID rxn03891_c1
# The ID rxn01465_c0 is changed with 1 to create the final ID rxn01465_c1
# The ID rxn01833_c0 is changed with 1 to create the final ID rxn01833_c1
# The ID rxn05145_c0 is changed with 1 to create the final ID rxn05145_c1
# The ID rxn01872_c0 is changed with 1 to create the final ID rxn01872_c1
# The ID rxn01301_c0 is changed with 1 to create the final ID rxn01301_c1
# The ID rxn01643_c0 is changed with 1 to create the final ID rxn01643_c1
# The ID rxn04598_c0 is changed with 1 to create the final ID rxn04598_c1
# The ID rxn00248_c0 is changed with 1 to create the final ID rxn00248_c1
# The ID rxn00499_c0 is changed with 1 to create the final ID rxn00499_c1
# The ID rxn08844_c0 is changed with 1 to create the final ID rxn08844_c1
# The ID rxn05385_c0 is changed with 1 to create the final ID rxn05385_c1
# The ID rxn01637_c0 is changed with 1 to create the final ID rxn01637_c1
# The ID rxn05564_c0 is changed with 1 to create the final ID rxn05564_c1
# The ID rxn00566_c0 is changed with 1 to create the final ID rxn00566_c1
# The ID rxn00708_c0 is changed with 1 to create the final ID rxn00708_c1
# The ID rxn07433_c0 is changed with 1 to create the final ID rxn07433_c1
# The ID rxn00392_c0 is changed with 1 to create the final ID rxn00392_c1
# The ID rxn00747_c0 is changed with 1 to create the final ID rxn00747_c1
# The ID rxn01334_c0 is changed with 1 to create the final ID rxn01334_c1
# The ID rxn00830_c0 is changed with 1 to create the final ID rxn00830_c1
# The ID rxn01108_c0 is changed with 1 to create the final ID rxn01108_c1
# The ID rxn05219_c0 is changed with 1 to create the final ID rxn05219_c1
# The ID rxn00879_c0 is changed with 1 to create the final ID rxn00879_c1
# The ID rxn03406_c0 is changed with 1 to create the final ID rxn03406_c1
# The ID rxn00029_c0 is changed with 1 to create the final ID rxn00029_c1
# The ID rxn00609_c0 is changed with 1 to create the final ID rxn00609_c1
# The ID rxn06673_c0 is changed with 1 to create the final ID rxn06673_c1
# The ID rxn12646_c0 is changed with 1 to create the final ID rxn12646_c1
# The ID rxn06777_c0 is changed with 1 to create the final ID rxn06777_c1
# The ID rxn03869_c0 is changed with 1 to create the final ID rxn03869_c1
# The ID rxn05256_c0 is changed with 1 to create the final ID rxn05256_c1
# The ID rxn05448_c0 is changed with 1 to create the final ID rxn05448_c1
# The ID rxn05446_c0 is changed with 1 to create the final ID rxn05446_c1
# The ID rxn02175_c0 is changed with 1 to create the final ID rxn02175_c1
# The ID rxn05211_c0 is changed with 1 to create the final ID rxn05211_c1
# The ID rxn01634_c0 is changed with 1 to create the final ID rxn01634_c1
# The ID rxn02835_c0 is changed with 1 to create the final ID rxn02835_c1
# The ID rxn03884_c0 is changed with 1 to create the final ID rxn03884_c1
# The ID rxn02774_c0 is changed with 1 to create the final ID rxn02774_c1
# The ID rxn04385_c0 is changed with 1 to create the final ID rxn04385_c1
# The ID rxn01675_c0 is changed with 1 to create the final ID rxn01675_c1
# The ID rxn08839_c0 is changed with 1 to create the final ID rxn08839_c1
# The ID rxn03536_c0 is changed with 1 to create the final ID rxn03536_c1
# The ID rxn01575_c0 is changed with 1 to create the final ID rxn01575_c1
# The ID rxn05150_c0 is changed with 1 to create the final ID rxn05150_c1
# The ID rxn00656_c0 is changed with 1 to create the final ID rxn00656_c1
# The ID rxn02009_c0 is changed with 1 to create the final ID rxn02009_c1
# The ID rxn01868_c0 is changed with 1 to create the final ID rxn01868_c1
# The ID rxn03240_c0 is changed with 1 to create the final ID rxn03240_c1
# The ID rxn09562_c0 is changed with 1 to create the final ID rxn09562_c1
# The ID rxn00555_c0 is changed with 1 to create the final ID rxn00555_c1
# The ID rxn01828_c0 is changed with 1 to create the final ID rxn01828_c1
# The ID rxn03435_c0 is changed with 1 to create the final ID rxn03435_c1
# The ID rxn03080_c0 is changed with 1 to create the final ID rxn03080_c1
# The ID rxn10237_c0 is changed with 1 to create the final ID rxn10237_c1
# The ID rxn01044_c0 is changed with 1 to create the final ID rxn01044_c1
# The ID rxn10011_c0 is changed with 1 to create the final ID rxn10011_c1
# The ID rxn00143_c0 is changed with 1 to create the final ID rxn00143_c1
# The ID rxn12644_c0 is changed with 1 to create the final ID rxn12644_c1
# The ID rxn00147_c0 is changed with 1 to create the final ID rxn00147_c1
# The ID rxn00737_c0 is changed with 1 to create the final ID rxn00737_c1
# The ID rxn05292_c0 is changed with 1 to create the final ID rxn05292_c1
# The ID rxn08843_c0 is changed with 1 to create the final ID rxn08843_c1
# The ID rxn01256_c0 is changed with 1 to create the final ID rxn01256_c1
# The ID rxn00213_c0 is changed with 1 to create the final ID rxn00213_c1
# The ID rxn03040_c0 is changed with 1 to create the final ID rxn03040_c1
# The ID rxn01629_c0 is changed with 1 to create the final ID rxn01629_c1
# The ID rxn00777_c0 is changed with 1 to create the final ID rxn00777_c1
# The ID rxn01740_c0 is changed with 1 to create the final ID rxn01740_c1
# The ID rxn05533_c0 is changed with 1 to create the final ID rxn05533_c1
# The ID rxn05573_c0 is changed with 1 to create the final ID rxn05573_c1
# The ID rxn00190_c0 is changed with 1 to create the final ID rxn00190_c1
# The ID rxn05327_c0 is changed with 1 to create the final ID rxn05327_c1
# The ID rxn02762_c0 is changed with 1 to create the final ID rxn02762_c1
# The ID rxn05655_c0 is changed with 1 to create the final ID rxn05655_c1
# The ID rxn02314_c0 is changed with 1 to create the final ID rxn02314_c1
# The ID rxn08801_c0 is changed with 1 to create the final ID rxn08801_c1
# The ID rxn02161_c0 is changed with 1 to create the final ID rxn02161_c1
# The ID rxn02275_c0 is changed with 1 to create the final ID rxn02275_c1
# The ID rxn00251_c0 is changed with 1 to create the final ID rxn00251_c1
# The ID rxn01545_c0 is changed with 1 to create the final ID rxn01545_c1
# The ID rxn00139_c0 is changed with 1 to create the final ID rxn00139_c1
# The ID rxn00790_c0 is changed with 1 to create the final ID rxn00790_c1
# The ID rxn03910_c0 is changed with 1 to create the final ID rxn03910_c1
# The ID rxn00237_c0 is changed with 1 to create the final ID rxn00237_c1
# The ID rxn00463_c0 is changed with 1 to create the final ID rxn00463_c1
# The ID rxn01489_c0 is changed with 1 to create the final ID rxn01489_c1
# The ID rxn03540_c0 is changed with 1 to create the final ID rxn03540_c1
# The ID rxn08311_c0 is changed with 1 to create the final ID rxn08311_c1
# The ID rxn03175_c0 is changed with 1 to create the final ID rxn03175_c1
# The ID rxn10264_c0 is changed with 1 to create the final ID rxn10264_c1
# The ID rxn10124_c0 is changed with 1 to create the final ID rxn10124_c1
# The ID rxn03421_c0 is changed with 1 to create the final ID rxn03421_c1
# The ID rxn10227_c0 is changed with 1 to create the final ID rxn10227_c1
# The ID rxn01146_c0 is changed with 1 to create the final ID rxn01146_c1
# The ID rxn05336_c0 is changed with 1 to create the final ID rxn05336_c1
# The ID rxn09210_c0 is changed with 1 to create the final ID rxn09210_c1
# The ID rxn01484_c0 is changed with 1 to create the final ID rxn01484_c1
# The ID rxn01124_c0 is changed with 1 to create the final ID rxn01124_c1
# The ID rxn00285_c0 is changed with 1 to create the final ID rxn00285_c1
# The ID rxn00182_c0 is changed with 1 to create the final ID rxn00182_c1
# The ID rxn05552_c0 is changed with 1 to create the final ID rxn05552_c1
# The ID rxn01416_c0 is changed with 1 to create the final ID rxn01416_c1
# The ID rxn05567_c0 is changed with 1 to create the final ID rxn05567_c1
# The ID rxn04011_c0 is changed with 1 to create the final ID rxn04011_c1
# The ID rxn05172_c0 is changed with 1 to create the final ID rxn05172_c1
# The ID rxn01642_c0 is changed with 1 to create the final ID rxn01642_c1
# The ID rxn01204_c0 is changed with 1 to create the final ID rxn01204_c1
# The ID rxn01045_c0 is changed with 1 to create the final ID rxn01045_c1
# The ID rxn08044_c0 is changed with 1 to create the final ID rxn08044_c1
# The ID rxn04052_c0 is changed with 1 to create the final ID rxn04052_c1
# The ID rxn08893_c0 is changed with 1 to create the final ID rxn08893_c1
# The ID rxn06864_c0 is changed with 1 to create the final ID rxn06864_c1
# The ID rxn00712_c0 is changed with 1 to create the final ID rxn00712_c1
# The ID rxn12850_c0 is changed with 1 to create the final ID rxn12850_c1
# The ID rxn08815_c0 is changed with 1 to create the final ID rxn08815_c1
# The ID rxn00126_c0 is changed with 1 to create the final ID rxn00126_c1
# The ID rxn01518_c0 is changed with 1 to create the final ID rxn01518_c1
# The ID rxn03969_c0 is changed with 1 to create the final ID rxn03969_c1
# The ID rxn01278_c0 is changed with 1 to create the final ID rxn01278_c1
# The ID rxn01015_c0 is changed with 1 to create the final ID rxn01015_c1
# The ID rxn12844_c0 is changed with 1 to create the final ID rxn12844_c1
# The ID rxn08798_c0 is changed with 1 to create the final ID rxn08798_c1
# The ID rxn05175_c0 is changed with 1 to create the final ID rxn05175_c1
# The ID rxn08119_c0 is changed with 1 to create the final ID rxn08119_c1
# The ID rxn08306_c0 is changed with 1 to create the final ID rxn08306_c1
# The ID rxn08821_c0 is changed with 1 to create the final ID rxn08821_c1
# The ID rxn01871_c0 is changed with 1 to create the final ID rxn01871_c1
# The ID rxn05340_c0 is changed with 1 to create the final ID rxn05340_c1
# The ID rxn02143_c0 is changed with 1 to create the final ID rxn02143_c1
# The ID rxn00484_c0 is changed with 1 to create the final ID rxn00484_c1
# The ID rxn00639_c0 is changed with 1 to create the final ID rxn00639_c1
# The ID rxn00299_c0 is changed with 1 to create the final ID rxn00299_c1
# The ID rxn08546_c0 is changed with 1 to create the final ID rxn08546_c1
# The ID rxn00756_c0 is changed with 1 to create the final ID rxn00756_c1
# The ID rxn05389_c0 is changed with 1 to create the final ID rxn05389_c1
# The ID rxn05735_c0 is changed with 1 to create the final ID rxn05735_c1
# The ID rxn00904_c0 is changed with 1 to create the final ID rxn00904_c1
# The ID rxn02484_c0 is changed with 1 to create the final ID rxn02484_c1
# The ID rxn04597_c0 is changed with 1 to create the final ID rxn04597_c1
# The ID rxn12639_c0 is changed with 1 to create the final ID rxn12639_c1
# The ID rxn01000_c0 is changed with 1 to create the final ID rxn01000_c1
# The ID rxn00647_c0 is changed with 1 to create the final ID rxn00647_c1
# The ID rxn03397_c0 is changed with 1 to create the final ID rxn03397_c1
# The ID rxn08120_c0 is changed with 1 to create the final ID rxn08120_c1
# The ID rxn00363_c0 is changed with 1 to create the final ID rxn00363_c1
# The ID rxn01462_c0 is changed with 1 to create the final ID rxn01462_c1
# The ID rxn08128_c0 is changed with 1 to create the final ID rxn08128_c1
# The ID rxn01281_c0 is changed with 1 to create the final ID rxn01281_c1
# The ID rxn12643_c0 is changed with 1 to create the final ID rxn12643_c1
# The ID rxn02522_c0 is changed with 1 to create the final ID rxn02522_c1
# The ID rxn05183_c0 is changed with 1 to create the final ID rxn05183_c1
# The ID rxn01706_c0 is changed with 1 to create the final ID rxn01706_c1
# The ID rxn09359_c0 is changed with 1 to create the final ID rxn09359_c1
# The ID rxn01300_c0 is changed with 1 to create the final ID rxn01300_c1
# The ID rxn00411_c0 is changed with 1 to create the final ID rxn00411_c1
# The ID rxn00321_c0 is changed with 1 to create the final ID rxn00321_c1
# The ID rxn03886_c0 is changed with 1 to create the final ID rxn03886_c1
# The ID rxn00786_c0 is changed with 1 to create the final ID rxn00786_c1
# The ID rxn05217_c0 is changed with 1 to create the final ID rxn05217_c1
# The ID rxn03908_c0 is changed with 1 to create the final ID rxn03908_c1
# The ID rxn09197_c0 is changed with 1 to create the final ID rxn09197_c1
# The ID rxn01100_c0 is changed with 1 to create the final ID rxn01100_c1
# The ID rxn00838_c0 is changed with 1 to create the final ID rxn00838_c1
# The ID rxn00102_c0 is changed with 1 to create the final ID rxn00102_c1
# The ID rxn00831_c0 is changed with 1 to create the final ID rxn00831_c1
# The ID rxn02004_c0 is changed with 1 to create the final ID rxn02004_c1
# The ID rxn12634_c0 is changed with 1 to create the final ID rxn12634_c1
# The ID rxn00883_c0 is changed with 1 to create the final ID rxn00883_c1
# The ID rxn01255_c0 is changed with 1 to create the final ID rxn01255_c1
# The ID rxn10014_c0 is changed with 1 to create the final ID rxn10014_c1
# The ID rxn05296_c0 is changed with 1 to create the final ID rxn05296_c1
# The ID rxn05251_c0 is changed with 1 to create the final ID rxn05251_c1
# The ID rxn01176_c0 is changed with 1 to create the final ID rxn01176_c1
# The ID rxn05485_c0 is changed with 1 to create the final ID rxn05485_c1
# The ID rxn00214_c0 is changed with 1 to create the final ID rxn00214_c1
# The ID rxn01895_c0 is changed with 1 to create the final ID rxn01895_c1
# The ID rxn01211_c0 is changed with 1 to create the final ID rxn01211_c1
# The ID rxn00348_c0 is changed with 1 to create the final ID rxn00348_c1
# The ID rxn00527_c0 is changed with 1 to create the final ID rxn00527_c1
# The ID rxn05322_c0 is changed with 1 to create the final ID rxn05322_c1
# The ID rxn05193_c0 is changed with 1 to create the final ID rxn05193_c1
# The ID rxn12848_c0 is changed with 1 to create the final ID rxn12848_c1
# The ID rxn00792_c0 is changed with 1 to create the final ID rxn00792_c1
# The ID rxn03537_c0 is changed with 1 to create the final ID rxn03537_c1
# The ID rxn08804_c0 is changed with 1 to create the final ID rxn08804_c1
# The ID rxn01316_c0 is changed with 1 to create the final ID rxn01316_c1
# The ID rxn08442_c0 is changed with 1 to create the final ID rxn08442_c1
# The ID rxn05430_c0 is changed with 1 to create the final ID rxn05430_c1
# The ID rxn01917_c0 is changed with 1 to create the final ID rxn01917_c1
# The ID rxn01951_c0 is changed with 1 to create the final ID rxn01951_c1
# The ID rxn10236_c0 is changed with 1 to create the final ID rxn10236_c1
# The ID rxn08527_c0 is changed with 1 to create the final ID rxn08527_c1
# The ID rxn05501_c0 is changed with 1 to create the final ID rxn05501_c1
# The ID rxn03253_c0 is changed with 1 to create the final ID rxn03253_c1
# The ID rxn01509_c0 is changed with 1 to create the final ID rxn01509_c1
# The ID rxn01748_c0 is changed with 1 to create the final ID rxn01748_c1
# The ID rxn00173_c0 is changed with 1 to create the final ID rxn00173_c1
# The ID rxn01715_c0 is changed with 1 to create the final ID rxn01715_c1
# The ID rxn01548_c0 is changed with 1 to create the final ID rxn01548_c1
# The ID rxn08528_c0 is changed with 1 to create the final ID rxn08528_c1
# The ID rxn01145_c0 is changed with 1 to create the final ID rxn01145_c1
# The ID rxn09176_c0 is changed with 1 to create the final ID rxn09176_c1
# The ID rxn07586_c0 is changed with 1 to create the final ID rxn07586_c1
# The ID rxn09205_c0 is changed with 1 to create the final ID rxn09205_c1
# The ID rxn03269_c0 is changed with 1 to create the final ID rxn03269_c1
# The ID rxn05163_c0 is changed with 1 to create the final ID rxn05163_c1
# The ID rxn05364_c0 is changed with 1 to create the final ID rxn05364_c1
# The ID rxn09201_c0 is changed with 1 to create the final ID rxn09201_c1
# The ID rxn01669_c0 is changed with 1 to create the final ID rxn01669_c1
# The ID rxn01249_c0 is changed with 1 to create the final ID rxn01249_c1
# The ID rxn00508_c0 is changed with 1 to create the final ID rxn00508_c1
# The ID rxn01896_c0 is changed with 1 to create the final ID rxn01896_c1
# The ID rxn10122_c0 is changed with 1 to create the final ID rxn10122_c1
# The ID rxn05547_c0 is changed with 1 to create the final ID rxn05547_c1
# The ID rxn08352_c0 is changed with 1 to create the final ID rxn08352_c1
# The ID rxn00187_c0 is changed with 1 to create the final ID rxn00187_c1
# The ID rxn00728_c0 is changed with 1 to create the final ID rxn00728_c1
# The ID rxn08850_c0 is changed with 1 to create the final ID rxn08850_c1
# The ID rxn05734_c0 is changed with 1 to create the final ID rxn05734_c1
# The ID rxn00772_c0 is changed with 1 to create the final ID rxn00772_c1
# The ID rxn05508_c0 is changed with 1 to create the final ID rxn05508_c1
# The ID rxn08812_c0 is changed with 1 to create the final ID rxn08812_c1
# The ID rxn05682_c0 is changed with 1 to create the final ID rxn05682_c1
# The ID rxn00006_c0 is changed with 1 to create the final ID rxn00006_c1
# The ID rxn02503_c0 is changed with 1 to create the final ID rxn02503_c1
# The ID rxn05338_c0 is changed with 1 to create the final ID rxn05338_c1
# The ID rxn03135_c0 is changed with 1 to create the final ID rxn03135_c1
# The ID rxn12146_c0 is changed with 1 to create the final ID rxn12146_c1
# The ID rxn08310_c0 is changed with 1 to create the final ID rxn08310_c1
# The ID rxn00915_c0 is changed with 1 to create the final ID rxn00915_c1
# The ID rxn02853_c0 is changed with 1 to create the final ID rxn02853_c1
# The ID rxn01967_c0 is changed with 1 to create the final ID rxn01967_c1
# The ID rxn01515_c0 is changed with 1 to create the final ID rxn01515_c1
# The ID rxn10224_c0 is changed with 1 to create the final ID rxn10224_c1
# The ID rxn05337_c0 is changed with 1 to create the final ID rxn05337_c1
# The ID rxn01653_c0 is changed with 1 to create the final ID rxn01653_c1
# The ID rxn00474_c0 is changed with 1 to create the final ID rxn00474_c1
# The ID rxn03147_c0 is changed with 1 to create the final ID rxn03147_c1
# The ID rxn08073_c0 is changed with 1 to create the final ID rxn08073_c1
# The ID rxn05376_c0 is changed with 1 to create the final ID rxn05376_c1
# The ID rxn01123_c0 is changed with 1 to create the final ID rxn01123_c1
# The ID rxn08557_c0 is changed with 1 to create the final ID rxn08557_c1
# The ID rxn01842_c0 is changed with 1 to create the final ID rxn01842_c1
# The ID rxn01802_c0 is changed with 1 to create the final ID rxn01802_c1
# The ID rxn02317_c0 is changed with 1 to create the final ID rxn02317_c1
# The ID rxn01116_c0 is changed with 1 to create the final ID rxn01116_c1
# The ID rxn02811_c0 is changed with 1 to create the final ID rxn02811_c1
# The ID rxn05173_c0 is changed with 1 to create the final ID rxn05173_c1
# The ID rxn03062_c0 is changed with 1 to create the final ID rxn03062_c1
# The ID rxn08847_c0 is changed with 1 to create the final ID rxn08847_c1
# The ID rxn05608_c0 is changed with 1 to create the final ID rxn05608_c1
# The ID rxn00670_c0 is changed with 1 to create the final ID rxn00670_c1
# The ID rxn01544_c0 is changed with 1 to create the final ID rxn01544_c1
# The ID rxn00863_c0 is changed with 1 to create the final ID rxn00863_c1
# The ID rxn09113_c0 is changed with 1 to create the final ID rxn09113_c1
# The ID rxn00711_c0 is changed with 1 to create the final ID rxn00711_c1
# The ID rxn01270_c0 is changed with 1 to create the final ID rxn01270_c1
# The ID rxn01763_c0 is changed with 1 to create the final ID rxn01763_c1
# The ID rxn04787_c0 is changed with 1 to create the final ID rxn04787_c1
# The ID rxn02894_c0 is changed with 1 to create the final ID rxn02894_c1
# The ID rxn01138_c0 is changed with 1 to create the final ID rxn01138_c1
# The ID rxn02402_c0 is changed with 1 to create the final ID rxn02402_c1
# The ID rxn00010_c0 is changed with 1 to create the final ID rxn00010_c1
# The ID rxn05465_c0 is changed with 1 to create the final ID rxn05465_c1
# The ID rxn12845_c0 is changed with 1 to create the final ID rxn12845_c1
# The ID rxn08820_c0 is changed with 1 to create the final ID rxn08820_c1
# The ID rxn05380_c0 is changed with 1 to create the final ID rxn05380_c1
# The ID rxn05347_c0 is changed with 1 to create the final ID rxn05347_c1
# The ID rxn06077_c0 is changed with 1 to create the final ID rxn06077_c1
# The ID rxn04413_c0 is changed with 1 to create the final ID rxn04413_c1
# The ID rxn00145_c0 is changed with 1 to create the final ID rxn00145_c1
# The ID rxn08126_c0 is changed with 1 to create the final ID rxn08126_c1
# The ID rxn03407_c0 is changed with 1 to create the final ID rxn03407_c1
# The ID rxn05732_c0 is changed with 1 to create the final ID rxn05732_c1
# The ID rxn01870_c0 is changed with 1 to create the final ID rxn01870_c1
# The ID rxn00113_c0 is changed with 1 to create the final ID rxn00113_c1
# The ID rxn00497_c0 is changed with 1 to create the final ID rxn00497_c1
# The ID rxn00297_c0 is changed with 1 to create the final ID rxn00297_c1
# The ID rxn00745_c0 is changed with 1 to create the final ID rxn00745_c1
# The ID rxn06023_c0 is changed with 1 to create the final ID rxn06023_c1
# The ID rxn05028_c0 is changed with 1 to create the final ID rxn05028_c1
# The ID rxn00611_c0 is changed with 1 to create the final ID rxn00611_c1
# The ID rxn07435_c0 is changed with 1 to create the final ID rxn07435_c1
# The ID rxn05746_c0 is changed with 1 to create the final ID rxn05746_c1
# The ID rxn01678_c0 is changed with 1 to create the final ID rxn01678_c1
# The ID rxn02286_c0 is changed with 1 to create the final ID rxn02286_c1
# The ID rxn00394_c0 is changed with 1 to create the final ID rxn00394_c1
# The ID rxn00872_c0 is changed with 1 to create the final ID rxn00872_c1
# The ID rxn00832_c0 is changed with 1 to create the final ID rxn00832_c1
# The ID rxn01106_c0 is changed with 1 to create the final ID rxn01106_c1
# The ID rxn12640_c0 is changed with 1 to create the final ID rxn12640_c1
# The ID rxn00977_c0 is changed with 1 to create the final ID rxn00977_c1
# The ID rxn00931_c0 is changed with 1 to create the final ID rxn00931_c1
# The ID rxn08756_c0 is changed with 1 to create the final ID rxn08756_c1
# The ID rxn08470_c0 is changed with 1 to create the final ID rxn08470_c1
# The ID rxn10012_c0 is changed with 1 to create the final ID rxn10012_c1
# The ID rxn09450_c0 is changed with 1 to create the final ID rxn09450_c1
# The ID rxn00938_c0 is changed with 1 to create the final ID rxn00938_c1
# The ID rxn08380_c0 is changed with 1 to create the final ID rxn08380_c1
# The ID rxn04938_c0 is changed with 1 to create the final ID rxn04938_c1
# The ID rxn05527_c0 is changed with 1 to create the final ID rxn05527_c1
# ...
# The ID rxn00686_c0 is changed with 2 to create the final ID rxn00686_c2
# The ID rxn09112_c0 is changed with 2 to create the final ID rxn09112_c2
# The ID rxn06075_c0 is changed with 2 to create the final ID rxn06075_c2
# The ID rxn00689_c0 is changed with 2 to create the final ID rxn00689_c2
# The ID rxn01286_c0 is changed with 2 to create the final ID rxn01286_c2
# The ID rxn05289_c0 is changed with 2 to create the final ID rxn05289_c2
# The ID rxn01973_c0 is changed with 2 to create the final ID rxn01973_c2
# The ID rxn02523_c0 is changed with 2 to create the final ID rxn02523_c2
# The ID rxn00117_c0 is changed with 2 to create the final ID rxn00117_c2
# The ID rxn05343_c0 is changed with 2 to create the final ID rxn05343_c2
# The ID rxn01520_c0 is changed with 2 to create the final ID rxn01520_c2
# The ID rxn03395_c0 is changed with 2 to create the final ID rxn03395_c2
# The ID rxn00330_c0 is changed with 2 to create the final ID rxn00330_c2
# The ID rxn05736_c0 is changed with 2 to create the final ID rxn05736_c2
# The ID rxn03445_c0 is changed with 2 to create the final ID rxn03445_c2
# The ID rxn11663_c0 is changed with 2 to create the final ID rxn11663_c2
# The ID rxn01226_c0 is changed with 2 to create the final ID rxn01226_c2
# The ID rxn00493_c0 is changed with 2 to create the final ID rxn00493_c2
# The ID rxn08298_c0 is changed with 2 to create the final ID rxn08298_c2
# The ID rxn01834_c0 is changed with 2 to create the final ID rxn01834_c2
# The ID rxn00293_c0 is changed with 2 to create the final ID rxn00293_c2
# The ID rxn00367_c0 is changed with 2 to create the final ID rxn00367_c2
# The ID rxn14011_c0 is changed with 2 to create the final ID rxn14011_c2
# The ID rxn00839_c0 is changed with 2 to create the final ID rxn00839_c2
# The ID rxn03838_c0 is changed with 2 to create the final ID rxn03838_c2
# The ID rxn21857_c0 is changed with 2 to create the final ID rxn21857_c2
# The ID rxn14159_c0 is changed with 2 to create the final ID rxn14159_c2
# The ID rxn45996_c0 is changed with 2 to create the final ID rxn45996_c2
# The ID rxn16839_c0 is changed with 2 to create the final ID rxn16839_c2
# The ID rxn03542_c0 is changed with 2 to create the final ID rxn03542_c2
# The ID rxn42230_c0 is changed with 2 to create the final ID rxn42230_c2
# The ID rxn07455_c0 is changed with 2 to create the final ID rxn07455_c2
# The ID rxn26361_c0 is changed with 2 to create the final ID rxn26361_c2
# The ID rxn47768_c0 is changed with 2 to create the final ID rxn47768_c2
# The ID rxn21861_c0 is changed with 2 to create the final ID rxn21861_c2
# The ID rxn23042_c0 is changed with 2 to create the final ID rxn23042_c2
# The ID rxn15021_c0 is changed with 2 to create the final ID rxn15021_c2
# The ID rxn00154_c0 is changed with 2 to create the final ID rxn00154_c2
# The ID rxn01084_c0 is changed with 2 to create the final ID rxn01084_c2
# The ID rxn15395_c0 is changed with 2 to create the final ID rxn15395_c2
# The ID rxn15972_c0 is changed with 2 to create the final ID rxn15972_c2
# The ID rxn25271_c0 is changed with 2 to create the final ID rxn25271_c2
# The ID rxn26456_c0 is changed with 2 to create the final ID rxn26456_c2
# The ID rxn14428_c0 is changed with 2 to create the final ID rxn14428_c2
# The ID rxn15249_c0 is changed with 2 to create the final ID rxn15249_c2
# The ID rxn15466_c0 is changed with 2 to create the final ID rxn15466_c2
# The ID rxn05121_c0 is changed with 2 to create the final ID rxn05121_c2
# The ID rxn14427_c0 is changed with 2 to create the final ID rxn14427_c2
# The ID rxn14422_c0 is changed with 2 to create the final ID rxn14422_c2
# The ID rxn14419_c0 is changed with 2 to create the final ID rxn14419_c2
# The ID rxn14426_c0 is changed with 2 to create the final ID rxn14426_c2
# The ID rxn10415_c0 is changed with 2 to create the final ID rxn10415_c2
# The ID rxn29769_c0 is changed with 2 to create the final ID rxn29769_c2
# The ID rxn18486_c0 is changed with 2 to create the final ID rxn18486_c2
# The ID rxn08070_c0 is changed with 2 to create the final ID rxn08070_c2
# The ID rxn08098_c0 is changed with 2 to create the final ID rxn08098_c2
# The ID rxn09295_c0 is changed with 2 to create the final ID rxn09295_c2
# The ID rxn08608_c0 is changed with 2 to create the final ID rxn08608_c2
# The ID rxn08762_c0 is changed with 2 to create the final ID rxn08762_c2
# The ID rxn08192_c0 is changed with 2 to create the final ID rxn08192_c2
# The ID rxn08173_c0 is changed with 2 to create the final ID rxn08173_c2
# The ID rxn08869_c0 is changed with 2 to create the final ID rxn08869_c2
# The ID rxn08734_c0 is changed with 2 to create the final ID rxn08734_c2
# The ID rxn09003_c0 is changed with 2 to create the final ID rxn09003_c2
# The ID rxn27362_c0 is changed with 2 to create the final ID rxn27362_c2
# The ID rxn14412_c0 is changed with 2 to create the final ID rxn14412_c2
# The ID rxn14418_c0 is changed with 2 to create the final ID rxn14418_c2
# The ID rxn14421_c0 is changed with 2 to create the final ID rxn14421_c2
# The ID rxn14425_c0 is changed with 2 to create the final ID rxn14425_c2
# The ID rxn14420_c0 is changed with 2 to create the final ID rxn14420_c2
# The ID rxn09001_c0 is changed with 2 to create the final ID rxn09001_c2
# The ID rxn14415_c0 is changed with 2 to create the final ID rxn14415_c2
# The ID rxn26307_c0 is changed with 2 to create the final ID rxn26307_c2
# The ID rxn23043_c0 is changed with 2 to create the final ID rxn23043_c2
# The ID rxn41896_c0 is changed with 2 to create the final ID rxn41896_c2
# The ID rxn21729_c0 is changed with 2 to create the final ID rxn21729_c2
# The ID rxn23045_c0 is changed with 2 to create the final ID rxn23045_c2
# The ID rxn21862_c0 is changed with 2 to create the final ID rxn21862_c2
# The ID rxn39452_c0 is changed with 2 to create the final ID rxn39452_c2
# The ID rxn16583_c0 is changed with 2 to create the final ID rxn16583_c2
# The ID rxn44539_c0 is changed with 2 to create the final ID rxn44539_c2
# The ID rxn15337_c0 is changed with 2 to create the final ID rxn15337_c2
# The ID rxn10506_c0 is changed with 2 to create the final ID rxn10506_c2
# The ID rxn15338_c0 is changed with 2 to create the final ID rxn15338_c2
# The ID rxn21864_c0 is changed with 2 to create the final ID rxn21864_c2
# The ID rxn39451_c0 is changed with 2 to create the final ID rxn39451_c2
# The ID rxn21858_c0 is changed with 2 to create the final ID rxn21858_c2
# The ID rxn46694_c0 is changed with 2 to create the final ID rxn46694_c2
# The ID rxn40439_c0 is changed with 2 to create the final ID rxn40439_c2
# The ID rxn24830_c0 is changed with 2 to create the final ID rxn24830_c2
# The ID rxn24134_c0 is changed with 2 to create the final ID rxn24134_c2
# The ID rxn26021_c0 is changed with 2 to create the final ID rxn26021_c2
# The ID rxn41683_c0 is changed with 2 to create the final ID rxn41683_c2
# The ID rxn15334_c0 is changed with 2 to create the final ID rxn15334_c2
# The ID rxn07436_c0 is changed with 2 to create the final ID rxn07436_c2
# The ID rxn15167_c0 is changed with 2 to create the final ID rxn15167_c2
# The ID rxn28338_c0 is changed with 2 to create the final ID rxn28338_c2
# The ID rxn03396_c0 is changed with 2 to create the final ID rxn03396_c2
# The ID rxn15296_c0 is changed with 2 to create the final ID rxn15296_c2
# The ID rxn15293_c0 is changed with 2 to create the final ID rxn15293_c2
# The ID rxn13741_c0 is changed with 2 to create the final ID rxn13741_c2
# The ID rxn08153_c0 is changed with 2 to create the final ID rxn08153_c2
# The ID rxn22316_c0 is changed with 2 to create the final ID rxn22316_c2
# The ID rxn43581_c0 is changed with 2 to create the final ID rxn43581_c2
# The ID rxn24966_c0 is changed with 2 to create the final ID rxn24966_c2
# The ID rxn25971_c0 is changed with 2 to create the final ID rxn25971_c2
# The ID rxn08241_c0 is changed with 2 to create the final ID rxn08241_c2
# The ID rxn08234_c0 is changed with 2 to create the final ID rxn08234_c2
# The ID rxn08187_c0 is changed with 2 to create the final ID rxn08187_c2
# The ID rxn09182_c0 is changed with 2 to create the final ID rxn09182_c2
# The ID rxn08715_c0 is changed with 2 to create the final ID rxn08715_c2
# The ID rxn26305_c0 is changed with 2 to create the final ID rxn26305_c2
# The ID rxn26457_c0 is changed with 2 to create the final ID rxn26457_c2
# The ID rxn26459_c0 is changed with 2 to create the final ID rxn26459_c2
# The ID rxn23336_c0 is changed with 2 to create the final ID rxn23336_c2
# The ID rxn23850_c0 is changed with 2 to create the final ID rxn23850_c2
# The ID rxn40368_c0 is changed with 2 to create the final ID rxn40368_c2
# The ID rxn15230_c0 is changed with 2 to create the final ID rxn15230_c2
# The ID rxn20583_c0 is changed with 2 to create the final ID rxn20583_c2
# The ID rxn15467_c0 is changed with 2 to create the final ID rxn15467_c2
# The ID rxn27318_c0 is changed with 2 to create the final ID rxn27318_c2
# The ID rxn16824_c0 is changed with 2 to create the final ID rxn16824_c2
# The ID rxn39964_c0 is changed with 2 to create the final ID rxn39964_c2
# The ID rxn16806_c0 is changed with 2 to create the final ID rxn16806_c2
# The ID rxn14061_c0 is changed with 2 to create the final ID rxn14061_c2
# The ID rxn13957_c0 is changed with 2 to create the final ID rxn13957_c2
# The ID rxn21863_c0 is changed with 2 to create the final ID rxn21863_c2
# The ID rxn40037_c0 is changed with 2 to create the final ID rxn40037_c2
# The ID rxn41287_c0 is changed with 2 to create the final ID rxn41287_c2
# The ID rxn21859_c0 is changed with 2 to create the final ID rxn21859_c2
# The ID rxn17731_c0 is changed with 2 to create the final ID rxn17731_c2
# The ID rxn21860_c0 is changed with 2 to create the final ID rxn21860_c2
# The ID rxn05120_c0 is changed with 2 to create the final ID rxn05120_c2
# The ID rxn15750_c0 is changed with 2 to create the final ID rxn15750_c2
# The ID rxn26127_c0 is changed with 2 to create the final ID rxn26127_c2
# The ID rxn19704_c0 is changed with 2 to create the final ID rxn19704_c2
# The ID rxn45692_c0 is changed with 2 to create the final ID rxn45692_c2
# The ID rxn10470_c0 is changed with 2 to create the final ID rxn10470_c2
# The ID rxn05469_c0 is changed with 2 to create the final ID rxn05469_c2
# The ID rxn05064_c0 is changed with 2 to create the final ID rxn05064_c2
# The ID rxn02374_c0 is changed with 2 to create the final ID rxn02374_c2
# The ID rxn05730_c0 is changed with 2 to create the final ID rxn05730_c2
# The ID rxn04457_c0 is changed with 2 to create the final ID rxn04457_c2
# The ID rxn05129_c0 is changed with 2 to create the final ID rxn05129_c2
# The ID rxn02916_c0 is changed with 2 to create the final ID rxn02916_c2
# The ID rxn05488_c0 is changed with 2 to create the final ID rxn05488_c2
# The ID rxn03012_c0 is changed with 2 to create the final ID rxn03012_c2
# The ID rxn10471_c0 is changed with 2 to create the final ID rxn10471_c2
# The ID rxn04132_c0 is changed with 2 to create the final ID rxn04132_c2
# The ID rxn05559_c0 is changed with 2 to create the final ID rxn05559_c2
# The ID rxn05195_c0 is changed with 2 to create the final ID rxn05195_c2
# The ID rxn01208_c0 is changed with 2 to create the final ID rxn01208_c2
# The ID rxn02989_c0 is changed with 2 to create the final ID rxn02989_c2
# The ID rxn00064_c0 is changed with 2 to create the final ID rxn00064_c2
# The ID rxn05468_c0 is changed with 2 to create the final ID rxn05468_c2
# The ID rxn04133_c0 is changed with 2 to create the final ID rxn04133_c2
# The ID rxn10570_c0 is changed with 2 to create the final ID rxn10570_c2
# The ID rxn02666_c0 is changed with 2 to create the final ID rxn02666_c2
# The ID rxn05467_c0 is changed with 2 to create the final ID rxn05467_c2
# The ID rxn24718_c0 is changed with 2 to create the final ID rxn24718_c2
# The ID rxn23589_c0 is changed with 2 to create the final ID rxn23589_c2
# The ID rxn08502_e0 is changed with  to create the final ID rxn08502_e0
# The ID rxn08428_c0 is changed with 2 to create the final ID rxn08428_c2
# The ID rxn08032_c0 is changed with 2 to create the final ID rxn08032_c2
# The ID rxn09008_c0 is changed with 2 to create the final ID rxn09008_c2
# The ID rxn08691_c0 is changed with 2 to create the final ID rxn08691_c2
# The ID rxn08966_c0 is changed with 2 to create the final ID rxn08966_c2
# The ID rxn08350_c0 is changed with 2 to create the final ID rxn08350_c2
# The ID rxn08689_c0 is changed with 2 to create the final ID rxn08689_c2
# The ID rxn09260_c0 is changed with 2 to create the final ID rxn09260_c2
# The ID rxn09330_c0 is changed with 2 to create the final ID rxn09330_c2
# The ID rxn00062_c0 is changed with 2 to create the final ID rxn00062_c2
# The ID rxn12225_c0 is changed with 2 to create the final ID rxn12225_c2
# The ID rxn12008_c0 is changed with 2 to create the final ID rxn12008_c2
# The ID rxn03086_c0 is changed with 2 to create the final ID rxn03086_c2
# The ID rxn08333_c0 is changed with 2 to create the final ID rxn08333_c2
# The ID rxn02898_c0 is changed with 2 to create the final ID rxn02898_c2
# The ID rxn10336_c0 is changed with 2 to create the final ID rxn10336_c2
# The ID rxn03030_c0 is changed with 2 to create the final ID rxn03030_c2
# The ID rxn01331_c0 is changed with 2 to create the final ID rxn01331_c2
# The ID rxn05459_c0 is changed with 2 to create the final ID rxn05459_c2
# The ID rxn00442_c0 is changed with 2 to create the final ID rxn00442_c2
# The ID rxn00068_c0 is changed with 2 to create the final ID rxn00068_c2
# The ID rxn05481_c0 is changed with 2 to create the final ID rxn05481_c2
# The ID rxn00340_c0 is changed with 2 to create the final ID rxn00340_c2
# The ID rxn05722_c0 is changed with 2 to create the final ID rxn05722_c2
# The ID rxn02404_c0 is changed with 2 to create the final ID rxn02404_c2
# The ID rxn05039_c0 is changed with 2 to create the final ID rxn05039_c2
# The ID rxn03891_c0 is changed with 2 to create the final ID rxn03891_c2
# The ID rxn09128_c0 is changed with 2 to create the final ID rxn09128_c2
# The ID rxn09042_c0 is changed with 2 to create the final ID rxn09042_c2
# The ID rxn01972_c0 is changed with 2 to create the final ID rxn01972_c2
# The ID rxn00979_c0 is changed with 2 to create the final ID rxn00979_c2
# The ID rxn00966_c0 is changed with 2 to create the final ID rxn00966_c2
# The ID rxn01539_c0 is changed with 2 to create the final ID rxn01539_c2
# The ID rxn02939_c0 is changed with 2 to create the final ID rxn02939_c2
# The ID rxn09041_c0 is changed with 2 to create the final ID rxn09041_c2
# The ID rxn03150_c0 is changed with 2 to create the final ID rxn03150_c2
# The ID rxn01213_c0 is changed with 2 to create the final ID rxn01213_c2
# The ID rxn03398_c0 is changed with 2 to create the final ID rxn03398_c2
# The ID rxn02831_c0 is changed with 2 to create the final ID rxn02831_c2
# The ID rxn01258_c0 is changed with 2 to create the final ID rxn01258_c2
# The ID rxn02832_c0 is changed with 2 to create the final ID rxn02832_c2
# The ID rxn00127_c0 is changed with 2 to create the final ID rxn00127_c2
# The ID rxn13477_c0 is changed with 2 to create the final ID rxn13477_c2
# The ID SK_cpd02701_c0 is changed with 2 to create the final ID SK_cpd02701_c2
# The ID SK_cpd03091_c0 is changed with 2 to create the final ID SK_cpd03091_c2
# The ID SK_cpd11416_c0 is changed with 2 to create the final ID SK_cpd11416_c2
# The ID SK_cpd15302_c0 is changed with 2 to create the final ID SK_cpd15302_c2
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c1' since it already exists.
# WARNING:cobra.core.model:Ignoring reaction 'rxn00062_c2' since it already exists.
# cpd11416_c0 bio1: 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0;	cpd11416_c0 SK_cpd11416_c0: cpd11416_c0 <=> ;
# Pantoea_sp._YR343_2511231025.fna.RAST.mdl 300 0.5
# Rhizobium_sp._CF142_2510917030.fna.RAST.mdl 300 0.5
# MainProcess~~5	['Pantoea_sp._YR343_2511231025.fna.RAST.mdl', 'Rhizobium_sp._CF142_2510917030.fna.RAST.mdl']	116.69351620911931
# Pantoea_sp._YR343_2511231025.fna.RAST.mdl 74.19465065631161
# Rhizobium_sp._CF142_2510917030.fna.RAST.mdl 25.757922625618484
# /Library/Python/3.9/site-packages/sigfig/sigfig.py:586: UserWarning: warning: 5 significant figures requested from number with only 3 significant figures
#   warn("warning: %d significant figures requested from number with only %d significant figures" % (given['sigfigs'], len(num.map)))

# %%
from cobra import Model, Metabolite, Reaction
from modelseedpy import MSModelUtil
import re

def parse_id(object):
    if re.search("(.+)_([a-z]+)(\d*)$", object.id) != None:
        m = re.search("(.+)_([a-z]+)(\d*)$", object.id)
        return (m[1], m[2], m[3])
    return None

def build_from_species_models2(
        models, mdlid=None, name=None, names=[], abundances=None,basemodel=None
    ):
        """Merges the input list of single species metabolic models into a community metabolic model

        Parameters
        ----------
        models : list<Cobra.Model>
            List of models to be merged into a community model
        mdlid : string
            String specifying community model ID
        name : string
            String specifying community model name
        names : list<string>
            List of human readable names for models being merged
        abundances : dict<string,float>
            Hash of relative abundances for input models in community model

        Returns
        -------
        Cobra.Model
            Community model object

        Raises
        ------
        """
        if basemodel:
            newmodel = basemodel
        else:
            newmodel = Model(mdlid, name)
        newutl = MSModelUtil.get(newmodel)
        biomass_compounds = []
        index = 1
        biomass_index = 2
        for model in models:
            new_metabolites = []
            new_reactions = []
            # Rename metabolites
            for met in model.metabolites:
                # Renaming compartments
                if re.search("[a-z+](\d*)$", met.compartment):
                    m = re.search("([a-z]+)(\d*)$", met.compartment)
                    if len(m[2]) == 0:
                        if m[1] == "e":
                            met.compartment += "0"
                        else:
                            met.compartment += str(index)
                    elif m[1] == "e":
                        met.compartment = m[1] + "0"
                    else:
                        met.compartment = m[1] + str(index)
                # Processing metabolite ID
                output = parse_id(met)
                if output == None:
                    if met.compartment[0] != "e":
                        met.id += str(index)
                elif output[1] != "e":
                    if len(output[2]) == 0:
                        met.id = met.id + str(index)
                    else:
                        met.id = output[0] + "_" + output[1] + str(index)
                if met.id not in newmodel.metabolites:
                    new_metabolites.append(met)
                    if newutl.metabolite_msid(met) == "cpd11416":
                        biomass_compounds.append(met)
            # Rename reactions
            for rxn in model.reactions:
                if rxn.id[0:3] != "EX_":
                    if re.search("^(bio)(\d+)$", rxn.id) != None:
                        rxn.id = "bio" + str(biomass_index)
                        biomass_index += 1
                    else:
                        output = parse_id(rxn)
                        if output == None:
                            if rxn.compartment.id[0] != "e":
                                rxn.id += str(index)
                        elif output[1] != "e":
                            if len(output[2]) == 0:
                                rxn.id = rxn.id + str(index)
                            else:
                                rxn.id = output[0] + "_" + output[1] + str(index)
                if rxn.id not in newmodel.reactions:
                    new_reactions.append(rxn)
            # Adding new reactions and compounds to base model
            newmodel.add_reactions(new_reactions)
            newmodel.add_metabolites(new_metabolites)
            index += 1
        # Create community biomass
        comm_biomass = Metabolite("cpd11416_c0", None, "Community biomass", 0, "c0")
        metabolites = {comm_biomass: 1}
        comm_biorxn = Reaction(id="bio1", name="bio1", lower_bound=0, upper_bound=100)
        count = len(biomass_compounds)
        for cpd in biomass_compounds:
            metabolites[cpd] = -1 / count
        comm_biorxn.add_metabolites(metabolites)
        newmodel.add_reactions([comm_biorxn])
        newutl.add_exchanges_for_metabolites([comm_biomass], 0, 100, "SK_")
        return newmodel

example_pairwise_chris = build_from_species_models2(models[:2])

# %%
print(example_pairwise_chris.reactions.bio1.reaction)
sol = example_pairwise_chris.optimize()
print({"bio2": sol.fluxes["bio2"], "bio3": sol.fluxes["bio3"]})
# Out:
# 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# {'bio2': 0.0, 'bio3': 0.0}

# %%
example_pairwise = build_from_species_models(models[:2])
# Out:
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02201_c1 complex cpx00700 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02201_c1 complex cpx01370 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00351_c1 complex cpx01737 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn07431_c1 complex cpx00466 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00836_c1 complex cpx00605 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00423_c1 complex cpx01222 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00364_c1 complex tcpx00352 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05561_c1 complex cpx00333 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05561_c1 complex tcpx00648 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03408_c1 complex cpx00655 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02177_c1 complex cpx00931 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05250_c1 complex cpx00498 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00646_c1 complex cpx01042 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05440_c1 complex cpx00149 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01673_c1 complex cpx00356 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00247_c1 complex cpx01779 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05625_c1 complex tcpx00621 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02360_c1 complex cpx01559 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02342_c1 complex tcpx00090 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05156_c1 complex tcpx00674 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01452_c1 complex cpx01574 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00642_c1 complex cpx01147 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00022_c1 complex cpx01675 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03239_c1 complex cpx01599 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03534_c1 complex tcpx00169 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00322_c1 complex cpx01187 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00654_c1 complex cpx01287 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05457_c1 complex cpx00117 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00107_c1 complex cpx00356 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08934_c1 complex cpx01675 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn04070_c1 complex cpx01610 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00199_c1 complex cpx00073 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01358_c1 complex cpx00287 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03433_c1 complex cpx01365 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10231_c1 complex cpx00192 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01867_c1 complex cpx00851 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10270_c1 complex cpx00172 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12637_c1 complex cpx00045 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12637_c1 complex cpx00046 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12637_c1 complex cpx00048 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12637_c1 complex cpx00051 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01385_c1 complex cpx01361 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn09240_c1 complex cpx01046 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01219_c1 complex tcpx00352 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00800_c1 complex cpx00903 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00800_c1 complex tcpx00432 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn09177_c1 complex cpx00641 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00211_c1 complex tcpx00435 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00179_c1 complex cpx01204 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02945_c1 complex cpx00208 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00587_c1 complex tcpx00015 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01210_c1 complex cpx00440 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00192_c1 complex cpx01409 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00192_c1 complex tcpx01368 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01218_c1 complex cpx00863 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01218_c1 complex cpx01447 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01218_c1 complex cpx52456 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00509_c1 complex cpx01308 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00962_c1 complex cpx52638 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05654_c1 complex cpx00333 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05654_c1 complex tcpx00648 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01199_c1 complex cpx00015 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08807_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08807_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05614_c1 complex cpx00126 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00501_c1 complex cpx00297 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10344_c1 complex cpx01488 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02320_c1 complex cpx00580 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03384_c1 complex cpx00858 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05167_c1 complex tcpx00630 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02095_c1 complex tcpx00243 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01405_c1 complex tcpx00851 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02504_c1 complex cpx01264 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn04996_c1 complex cpx00873 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00262_c1 complex cpx00467 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03039_c1 complex cpx00606 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10262_c1 complex cpx00210 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10126_c1 complex tcpx00088 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08084_c1 complex tcpx00177 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10225_c1 complex cpx00209 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00898_c1 complex cpx00562 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05444_c1 complex cpx00149 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05334_c1 complex cpx52441 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05334_c1 complex cpx52442 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05040_c1 complex tcpx00757 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00890_c1 complex cpx01226 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01636_c1 complex cpx01763 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02090_c1 complex cpx00487 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05377_c1 complex cpx52441 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08556_c1 complex tcpx00405 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01843_c1 complex cpx00730 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00816_c1 complex tcpx00209 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02988_c1 complex tcpx01102 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn04792_c1 complex tcpx00864 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01021_c1 complex cpx00311 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00165_c1 complex cpx00322 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00165_c1 complex cpx01545 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00165_c1 complex tcpx00443 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00165_c1 complex tcpx01318 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10228_c1 complex cpx00192 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01117_c1 complex cpx52577 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05542_c1 complex tcpx00574 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00539_c1 complex tcpx00245 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01121_c1 complex cpx01152 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00001_c1 complex cpx01835 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05369_c1 complex cpx52441 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05545_c1 complex tcpx00574 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08895_c1 complex cpx52446 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00671_c1 complex cpx00297 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn11268_c1 complex cpx01032 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn11268_c1 complex cpx01033 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00710_c1 complex cpx00474 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01114_c1 complex cpx00577 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02305_c1 complex cpx00853 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02305_c1 complex tcpx01094 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00470_c1 complex cpx00689 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00470_c1 complex tcpx00014 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02885_c1 complex cpx01360 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08817_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08817_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01203_c1 complex tcpx00395 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00910_c1 complex cpx00544 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00953_c1 complex cpx00630 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn11944_c1 complex cpx00127 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08296_c1 complex cpx00181 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05541_c1 complex tcpx00574 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00717_c1 complex cpx00487 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01297_c1 complex tcpx00087 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01962_c1 complex tcpx00872 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10254_c1 complex cpx00181 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01682_c1 complex cpx00547 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08796_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08796_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01806_c1 complex tcpx00149 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08941_c1 complex cpx01600 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03181_c1 complex cpx01602 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02331_c1 complex cpx00239 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12846_c1 complex cpx00045 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12846_c1 complex cpx00046 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12846_c1 complex cpx00048 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12846_c1 complex cpx00051 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00337_c1 complex cpx01572 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08308_c1 complex cpx00209 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00208_c1 complex cpx00756 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08823_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08823_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05031_c1 complex cpx00208 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05434_c1 complex cpx00149 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00140_c1 complex tcpx00020 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05346_c1 complex cpx00244 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05346_c1 complex cpx00289 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05346_c1 complex tcpx00137 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00867_c1 complex cpx01683 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00452_c1 complex cpx01643 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03248_c1 complex cpx00454 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05386_c1 complex cpx52441 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05386_c1 complex cpx52442 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05516_c1 complex cpx01488 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05733_c1 complex cpx00259 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn09206_c1 complex cpx00192 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02376_c1 complex cpx00636 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08017_c1 complex tcpx00355 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05598_c1 complex cpx01729 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn09209_c1 complex cpx00192 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12512_c1 complex cpx00641 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08669_c1 complex cpx00346 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00902_c1 complex cpx00182 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00015_c1 complex tcpx00851 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn06672_c1 complex cpx01771 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00649_c1 complex cpx00259 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01739_c1 complex cpx01436 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02400_c1 complex cpx00863 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02400_c1 complex cpx01447 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02400_c1 complex cpx52456 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01268_c1 complex cpx01312 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01268_c1 complex tcpx00091 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00641_c1 complex cpx00816 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00361_c1 complex cpx00436 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02679_c1 complex tcpx00049 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02679_c1 complex tcpx00282 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn07434_c1 complex cpx00466 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01974_c1 complex cpx00594 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01640_c1 complex cpx01272 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00242_c1 complex cpx00737 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12641_c1 complex cpx00045 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12641_c1 complex cpx00046 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12641_c1 complex cpx00048 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12641_c1 complex cpx00051 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00568_c1 complex tcpx00199 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08971_c1 complex cpx00019 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01635_c1 complex cpx00778 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08471_c1 complex tcpx00097 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn04384_c1 complex tcpx01091 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02775_c1 complex tcpx00140 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00060_c1 complex cpx01323 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00225_c1 complex cpx00005 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05350_c1 complex cpx00244 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05350_c1 complex cpx00289 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05350_c1 complex tcpx00137 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn09198_c1 complex cpx00251 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08838_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08838_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00148_c1 complex cpx01664 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03906_c1 complex cpx00160 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00100_c1 complex cpx00384 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02281_c1 complex tcpx00372 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02281_c1 complex tcpx00373 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02842_c1 complex tcpx00783 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00514_c1 complex tcpx00872 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00789_c1 complex tcpx00419 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00789_c1 complex tcpx00421 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03436_c1 complex tcpx00147 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03436_c1 complex tcpx00266 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05390_c1 complex cpx52441 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05390_c1 complex cpx52442 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05437_c1 complex cpx00149 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05158_c1 complex tcpx00665 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08976_c1 complex cpx00019 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00781_c1 complex cpx01143 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05319_c1 complex tcpx00992 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00881_c1 complex cpx00139 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05298_c1 complex cpx00159 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01355_c1 complex tcpx00146 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00383_c1 complex tcpx01122 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08336_c1 complex tcpx01156 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05401_c1 complex cpx00147 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03043_c1 complex tcpx00903 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02264_c1 complex cpx01632 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05157_c1 complex tcpx00699 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn09202_c1 complex cpx00251 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01451_c1 complex cpx00206 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01451_c1 complex cpx01599 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03903_c1 complex cpx01511 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00097_c1 complex cpx00811 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05514_c1 complex cpx01502 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05514_c1 complex tcpx00576 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02212_c1 complex cpx00113 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00695_c1 complex cpx01571 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00250_c1 complex tcpx00387 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05324_c1 complex cpx00149 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10481_c1 complex tcpx00605 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03535_c1 complex cpx00910 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03535_c1 complex cpx52754 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00692_c1 complex cpx01278 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00802_c1 complex cpx00032 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08440_c1 complex cpx52428 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02160_c1 complex cpx00118 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08802_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08802_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01825_c1 complex tcpx00374 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00926_c1 complex cpx01331 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10230_c1 complex cpx00192 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02720_c1 complex tcpx00049 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02720_c1 complex tcpx00282 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00913_c1 complex cpx00863 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00913_c1 complex cpx01447 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00913_c1 complex cpx52456 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08809_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08809_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00460_c1 complex cpx01664 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00171_c1 complex cpx00893 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03958_c1 complex cpx01001 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00131_c1 complex cpx01374 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00178_c1 complex cpx00454 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00178_c1 complex cpx00666 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03264_c1 complex cpx01452 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01362_c1 complex cpx01728 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05329_c1 complex cpx52441 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05329_c1 complex cpx52442 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03174_c1 complex cpx00115 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05161_c1 complex tcpx00675 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00549_c1 complex tcpx00461 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03951_c1 complex cpx01707 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12746_c1 complex tcpx00826 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05418_c1 complex cpx00147 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00506_c1 complex cpx00145 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10060_c1 complex cpx00366 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02933_c1 complex cpx00382 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00727_c1 complex cpx00924 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00813_c1 complex tcpx00362 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03852_c1 complex cpx00183 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12638_c1 complex cpx00045 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12638_c1 complex cpx00046 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12638_c1 complex cpx00048 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12638_c1 complex cpx00051 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01354_c1 complex cpx01664 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02268_c1 complex cpx00041 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02268_c1 complex cpx00042 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn09105_c1 complex cpx00172 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01445_c1 complex cpx00863 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01445_c1 complex cpx01447 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01445_c1 complex cpx52456 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05248_c1 complex cpx00498 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00612_c1 complex cpx00870 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08766_c1 complex tcpx00865 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05539_c1 complex tcpx00649 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08045_c1 complex cpx52492 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08841_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08841_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05461_c1 complex cpx00147 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05461_c1 complex tcpx00010 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03586_c1 complex cpx52572 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02159_c1 complex cpx01212 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10222_c1 complex cpx00209 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00269_c1 complex cpx00381 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10263_c1 complex cpx00210 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02791_c1 complex cpx00827 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05466_c1 complex cpx01115 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08814_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08814_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00004_c1 complex tcpx00218 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00917_c1 complex cpx52641 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00917_c1 complex cpx52642 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08078_c1 complex cpx52430 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08845_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08845_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00395_c1 complex cpx00841 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn07981_c1 complex cpx52441 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00375_c1 complex cpx00302 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00300_c1 complex cpx01303 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01925_c1 complex cpx00892 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08792_c1 complex cpx00878 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08792_c1 complex tcpx00044 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02798_c1 complex cpx52571 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00999_c1 complex cpx00193 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05174_c1 complex tcpx00679 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08799_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08799_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05585_c1 complex tcpx00595 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00433_c1 complex cpx52629 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00433_c1 complex cpx52630 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00433_c1 complex tcpx00365 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00433_c1 complex tcpx00366 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05957_c1 complex cpx00168 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05957_c1 complex tcpx00353 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05335_c1 complex cpx52441 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05335_c1 complex cpx52442 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03023_c1 complex tcpx00360 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00537_c1 complex cpx00970 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03419_c1 complex cpx00115 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05890_c1 complex cpx01186 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn10256_c1 complex cpx00181 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00679_c1 complex cpx01706 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00758_c1 complex cpx00346 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02103_c1 complex cpx00812 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00638_c1 complex cpx00686 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn09111_c1 complex cpx00210 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01746_c1 complex cpx00784 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn06078_c1 complex cpx00040 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00471_c1 complex cpx01047 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05595_c1 complex tcpx00727 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05348_c1 complex cpx00244 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05348_c1 complex cpx00289 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05348_c1 complex tcpx00137 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn04056_c1 complex tcpx00083 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05435_c1 complex cpx00149 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03245_c1 complex cpx00206 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03245_c1 complex tcpx00032 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn11946_c1 complex cpx00620 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn00907_c1 complex tcpx00829 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05458_c1 complex cpx00117 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08300_c1 complex cpx00181 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01644_c1 complex cpx52646 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn06887_c1 complex tcpx00774 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08297_c1 complex cpx00181 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02911_c1 complex cpx00206 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02911_c1 complex tcpx00032 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn01280_c1 complex cpx01012 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05450_c1 complex cpx00149 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12847_c1 complex cpx00045 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12847_c1 complex cpx00046 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12847_c1 complex cpx00048 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn12847_c1 complex cpx00051 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05410_c1 complex cpx00147 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05443_c1 complex cpx00149 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn09114_c1 complex cpx00210 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05535_c1 complex tcpx00574 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn09188_c1 complex tcpx00943 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn03974_c1 complex cpx01224 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08822_c1 complex cpx00034 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn08822_c1 complex cpx00035 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn05030_c1 complex cpx00708 not defined in model.groups
# WARNING:cobrakbase.core.kbasefba.fbamodel_reaction:IGNORE: reaction rxn02782_c1 complex cpx00946 not defined in model.groups
# ...
# The ID rxn05593_c2 is changed with  to create the final ID rxn05593_c2
# The ID rxn08295_c2 is changed with  to create the final ID rxn08295_c2
# The ID rxn05638_c2 is changed with  to create the final ID rxn05638_c2
# The ID rxn07475_c2 is changed with  to create the final ID rxn07475_c2
# The ID rxn02914_c2 is changed with  to create the final ID rxn02914_c2
# The ID rxn01603_c2 is changed with  to create the final ID rxn01603_c2
# The ID rxn00686_c2 is changed with  to create the final ID rxn00686_c2
# The ID rxn09112_c2 is changed with  to create the final ID rxn09112_c2
# The ID rxn00157_c2 is changed with  to create the final ID rxn00157_c2
# The ID rxn09232_c2 is changed with  to create the final ID rxn09232_c2
# The ID rxn06075_c2 is changed with  to create the final ID rxn06075_c2
# The ID rxn00689_c2 is changed with  to create the final ID rxn00689_c2
# The ID rxn08129_c2 is changed with  to create the final ID rxn08129_c2
# The ID rxn01286_c2 is changed with  to create the final ID rxn01286_c2
# The ID rxn05289_c2 is changed with  to create the final ID rxn05289_c2
# The ID rxn01973_c2 is changed with  to create the final ID rxn01973_c2
# The ID rxn00117_c2 is changed with  to create the final ID rxn00117_c2
# The ID rxn05343_c2 is changed with  to create the final ID rxn05343_c2
# The ID rxn01520_c2 is changed with  to create the final ID rxn01520_c2
# The ID rxn03395_c2 is changed with  to create the final ID rxn03395_c2
# The ID rxn00330_c2 is changed with  to create the final ID rxn00330_c2
# The ID rxn05736_c2 is changed with  to create the final ID rxn05736_c2
# The ID rxn03445_c2 is changed with  to create the final ID rxn03445_c2
# The ID rxn08122_c2 is changed with  to create the final ID rxn08122_c2
# The ID rxn02246_c2 is changed with  to create the final ID rxn02246_c2
# The ID rxn11663_c2 is changed with  to create the final ID rxn11663_c2
# The ID rxn01226_c2 is changed with  to create the final ID rxn01226_c2
# The ID rxn00493_c2 is changed with  to create the final ID rxn00493_c2
# The ID rxn08298_c2 is changed with  to create the final ID rxn08298_c2
# The ID rxn01834_c2 is changed with  to create the final ID rxn01834_c2
# The ID rxn00293_c2 is changed with  to create the final ID rxn00293_c2
# The ID rxn05491_c2 is changed with  to create the final ID rxn05491_c2
# The ID rxn10196_c2 is changed with  to create the final ID rxn10196_c2
# The ID rxn00701_c2 is changed with  to create the final ID rxn00701_c2
# The ID rxn00367_c2 is changed with  to create the final ID rxn00367_c2
# The ID rxn14011_c2 is changed with  to create the final ID rxn14011_c2
# The ID rxn00839_c2 is changed with  to create the final ID rxn00839_c2
# The ID rxn21857_c2 is changed with  to create the final ID rxn21857_c2
# The ID rxn16573_c2 is changed with  to create the final ID rxn16573_c2
# The ID rxn14159_c2 is changed with  to create the final ID rxn14159_c2
# The ID rxn45996_c2 is changed with  to create the final ID rxn45996_c2
# The ID rxn16839_c2 is changed with  to create the final ID rxn16839_c2
# The ID rxn27289_c2 is changed with  to create the final ID rxn27289_c2
# The ID rxn42230_c2 is changed with  to create the final ID rxn42230_c2
# The ID rxn07455_c2 is changed with  to create the final ID rxn07455_c2
# The ID rxn47768_c2 is changed with  to create the final ID rxn47768_c2
# The ID rxn21861_c2 is changed with  to create the final ID rxn21861_c2
# The ID rxn25839_c2 is changed with  to create the final ID rxn25839_c2
# The ID rxn23042_c2 is changed with  to create the final ID rxn23042_c2
# The ID rxn15021_c2 is changed with  to create the final ID rxn15021_c2
# The ID rxn00154_c2 is changed with  to create the final ID rxn00154_c2
# The ID rxn01084_c2 is changed with  to create the final ID rxn01084_c2
# The ID rxn15395_c2 is changed with  to create the final ID rxn15395_c2
# The ID rxn14178_c2 is changed with  to create the final ID rxn14178_c2
# The ID rxn15972_c2 is changed with  to create the final ID rxn15972_c2
# The ID rxn14146_c2 is changed with  to create the final ID rxn14146_c2
# The ID rxn26456_c2 is changed with  to create the final ID rxn26456_c2
# The ID rxn15699_c2 is changed with  to create the final ID rxn15699_c2
# The ID rxn15249_c2 is changed with  to create the final ID rxn15249_c2
# The ID rxn15466_c2 is changed with  to create the final ID rxn15466_c2
# The ID rxn14427_c2 is changed with  to create the final ID rxn14427_c2
# The ID rxn14422_c2 is changed with  to create the final ID rxn14422_c2
# The ID rxn14419_c2 is changed with  to create the final ID rxn14419_c2
# The ID rxn10415_c2 is changed with  to create the final ID rxn10415_c2
# The ID rxn08676_c2 is changed with  to create the final ID rxn08676_c2
# The ID rxn08070_c2 is changed with  to create the final ID rxn08070_c2
# The ID rxn08098_c2 is changed with  to create the final ID rxn08098_c2
# The ID rxn08158_c2 is changed with  to create the final ID rxn08158_c2
# The ID rxn08048_c2 is changed with  to create the final ID rxn08048_c2
# The ID rxn08213_c2 is changed with  to create the final ID rxn08213_c2
# The ID rxn29120_c2 is changed with  to create the final ID rxn29120_c2
# The ID rxn08475_c2 is changed with  to create the final ID rxn08475_c2
# The ID rxn09295_c2 is changed with  to create the final ID rxn09295_c2
# The ID rxn08608_c2 is changed with  to create the final ID rxn08608_c2
# The ID rxn08762_c2 is changed with  to create the final ID rxn08762_c2
# The ID rxn08192_c2 is changed with  to create the final ID rxn08192_c2
# The ID rxn08173_c2 is changed with  to create the final ID rxn08173_c2
# The ID rxn08869_c2 is changed with  to create the final ID rxn08869_c2
# The ID rxn08734_c2 is changed with  to create the final ID rxn08734_c2
# The ID rxn09003_c2 is changed with  to create the final ID rxn09003_c2
# The ID rxn14418_c2 is changed with  to create the final ID rxn14418_c2
# The ID rxn14421_c2 is changed with  to create the final ID rxn14421_c2
# The ID rxn14420_c2 is changed with  to create the final ID rxn14420_c2
# The ID rxn09001_c2 is changed with  to create the final ID rxn09001_c2
# The ID rxn26307_c2 is changed with  to create the final ID rxn26307_c2
# The ID rxn23043_c2 is changed with  to create the final ID rxn23043_c2
# The ID rxn41896_c2 is changed with  to create the final ID rxn41896_c2
# The ID rxn21729_c2 is changed with  to create the final ID rxn21729_c2
# The ID rxn23045_c2 is changed with  to create the final ID rxn23045_c2
# The ID rxn39434_c2 is changed with  to create the final ID rxn39434_c2
# The ID rxn21862_c2 is changed with  to create the final ID rxn21862_c2
# The ID rxn39452_c2 is changed with  to create the final ID rxn39452_c2
# The ID rxn16611_c2 is changed with  to create the final ID rxn16611_c2
# The ID rxn16583_c2 is changed with  to create the final ID rxn16583_c2
# The ID rxn16615_c2 is changed with  to create the final ID rxn16615_c2
# The ID rxn44539_c2 is changed with  to create the final ID rxn44539_c2
# The ID rxn15337_c2 is changed with  to create the final ID rxn15337_c2
# The ID rxn10506_c2 is changed with  to create the final ID rxn10506_c2
# The ID rxn15338_c2 is changed with  to create the final ID rxn15338_c2
# The ID rxn41452_c2 is changed with  to create the final ID rxn41452_c2
# The ID rxn21864_c2 is changed with  to create the final ID rxn21864_c2
# The ID rxn39451_c2 is changed with  to create the final ID rxn39451_c2
# The ID rxn21858_c2 is changed with  to create the final ID rxn21858_c2
# The ID rxn46694_c2 is changed with  to create the final ID rxn46694_c2
# The ID rxn40439_c2 is changed with  to create the final ID rxn40439_c2
# The ID rxn24830_c2 is changed with  to create the final ID rxn24830_c2
# The ID rxn16574_c2 is changed with  to create the final ID rxn16574_c2
# The ID rxn24134_c2 is changed with  to create the final ID rxn24134_c2
# The ID rxn26021_c2 is changed with  to create the final ID rxn26021_c2
# The ID rxn41683_c2 is changed with  to create the final ID rxn41683_c2
# The ID rxn07436_c2 is changed with  to create the final ID rxn07436_c2
# The ID rxn16826_c2 is changed with  to create the final ID rxn16826_c2
# The ID rxn16794_c2 is changed with  to create the final ID rxn16794_c2
# The ID rxn16776_c2 is changed with  to create the final ID rxn16776_c2
# The ID rxn16829_c2 is changed with  to create the final ID rxn16829_c2
# The ID rxn28338_c2 is changed with  to create the final ID rxn28338_c2
# The ID rxn14169_c2 is changed with  to create the final ID rxn14169_c2
# The ID rxn03396_c2 is changed with  to create the final ID rxn03396_c2
# The ID rxn15293_c2 is changed with  to create the final ID rxn15293_c2
# The ID rxn15121_c2 is changed with  to create the final ID rxn15121_c2
# The ID rxn13741_c2 is changed with  to create the final ID rxn13741_c2
# The ID rxn08153_c2 is changed with  to create the final ID rxn08153_c2
# The ID rxn08233_c2 is changed with  to create the final ID rxn08233_c2
# The ID rxn42976_c2 is changed with  to create the final ID rxn42976_c2
# The ID rxn17275_c2 is changed with  to create the final ID rxn17275_c2
# The ID rxn09037_c2 is changed with  to create the final ID rxn09037_c2
# The ID rxn43581_c2 is changed with  to create the final ID rxn43581_c2
# The ID rxn08995_c2 is changed with  to create the final ID rxn08995_c2
# The ID rxn09193_c2 is changed with  to create the final ID rxn09193_c2
# The ID rxn09165_c2 is changed with  to create the final ID rxn09165_c2
# The ID rxn08241_c2 is changed with  to create the final ID rxn08241_c2
# The ID rxn08879_c2 is changed with  to create the final ID rxn08879_c2
# The ID rxn08742_c2 is changed with  to create the final ID rxn08742_c2
# The ID rxn08234_c2 is changed with  to create the final ID rxn08234_c2
# The ID rxn08578_c2 is changed with  to create the final ID rxn08578_c2
# The ID rxn08854_c2 is changed with  to create the final ID rxn08854_c2
# The ID rxn09182_c2 is changed with  to create the final ID rxn09182_c2
# The ID rxn08715_c2 is changed with  to create the final ID rxn08715_c2
# The ID rxn26457_c2 is changed with  to create the final ID rxn26457_c2
# The ID rxn26459_c2 is changed with  to create the final ID rxn26459_c2
# The ID rxn23336_c2 is changed with  to create the final ID rxn23336_c2
# The ID rxn08508_c2 is changed with  to create the final ID rxn08508_c2
# The ID rxn23850_c2 is changed with  to create the final ID rxn23850_c2
# The ID rxn40368_c2 is changed with  to create the final ID rxn40368_c2
# The ID rxn15230_c2 is changed with  to create the final ID rxn15230_c2
# The ID rxn20583_c2 is changed with  to create the final ID rxn20583_c2
# The ID rxn15467_c2 is changed with  to create the final ID rxn15467_c2
# The ID rxn27318_c2 is changed with  to create the final ID rxn27318_c2
# The ID rxn16824_c2 is changed with  to create the final ID rxn16824_c2
# The ID rxn39964_c2 is changed with  to create the final ID rxn39964_c2
# The ID rxn16806_c2 is changed with  to create the final ID rxn16806_c2
# The ID rxn14061_c2 is changed with  to create the final ID rxn14061_c2
# The ID rxn13957_c2 is changed with  to create the final ID rxn13957_c2
# The ID rxn09171_c2 is changed with  to create the final ID rxn09171_c2
# The ID rxn09304_c2 is changed with  to create the final ID rxn09304_c2
# The ID rxn08722_c2 is changed with  to create the final ID rxn08722_c2
# The ID rxn08062_c2 is changed with  to create the final ID rxn08062_c2
# The ID rxn26439_c2 is changed with  to create the final ID rxn26439_c2
# The ID rxn21863_c2 is changed with  to create the final ID rxn21863_c2
# The ID rxn40037_c2 is changed with  to create the final ID rxn40037_c2
# The ID rxn21859_c2 is changed with  to create the final ID rxn21859_c2
# The ID rxn20643_c2 is changed with  to create the final ID rxn20643_c2
# The ID rxn17731_c2 is changed with  to create the final ID rxn17731_c2
# The ID rxn21860_c2 is changed with  to create the final ID rxn21860_c2
# The ID rxn16149_c2 is changed with  to create the final ID rxn16149_c2
# The ID rxn05120_c2 is changed with  to create the final ID rxn05120_c2
# The ID rxn16828_c2 is changed with  to create the final ID rxn16828_c2
# The ID rxn15750_c2 is changed with  to create the final ID rxn15750_c2
# The ID rxn43837_c2 is changed with  to create the final ID rxn43837_c2
# The ID rxn26127_c2 is changed with  to create the final ID rxn26127_c2
# The ID sul00010_c2 is changed with  to create the final ID sul00010_c2
# The ID rxn19704_c2 is changed with  to create the final ID rxn19704_c2
# The ID rxn45692_c2 is changed with  to create the final ID rxn45692_c2
# The ID rxn10470_c2 is changed with  to create the final ID rxn10470_c2
# The ID rxn05469_c2 is changed with  to create the final ID rxn05469_c2
# The ID rxn05064_c2 is changed with  to create the final ID rxn05064_c2
# The ID rxn02374_c2 is changed with  to create the final ID rxn02374_c2
# The ID rxn05730_c2 is changed with  to create the final ID rxn05730_c2
# The ID rxn04457_c2 is changed with  to create the final ID rxn04457_c2
# The ID rxn05129_c2 is changed with  to create the final ID rxn05129_c2
# The ID rxn02916_c2 is changed with  to create the final ID rxn02916_c2
# The ID rxn03012_c2 is changed with  to create the final ID rxn03012_c2
# The ID rxn10471_c2 is changed with  to create the final ID rxn10471_c2
# The ID rxn04132_c2 is changed with  to create the final ID rxn04132_c2
# The ID rxn01208_c2 is changed with  to create the final ID rxn01208_c2
# The ID rxn02989_c2 is changed with  to create the final ID rxn02989_c2
# The ID rxn04791_c2 is changed with  to create the final ID rxn04791_c2
# The ID rxn00064_c2 is changed with  to create the final ID rxn00064_c2
# The ID rxn05468_c2 is changed with  to create the final ID rxn05468_c2
# The ID rxn04133_c2 is changed with  to create the final ID rxn04133_c2
# The ID rxn10570_c2 is changed with  to create the final ID rxn10570_c2
# The ID rxn05467_c2 is changed with  to create the final ID rxn05467_c2
# The ID rxn24718_c2 is changed with  to create the final ID rxn24718_c2
# The ID rxn23589_c2 is changed with  to create the final ID rxn23589_c2
# The ID rxn08502_e0 is changed with  to create the final ID rxn08502_e0
# The ID rxn08428_c2 is changed with  to create the final ID rxn08428_c2
# The ID rxn08032_c2 is changed with  to create the final ID rxn08032_c2
# The ID rxn09008_c2 is changed with  to create the final ID rxn09008_c2
# The ID rxn08691_c2 is changed with  to create the final ID rxn08691_c2
# The ID rxn08350_c2 is changed with  to create the final ID rxn08350_c2
# The ID rxn07919_c2 is changed with  to create the final ID rxn07919_c2
# The ID rxn08689_c2 is changed with  to create the final ID rxn08689_c2
# The ID rxn09260_c2 is changed with  to create the final ID rxn09260_c2
# The ID rxn09330_c2 is changed with  to create the final ID rxn09330_c2
# The ID rxn00062_c2 is changed with  to create the final ID rxn00062_c2
# The ID rxn08333_c2 is changed with  to create the final ID rxn08333_c2
# The ID rxn02898_c2 is changed with  to create the final ID rxn02898_c2
# The ID rxn05459_c2 is changed with  to create the final ID rxn05459_c2
# The ID rxn05481_c2 is changed with  to create the final ID rxn05481_c2
# The ID rxn11703_c2 is changed with  to create the final ID rxn11703_c2
# The ID rxn03537_c2 is changed with  to create the final ID rxn03537_c2
# The ID rxn00333_c2 is changed with  to create the final ID rxn00333_c2
# The ID rxn03150_c2 is changed with  to create the final ID rxn03150_c2
# The ID rxn03538_c2 is changed with  to create the final ID rxn03538_c2
# The ID rxn00599_c2 is changed with  to create the final ID rxn00599_c2
# The ID rxn11702_c2 is changed with  to create the final ID rxn11702_c2
# The ID rxn02897_c2 is changed with  to create the final ID rxn02897_c2
# The ID rxn00141_c2 is changed with  to create the final ID rxn00141_c2
# The ID rxn02831_c2 is changed with  to create the final ID rxn02831_c2
# The ID rxn02832_c2 is changed with  to create the final ID rxn02832_c2
# The ID rxn00127_c2 is changed with  to create the final ID rxn00127_c2
# The ID SK_cpd02701_c2 is changed with  to create the final ID SK_cpd02701_c2
# The ID SK_cpd03091_c2 is changed with  to create the final ID SK_cpd03091_c2
# The ID SK_cpd11416_c2 is changed with  to create the final ID SK_cpd11416_c2
# The ID SK_cpd15302_c2 is changed with  to create the final ID SK_cpd15302_c2

# %%
print(example_pairwise.reactions.bio1.reaction)
sol = example_pairwise.optimize()
print({"bio2": sol.fluxes["bio2"], "bio3": sol.fluxes["bio3"]})
# Out:
# 0.5 cpd11416_c1 + 0.5 cpd11416_c2 --> cpd11416_c0
# {'bio2': 58.34675810455965, 'bio3': 58.346758104559655}

# %%
from pandas import set_option
set_option("display.max_columns", None)
display(fluxes, mets)
# Out:
#                                               model1  \
# 0  Streptomyces_mirabilis_YR139_2582581314.fna.RA...
# 1  Streptomyces_mirabilis_YR139_2582581314.fna.RA...
# 2  Streptomyces_mirabilis_YR139_2582581314.fna.RA...
# 3       Pseudomonas_sp._GM17_2511231006.fna.RAST.mdl
# 4       Pseudomonas_sp._GM17_2511231006.fna.RAST.mdl
# 5          Pantoea_sp._YR343_2511231025.fna.RAST.mdl
#
#                                          model2            media  \
# 0  Pseudomonas_sp._GM17_2511231006.fna.RAST.mdl  R2A_edition_003
# 1     Pantoea_sp._YR343_2511231025.fna.RAST.mdl  R2A_edition_003
# 2   Rhizobium_sp._CF142_2510917030.fna.RAST.mdl  R2A_edition_003
# 3     Pantoea_sp._YR343_2511231025.fna.RAST.mdl  R2A_edition_003
# 4   Rhizobium_sp._CF142_2510917030.fna.RAST.mdl  R2A_edition_003
# 5   Rhizobium_sp._CF142_2510917030.fna.RAST.mdl  R2A_edition_003
#
#   model1 growth model2 growth community growth coculture growth model1  \
# 0        57.961         41.63            99.79               65.151455
# 1        57.961        74.195           105.65               66.463934
# 2        57.961        25.758            72.17               52.907653
# 3         41.63        74.195           112.32               77.685656
# 4         41.63        25.758           53.532               58.346758
# 5        74.195        25.758            69.84               58.346758
#
#   coculture growth model2       MRO_model1       MRO_model2 CIP  \
# 0               65.151455  56.250% (18/32)  40.000% (18/45)  18
# 1               66.463934  65.625% (21/32)  52.500% (21/40)  17
# 2               52.907653  56.250% (18/32)  58.065% (18/31)  15
# 3               77.685656  62.222% (28/45)  70.000% (28/40)  18
# 4               58.346758  44.444% (20/45)  64.516% (20/31)  16
# 5               58.346758  50.000% (20/40)  64.516% (20/31)  15
#
#   MIP_model1 (costless) MIP_model2 (costless) BSS_model1 BSS_model2 PC_comm  \
# 0                 2 (0)                 1 (0)    77.778%    46.875%  1.3084
# 1                 5 (1)                 3 (0)      70.0%      50.0%  1.0058
# 2                 5 (2)                 1 (0)    51.613%      50.0%  1.2639
# 3                 7 (0)                 4 (0)      65.0%    71.111%  1.3414
# 4                 2 (1)                 1 (0)    51.613%    73.333%  1.7317
# 5                 2 (1)                 1 (0)    51.613%      62.5%  1.1675
#
#   PC_model1 PC_model2           BIT     GYD1     GYD2
# 0    1.1241     1.565     mutualism  0.28176   0.3923
# 1    1.1467    0.8958    parasitism  0.28008   0.2188
# 2   0.91281     2.054  commensalism   0.5556   1.2502
# 3    1.8661    1.0471  commensalism  0.78226  0.43891
# 4    1.4016    2.2652     mutualism  0.38126  0.61619
# 5    0.7864    2.2652    parasitism  0.65283   1.8805
# [{'MRO metabolites': ['cpd00063',
#    'cpd00058',
#    'cpd10515',
#    'cpd00205',
#    'cpd00028',
#    'cpd00034',
#    'cpd00209',
#    'cpd00080',
#    'cpd00099',
#    'cpd10516',
#    'cpd00051',
#    'cpd00149',
#    'cpd00254',
#    'cpd00030',
#    'cpd00048',
#    'cpd00264',
#    'cpd00007',
#    'cpd00307'],
#   'CIP metabolites': ['cpd00122',
#    'cpd00067',
#    'cpd00029',
#    'cpd01981',
#    'cpd00309',
#    'cpd00013',
#    'cpd00073',
#    'cpd00130',
#    'cpd00011',
#    'cpd00020',
#    'cpd00001',
#    'cpd00117',
#    'cpd15378',
#    'cpd00024',
#    'cpd00129',
#    'cpd00047',
#    'cpd00221',
#    'cpd00064'],
#   'MIP model1 metabolites': ['cpd00100', 'cpd00048'],
#   'MIP model2 metabolites': ['cpd00071'],
#   'BSS model1 metabolites': {'cpd00001',
#    'cpd00002',
#    'cpd00003',
#    'cpd00004',
#    'cpd00005',
#    'cpd00006',
#    'cpd00007',
#    'cpd00008',
#    'cpd00009',
#    'cpd00010',
#    'cpd00011',
#    'cpd00012',
#    'cpd00013',
#    'cpd00014',
#    'cpd00015',
#    'cpd00016',
#    'cpd00017',
#    'cpd00018',
#    'cpd00019',
#    'cpd00020',
#    'cpd00022',
#    'cpd00023',
#    'cpd00024',
#    'cpd00025',
#    'cpd00026',
#    'cpd00027',
#    'cpd00028',
#    'cpd00029',
#    'cpd00031',
#    'cpd00032',
#    'cpd00033',
#    'cpd00035',
#    'cpd00036',
#    'cpd00037',
#    'cpd00038',
#    'cpd00039',
#    'cpd00040',
#    'cpd00041',
#    'cpd00042',
#    'cpd00043',
#    'cpd00044',
#    'cpd00045',
#    'cpd00046',
#    'cpd00047',
#    'cpd00048',
#    'cpd00050',
#    'cpd00051',
#    'cpd00052',
#    'cpd00053',
#    'cpd00054',
#    'cpd00055',
#    'cpd00056',
#    'cpd00060',
#    'cpd00061',
#    'cpd00062',
#    'cpd00064',
#    'cpd00065',
#    'cpd00066',
#    'cpd00067',
#    'cpd00068',
#    'cpd00069',
#    'cpd00070',
#    'cpd00071',
#    'cpd00072',
#    'cpd00073',
#    'cpd00075',
#    'cpd00076',
#    'cpd00078',
#    'cpd00079',
#    'cpd00080',
#    'cpd00081',
#    'cpd00082',
#    'cpd00084',
#    'cpd00085',
#    'cpd00086',
#    'cpd00087',
#    'cpd00089',
#    'cpd00090',
#    'cpd00091',
#    'cpd00092',
#    'cpd00093',
#    'cpd00094',
#    'cpd00095',
#    'cpd00096',
#    'cpd00098',
#    'cpd00100',
#    'cpd00101',
#    'cpd00102',
#    'cpd00103',
#    'cpd00104',
#    'cpd00105',
#    'cpd00106',
#    'cpd00107',
#    'cpd00108',
#    'cpd00109',
#    'cpd00110',
#    'cpd00111',
#    'cpd00113',
#    'cpd00114',
#    'cpd00115',
#    'cpd00116',
#    'cpd00117',
#    'cpd00118',
#    'cpd00119',
#    'cpd00121',
#    'cpd00122',
#    'cpd00123',
#    'cpd00125',
#    'cpd00126',
#    'cpd00128',
#    'cpd00129',
#    'cpd00132',
#    'cpd00133',
#    'cpd00134',
#    'cpd00135',
#    'cpd00136',
#    'cpd00138',
#    'cpd00139',
#    'cpd00142',
#    'cpd00143',
#    'cpd00144',
#    'cpd00146',
#    'cpd00147',
#    'cpd00151',
#    'cpd00153',
#    'cpd00157',
#    'cpd00159',
#    'cpd00161',
#    'cpd00162',
#    'cpd00164',
#    'cpd00166',
#    'cpd00169',
#    'cpd00170',
#    'cpd00171',
#    'cpd00176',
#    'cpd00177',
#    'cpd00179',
#    'cpd00180',
#    'cpd00182',
#    'cpd00184',
#    'cpd00186',
#    'cpd00190',
#    'cpd00191',
#    'cpd00193',
#    'cpd00196',
#    'cpd00197',
#    'cpd00198',
#    'cpd00199',
#    'cpd00200',
#    'cpd00201',
#    'cpd00202',
#    'cpd00203',
#    'cpd00204',
#    'cpd00207',
#    'cpd00209',
#    'cpd00213',
#    'cpd00214',
#    'cpd00215',
#    'cpd00216',
#    'cpd00218',
#    'cpd00219',
#    'cpd00220',
#    'cpd00221',
#    'cpd00222',
#    'cpd00223',
#    'cpd00224',
#    'cpd00226',
#    'cpd00229',
#    'cpd00231',
#    'cpd00233',
#    'cpd00235',
#    'cpd00236',
#    'cpd00239',
#    'cpd00241',
#    'cpd00242',
#    'cpd00246',
#    'cpd00247',
#    'cpd00249',
#    'cpd00259',
#    'cpd00262',
#    'cpd00264',
#    'cpd00274',
#    'cpd00277',
#    'cpd00279',
#    'cpd00281',
#    'cpd00283',
#    'cpd00284',
#    'cpd00286',
#    'cpd00287',
#    'cpd00288',
#    'cpd00289',
#    'cpd00290',
#    'cpd00293',
#    'cpd00295',
#    'cpd00296',
#    'cpd00297',
#    'cpd00298',
#    'cpd00299',
#    'cpd00300',
#    'cpd00307',
#    'cpd00309',
#    'cpd00311',
#    'cpd00318',
#    'cpd00320',
#    'cpd00321',
#    'cpd00324',
#    'cpd00327',
#    'cpd00330',
#    'cpd00331',
#    'cpd00334',
#    'cpd00339',
#    'cpd00340',
#    'cpd00343',
#    'cpd00344',
#    'cpd00346',
#    'cpd00347',
#    'cpd00348',
#    'cpd00349',
#    'cpd00350',
#    'cpd00355',
#    'cpd00356',
#    'cpd00357',
#    'cpd00358',
#    'cpd00359',
#    'cpd00362',
#    'cpd00367',
#    'cpd00374',
#    'cpd00379',
#    'cpd00382',
#    'cpd00387',
#    'cpd00388',
#    'cpd00390',
#    'cpd00393',
#    'cpd00397',
#    'cpd00412',
#    'cpd00415',
#    'cpd00421',
#    'cpd00424',
#    'cpd00425',
#    'cpd00426',
#    'cpd00428',
#    'cpd00430',
#    'cpd00438',
#    'cpd00443',
#    'cpd00446',
#    'cpd00447',
#    'cpd00448',
#    'cpd00452',
#    'cpd00461',
#    'cpd00465',
#    'cpd00475',
#    'cpd00477',
#    'cpd00482',
#    'cpd00483',
#    'cpd00484',
#    'cpd00485',
#    'cpd00491',
#    'cpd00492',
#    'cpd00497',
#    'cpd00498',
#    'cpd00504',
#    'cpd00506',
#    'cpd00508',
#    'cpd00509',
#    'cpd00516',
#    'cpd00518',
#    'cpd00519',
#    'cpd00520',
#    'cpd00521',
#    'cpd00522',
#    'cpd00523',
#    'cpd00524',
#    'cpd00525',
#    'cpd00533',
#    'cpd00540',
#    'cpd00579',
#    'cpd00581',
#    'cpd00585',
#    'cpd00588',
#    'cpd00626',
#    'cpd00630',
#    'cpd00638',
#    'cpd00641',
#    'cpd00644',
#    'cpd00646',
#    'cpd00649',
#    'cpd00650',
#    'cpd00654',
#    'cpd00655',
#    'cpd00658',
#    'cpd00683',
#    'cpd00689',
#    'cpd00699',
#    'cpd00703',
#    'cpd00706',
#    'cpd00712',
#    'cpd00719',
#    'cpd00724',
#    'cpd00729',
#    'cpd00731',
#    'cpd00755',
#    'cpd00757',
#    'cpd00759',
#    'cpd00762',
#    'cpd00763',
#    'cpd00764',
#    'cpd00770',
#    'cpd00774',
#    'cpd00780',
#    'cpd00781',
#    'cpd00793',
#    'cpd00794',
#    'cpd00800',
#    'cpd00802',
#    'cpd00808',
#    'cpd00809',
#    'cpd00817',
#    'cpd00831',
#    'cpd00834',
#    'cpd00836',
#    'cpd00840',
#    'cpd00843',
#    'cpd00856',
#    'cpd00858',
#    'cpd00860',
#    'cpd00861',
#    'cpd00863',
#    'cpd00868',
#    'cpd00873',
#    'cpd00875',
#    'cpd00876',
#    'cpd00890',
#    'cpd00906',
#    'cpd00908',
#    'cpd00911',
#    'cpd00918',
#    'cpd00922',
#    'cpd00930',
#    'cpd00932',
#    'cpd00946',
#    'cpd00954',
#    'cpd00956',
#    'cpd00957',
#    'cpd00977',
#    'cpd00978',
#    'cpd00982',
#    'cpd00988',
#    'cpd00989',
#    'cpd01011',
#    'cpd01017',
#    'cpd01046',
#    'cpd01067',
#    'cpd01080',
#    'cpd01092',
#    'cpd01150',
#    'cpd01155',
#    'cpd01211',
#    'cpd01217',
#    'cpd01221',
#    'cpd01242',
#    'cpd01262',
#    'cpd01294',
#    'cpd01311',
#    'cpd01324',
#    'cpd01329',
#    'cpd01399',
#    'cpd01401',
#    'cpd01476',
#    'cpd01504',
#    'cpd01507',
#    'cpd01553',
#    'cpd01562',
#    'cpd01567',
#    'cpd01620',
#    'cpd01679',
#    'cpd01693',
#    'cpd01695',
#    'cpd01700',
#    'cpd01710',
#    'cpd01716',
#    'cpd01720',
#    'cpd01741',
#    'cpd01749',
#    'cpd01777',
#    'cpd01831',
#    'cpd01844',
#    'cpd01914',
#    'cpd01919',
#    'cpd01966',
#    'cpd01977',
#    'cpd01981',
#    'cpd01997',
#    'cpd02021',
#    'cpd02030',
#    'cpd02060',
#    'cpd02068',
#    'cpd02069',
#    'cpd02074',
#    'cpd02083',
#    'cpd02090',
#    'cpd02095',
#    'cpd02096',
#    'cpd02097',
#    'cpd02098',
#    'cpd02120',
#    'cpd02124',
#    'cpd02125',
#    'cpd02140',
#    'cpd02152',
#    'cpd02168',
#    'cpd02172',
#    'cpd02175',
#    'cpd02183',
#    'cpd02187',
#    'cpd02197',
#    'cpd02201',
#    'cpd02210',
#    'cpd02211',
#    'cpd02227',
#    'cpd02229',
#    'cpd02234',
#    'cpd02235',
#    'cpd02255',
#    'cpd02258',
#    'cpd02295',
#    'cpd02333',
#    'cpd02345',
#    'cpd02357',
#    'cpd02361',
#    'cpd02371',
#    'cpd02375',
#    'cpd02394',
#    'cpd02431',
#    'cpd02441',
#    'cpd02456',
#    'cpd02465',
#    'cpd02484',
#    'cpd02498',
#    'cpd02501',
#    'cpd02506',
#    'cpd02507',
#    'cpd02522',
#    'cpd02546',
#    'cpd02547',
#    'cpd02552',
#    'cpd02566',
#    'cpd02569',
#    'cpd02574',
#    'cpd02590',
#    'cpd02591',
#    'cpd02605',
#    'cpd02611',
#    'cpd02612',
#    'cpd02626',
#    'cpd02631',
#    'cpd02654',
#    'cpd02656',
#    'cpd02663',
#    'cpd02666',
#    'cpd02678',
#    'cpd02679',
#    'cpd02692',
#    'cpd02700',
#    'cpd02701',
#    'cpd02711',
#    'cpd02721',
#    'cpd02724',
#    'cpd02731',
#    'cpd02740',
#    'cpd02746',
#    'cpd02775',
#    'cpd02791',
#    'cpd02820',
#    'cpd02826',
#    'cpd02851',
#    'cpd02857',
#    'cpd02861',
#    'cpd02862',
#    'cpd02882',
#    'cpd02884',
#    'cpd02886',
#    'cpd02893',
#    'cpd02894',
#    'cpd02904',
#    'cpd02920',
#    'cpd02921',
#    'cpd02930',
#    'cpd02948',
#    'cpd02961',
#    'cpd02964',
#    'cpd02968',
#    'cpd02978',
#    'cpd02979',
#    'cpd02991',
#    'cpd02993',
#    'cpd03002',
#    'cpd03034',
#    'cpd03091',
#    'cpd03114',
#    'cpd03117',
#    'cpd03119',
#    'cpd03121',
#    'cpd03123',
#    'cpd03124',
#    'cpd03125',
#    'cpd03126',
#    'cpd03127',
#    'cpd03129',
#    'cpd03130',
#    'cpd03161',
#    'cpd03171',
#    'cpd03187',
#    'cpd03189',
#    'cpd03198',
#    'cpd03205',
#    'cpd03211',
#    'cpd03279',
#    'cpd03285',
#    'cpd03326',
#    'cpd03362',
#    'cpd03392',
#    'cpd03407',
#    'cpd03413',
#    'cpd03416',
#    'cpd03421',
#    'cpd03422',
#    'cpd03423',
#    'cpd03426',
#    'cpd03431',
#    'cpd03443',
#    'cpd03444',
#    'cpd03445',
#    'cpd03446',
#    'cpd03447',
#    'cpd03448',
#    'cpd03449',
#    'cpd03451',
#    'cpd03453',
#    'cpd03454',
#    'cpd03470',
#    'cpd03471',
#    'cpd03480',
#    'cpd03488',
#    'cpd03491',
#    'cpd03492',
#    'cpd03494',
#    'cpd03495',
#    'cpd03496',
#    'cpd03517',
#    'cpd03518',
#    'cpd03519',
#    'cpd03520',
#    'cpd03524',
#    'cpd03559',
#    'cpd03572',
#    'cpd03584',
#    'cpd03585',
#    'cpd03586',
#    'cpd03593',
#    'cpd03606',
#    'cpd03608',
#    'cpd03641',
#    'cpd03646',
#    'cpd03666',
#    'cpd03697',
#    'cpd03698',
#    'cpd03701',
#    'cpd03704',
#    'cpd03726',
#    'cpd03727',
#    'cpd03752',
#    'cpd03761',
#    'cpd03813',
#    'cpd03847',
#    'cpd03861',
#    'cpd03862',
#    'cpd03914',
#    'cpd03916',
#    'cpd03917',
#    'cpd03918',
#    'cpd03919',
#    'cpd03920',
#    'cpd03969',
#    'cpd04073',
#    'cpd04122',
#    'cpd04242',
#    'cpd06227',
#    'cpd07924',
#    'cpd08210',
#    'cpd08287',
#    'cpd08288',
#    'cpd08289',
#    'cpd08301',
#    'cpd08353',
#    'cpd08368',
#    'cpd08369',
#    'cpd08370',
#    'cpd08371',
#    'cpd08375',
#    'cpd08405',
#    'cpd08615',
#    'cpd09027',
#    'cpd09253',
#    'cpd09254',
#    'cpd09843',
#    'cpd09879',
#    'cpd10162',
#    'cpd10515',
#    'cpd10516',
#    'cpd11206',
#    'cpd11225',
#    'cpd11310',
#    'cpd11312',
#    'cpd11313',
#    'cpd11416',
#    'cpd11420',
#    'cpd11421',
#    'cpd11432',
#    'cpd11434',
#    'cpd11435',
#    'cpd11437',
#    'cpd11439',
#    'cpd11441',
#    'cpd11459',
#    'cpd11461',
#    'cpd11462',
#    'cpd11463',
#    'cpd11465',
#    'cpd11467',
#    'cpd11468',
#    'cpd11469',
#    'cpd11471',
#    'cpd11473',
#    'cpd11474',
#    'cpd11475',
#    'cpd11477',
#    'cpd11484',
#    'cpd11485',
#    'cpd11486',
#    'cpd11487',
#    'cpd11488',
#    'cpd11489',
#    'cpd11490',
#    'cpd11491',
#    'cpd11492',
#    'cpd11493',
#    'cpd11494',
#    'cpd11497',
#    'cpd11499',
#    'cpd11501',
#    'cpd11503',
#    'cpd11505',
#    'cpd11507',
#    'cpd11509',
#    'cpd11511',
#    'cpd11513',
#    'cpd11515',
#    'cpd11517',
#    'cpd11519',
#    'cpd11522',
#    'cpd11524',
#    'cpd11526',
#    'cpd11528',
#    'cpd11530',
#    'cpd11532',
#    'cpd11534',
#    'cpd11536',
#    'cpd11538',
#    'cpd11540',
#    'cpd11542',
#    'cpd11544',
#    'cpd11547',
#    'cpd11549',
#    'cpd11551',
#    'cpd11553',
#    'cpd11555',
#    'cpd11557',
#    'cpd11559',
#    'cpd11561',
#    'cpd11563',
#    'cpd11565',
#    'cpd11567',
#    'cpd11569',
#    'cpd11570',
#    'cpd11571',
#    'cpd11573',
#    'cpd11609',
#    'cpd11620',
#    'cpd11621',
#    'cpd11830',
#    'cpd11959',
#    'cpd12005',
#    'cpd12225',
#    'cpd12370',
#    'cpd12543',
#    'cpd12689',
#    'cpd12848',
#    'cpd14507',
#    'cpd14545',
#    'cpd14548',
#    'cpd14589',
#    'cpd14698',
#    'cpd14699',
#    'cpd14700',
#    'cpd14702',
#    'cpd14703',
#    'cpd14960',
#    'cpd14961',
#    'cpd15170',
#    'cpd15237',
#    'cpd15238',
#    'cpd15239',
#    'cpd15268',
#    'cpd15269',
#    'cpd15274',
#    'cpd15294',
#    'cpd15298',
#    'cpd15302',
#    'cpd15325',
#    'cpd15327',
#    'cpd15330',
#    'cpd15339',
#    'cpd15346',
#    'cpd15352',
#    'cpd15353',
#    'cpd15378',
#    'cpd15386',
#    'cpd15387',
#    'cpd15391',
#    'cpd15396',
#    'cpd15399',
#    'cpd15401',
#    'cpd15417',
#    'cpd15418',
#    'cpd15419',
#    'cpd15420',
#    'cpd15421',
#    'cpd15422',
#    'cpd15423',
#    'cpd15494',
#    'cpd15495',
#    'cpd15499',
#    'cpd15500',
#    'cpd15505',
#    'cpd15506',
#    'cpd15507',
#    'cpd15522',
#    'cpd15526',
#    'cpd15527',
#    'cpd15528',
#    'cpd15529',
#    'cpd15530',
#    'cpd15531',
#    'cpd15532',
#    'cpd15533',
#    'cpd15534',
#    'cpd15540',
#    'cpd15542',
#    'cpd15543',
#    'cpd15544',
#    'cpd15545',
#    'cpd15546',
#    'cpd15547',
#    'cpd15548',
#    'cpd15552',
#    'cpd15553',
#    'cpd15554',
#    'cpd15555',
#    'cpd15556',
#    'cpd15557',
#    'cpd15558',
#    'cpd15560',
#    'cpd15561',
#    'cpd15611',
#    'cpd15665',
#    'cpd15666',
#    'cpd15683',
#    'cpd15684',
#    'cpd15685',
#    'cpd15686',
#    'cpd15687',
#    'cpd15688',
#    'cpd15689',
#    'cpd15690',
#    'cpd15691',
#    'cpd15692',
#    'cpd15693',
#    'cpd15694',
#    'cpd15695',
#    'cpd15696',
#    'cpd15697',
#    'cpd15698',
#    'cpd15699',
#    'cpd15700',
#    'cpd15716',
#    'cpd15717',
#    'cpd15718',
#    'cpd15719',
#    'cpd15720',
#    'cpd15721',
#    'cpd15793',
#    'cpd15807',
#    'cpd15839',
#    'cpd15889',
#    'cpd17150',
#    'cpd17270',
#    'cpd17278',
#    'cpd17281',
#    'cpd17282',
#    'cpd17535',
#    'cpd18076',
#    'cpd19001',
#    'cpd19006',
#    'cpd19008',
#    'cpd19019',
#    'cpd19020',
#    'cpd19047',
#    'cpd19503',
#    'cpd19505',
#    'cpd19587',
#    'cpd20412',
#    'cpd20413',
#    'cpd20940',
#    'cpd21037',
#    'cpd21088',
#    'cpd21090',
#    'cpd21167',
#    'cpd21288',
#    'cpd21301',
#    'cpd21464',
#    'cpd21479',
#    'cpd21488',
#    'cpd22022',
#    'cpd22027',
#    'cpd22065',
#    'cpd22312',
#    'cpd23005',
#    'cpd23834',
#    'cpd25679',
#    'cpd25981',
#    'cpd27180',
#    'cpd27484',
#    'cpd27713',
#    'cpd27735',
#    'cpd27744',
#    'cpd27758',
#    'cpd28060',
#    'cpd28083',
#    'cpd28253',
#    'cpd28297',
#    'cpd30750',
#    'cpd31338',
#    'cpd31434',
#    'cpd32452',
#    'cpd33647',
#    'cpd33930',
#    'cpd35194',
#    'cpd37010'},
#   'BSS model2 metabolites': {'cpd00001',
#    'cpd00002',
#    'cpd00003',
#    'cpd00004',
#    'cpd00005',
#    'cpd00006',
#    'cpd00007',
#    'cpd00008',
#    'cpd00009',
#    'cpd00010',
#    'cpd00011',
#    'cpd00012',
#    'cpd00013',
#    'cpd00014',
#    'cpd00015',
#    'cpd00016',
#    'cpd00017',
#    'cpd00018',
#    'cpd00019',
#    'cpd00020',
#    'cpd00022',
#    'cpd00023',
#    'cpd00024',
#    'cpd00025',
#    'cpd00026',
#    'cpd00027',
#    'cpd00028',
#    'cpd00029',
#    'cpd00031',
#    'cpd00032',
#    'cpd00033',
#    'cpd00035',
#    'cpd00036',
#    'cpd00037',
#    'cpd00038',
#    'cpd00039',
#    'cpd00040',
#    'cpd00041',
#    'cpd00042',
#    'cpd00043',
#    'cpd00044',
#    'cpd00045',
#    'cpd00046',
#    'cpd00047',
#    'cpd00048',
#    'cpd00050',
#    'cpd00051',
#    'cpd00052',
#    'cpd00053',
#    'cpd00054',
#    'cpd00055',
#    'cpd00056',
#    'cpd00060',
#    'cpd00061',
#    'cpd00062',
#    'cpd00064',
#    'cpd00065',
#    'cpd00066',
#    'cpd00067',
#    'cpd00068',
#    'cpd00069',
#    'cpd00070',
#    'cpd00071',
#    'cpd00072',
#    'cpd00073',
#    'cpd00075',
#    'cpd00077',
#    'cpd00078',
#    'cpd00079',
#    'cpd00080',
#    'cpd00081',
#    'cpd00082',
#    'cpd00083',
#    'cpd00084',
#    'cpd00085',
#    'cpd00086',
#    'cpd00087',
#    'cpd00089',
#    'cpd00091',
#    'cpd00092',
#    'cpd00093',
#    'cpd00094',
#    'cpd00095',
#    'cpd00096',
#    'cpd00098',
#    'cpd00100',
#    'cpd00101',
#    'cpd00102',
#    'cpd00103',
#    'cpd00104',
#    'cpd00105',
#    'cpd00106',
#    'cpd00107',
#    'cpd00109',
#    'cpd00110',
#    'cpd00111',
#    'cpd00113',
#    'cpd00114',
#    'cpd00115',
#    'cpd00116',
#    'cpd00117',
#    'cpd00118',
#    'cpd00119',
#    'cpd00121',
#    'cpd00122',
#    'cpd00123',
#    'cpd00125',
#    'cpd00126',
#    'cpd00128',
#    'cpd00129',
#    'cpd00132',
#    'cpd00134',
#    'cpd00135',
#    'cpd00139',
#    'cpd00142',
#    'cpd00143',
#    'cpd00144',
#    'cpd00145',
#    'cpd00146',
#    'cpd00147',
#    'cpd00151',
#    'cpd00152',
#    'cpd00153',
#    'cpd00155',
#    'cpd00157',
#    'cpd00159',
#    'cpd00161',
#    'cpd00162',
#    'cpd00166',
#    'cpd00169',
#    'cpd00170',
#    'cpd00171',
#    'cpd00177',
#    'cpd00180',
#    'cpd00182',
#    'cpd00184',
#    'cpd00186',
#    'cpd00190',
#    'cpd00193',
#    'cpd00196',
#    'cpd00197',
#    'cpd00198',
#    'cpd00199',
#    'cpd00200',
#    'cpd00201',
#    'cpd00202',
#    'cpd00203',
#    'cpd00204',
#    'cpd00207',
#    'cpd00209',
#    'cpd00213',
#    'cpd00214',
#    'cpd00216',
#    'cpd00218',
#    'cpd00219',
#    'cpd00220',
#    'cpd00221',
#    'cpd00222',
#    'cpd00223',
#    'cpd00226',
#    'cpd00229',
#    'cpd00231',
#    'cpd00235',
#    'cpd00236',
#    'cpd00239',
#    'cpd00241',
#    'cpd00246',
#    'cpd00247',
#    'cpd00249',
#    'cpd00264',
#    'cpd00274',
#    'cpd00275',
#    'cpd00277',
#    'cpd00279',
#    'cpd00281',
#    'cpd00283',
#    'cpd00284',
#    'cpd00286',
#    'cpd00287',
#    'cpd00288',
#    'cpd00290',
#    'cpd00291',
#    'cpd00293',
#    'cpd00295',
#    'cpd00296',
#    'cpd00297',
#    'cpd00298',
#    'cpd00299',
#    'cpd00300',
#    'cpd00307',
#    'cpd00309',
#    'cpd00311',
#    'cpd00320',
#    'cpd00327',
#    'cpd00330',
#    'cpd00331',
#    'cpd00338',
#    'cpd00339',
#    'cpd00340',
#    'cpd00341',
#    'cpd00343',
#    'cpd00344',
#    'cpd00346',
#    'cpd00347',
#    'cpd00350',
#    'cpd00352',
#    'cpd00355',
#    'cpd00356',
#    'cpd00357',
#    'cpd00358',
#    'cpd00359',
#    'cpd00362',
#    'cpd00367',
#    'cpd00390',
#    'cpd00393',
#    'cpd00412',
#    'cpd00421',
#    'cpd00424',
#    'cpd00426',
#    'cpd00428',
#    'cpd00430',
#    'cpd00438',
#    'cpd00443',
#    'cpd00446',
#    'cpd00447',
#    'cpd00448',
#    'cpd00452',
#    'cpd00461',
#    'cpd00465',
#    'cpd00477',
#    'cpd00478',
#    'cpd00480',
#    'cpd00482',
#    'cpd00483',
#    'cpd00485',
#    'cpd00491',
#    'cpd00492',
#    'cpd00493',
#    'cpd00497',
#    'cpd00498',
#    'cpd00504',
#    'cpd00506',
#    'cpd00508',
#    'cpd00509',
#    'cpd00515',
#    'cpd00516',
#    'cpd00521',
#    'cpd00522',
#    'cpd00523',
#    'cpd00524',
#    'cpd00525',
#    'cpd00533',
#    'cpd00540',
#    'cpd00581',
#    'cpd00585',
#    'cpd00626',
#    'cpd00630',
#    'cpd00638',
#    'cpd00641',
#    'cpd00644',
#    'cpd00646',
#    'cpd00650',
#    'cpd00654',
#    'cpd00655',
#    'cpd00658',
#    'cpd00659',
#    'cpd00683',
#    'cpd00689',
#    'cpd00699',
#    'cpd00703',
#    'cpd00706',
#    'cpd00712',
#    'cpd00719',
#    'cpd00722',
#    'cpd00724',
#    'cpd00729',
#    'cpd00731',
#    'cpd00755',
#    'cpd00757',
#    'cpd00759',
#    'cpd00762',
#    'cpd00763',
#    'cpd00764',
#    'cpd00770',
#    'cpd00774',
#    'cpd00780',
#    'cpd00781',
#    'cpd00790',
#    'cpd00791',
#    'cpd00793',
#    'cpd00794',
#    'cpd00800',
#    'cpd00802',
#    'cpd00809',
#    'cpd00817',
#    'cpd00834',
#    'cpd00836',
#    'cpd00843',
#    'cpd00854',
#    'cpd00856',
#    'cpd00860',
#    'cpd00863',
#    'cpd00868',
#    'cpd00869',
#    'cpd00873',
#    'cpd00875',
#    'cpd00876',
#    'cpd00890',
#    'cpd00896',
#    'cpd00897',
#    'cpd00900',
#    'cpd00906',
#    'cpd00908',
#    'cpd00911',
#    'cpd00918',
#    'cpd00922',
#    'cpd00930',
#    'cpd00931',
#    'cpd00932',
#    'cpd00945',
#    'cpd00946',
#    'cpd00954',
#    'cpd00956',
#    'cpd00957',
#    'cpd00977',
#    'cpd00978',
#    'cpd00982',
#    'cpd00986',
#    'cpd01011',
#    'cpd01017',
#    'cpd01046',
#    'cpd01080',
#    'cpd01092',
#    'cpd01101',
#    'cpd01150',
#    'cpd01155',
#    'cpd01211',
#    'cpd01217',
#    'cpd01242',
#    'cpd01262',
#    'cpd01294',
#    'cpd01311',
#    'cpd01324',
#    'cpd01329',
#    'cpd01399',
#    'cpd01504',
#    'cpd01507',
#    'cpd01567',
#    'cpd01620',
#    'cpd01630',
#    'cpd01679',
#    'cpd01693',
#    'cpd01695',
#    'cpd01710',
#    'cpd01715',
#    'cpd01716',
#    'cpd01720',
#    'cpd01741',
#    'cpd01749',
#    'cpd01777',
#    'cpd01831',
#    'cpd01844',
#    'cpd01914',
#    'cpd01919',
#    'cpd01966',
#    'cpd01977',
#    'cpd01997',
#    'cpd02016',
#    'cpd02021',
#    'cpd02024',
#    'cpd02030',
#    'cpd02060',
#    'cpd02068',
#    'cpd02069',
#    'cpd02074',
#    'cpd02083',
#    'cpd02089',
#    'cpd02090',
#    'cpd02096',
#    'cpd02097',
#    'cpd02103',
#    'cpd02120',
#    'cpd02124',
#    'cpd02125',
#    'cpd02140',
#    'cpd02147',
#    'cpd02152',
#    'cpd02160',
#    'cpd02175',
#    'cpd02197',
#    'cpd02201',
#    'cpd02210',
#    'cpd02211',
#    'cpd02229',
#    'cpd02234',
#    'cpd02235',
#    'cpd02255',
#    'cpd02258',
#    'cpd02295',
#    'cpd02333',
#    'cpd02345',
#    'cpd02360',
#    'cpd02375',
#    'cpd02394',
#    'cpd02419',
#    'cpd02431',
#    'cpd02439',
#    'cpd02465',
#    'cpd02498',
#    'cpd02501',
#    'cpd02506',
#    'cpd02507',
#    'cpd02546',
#    'cpd02547',
#    'cpd02552',
#    'cpd02555',
#    'cpd02566',
#    'cpd02569',
#    'cpd02572',
#    'cpd02574',
#    'cpd02590',
#    'cpd02597',
#    'cpd02605',
#    'cpd02611',
#    'cpd02626',
#    'cpd02631',
#    'cpd02654',
#    'cpd02656',
#    'cpd02666',
#    'cpd02678',
#    'cpd02692',
#    'cpd02700',
#    'cpd02701',
#    'cpd02711',
#    'cpd02720',
#    'cpd02721',
#    'cpd02724',
#    'cpd02731',
#    'cpd02740',
#    'cpd02746',
#    'cpd02775',
#    'cpd02791',
#    'cpd02820',
#    'cpd02826',
#    'cpd02828',
#    'cpd02851',
#    'cpd02857',
#    'cpd02862',
#    'cpd02882',
#    'cpd02884',
#    'cpd02886',
#    'cpd02893',
#    'cpd02894',
#    'cpd02904',
#    'cpd02920',
#    'cpd02921',
#    'cpd02930',
#    'cpd02948',
#    'cpd02961',
#    'cpd02964',
#    'cpd02968',
#    'cpd02978',
#    'cpd02979',
#    'cpd02991',
#    'cpd02993',
#    'cpd03002',
#    'cpd03034',
#    'cpd03063',
#    'cpd03078',
#    'cpd03091',
#    'cpd03114',
#    'cpd03117',
#    'cpd03119',
#    'cpd03121',
#    'cpd03123',
#    'cpd03124',
#    'cpd03125',
#    'cpd03126',
#    'cpd03127',
#    'cpd03129',
#    'cpd03130',
#    'cpd03171',
#    'cpd03187',
#    'cpd03189',
#    'cpd03279',
#    'cpd03285',
#    'cpd03326',
#    'cpd03392',
#    'cpd03407',
#    'cpd03416',
#    'cpd03420',
#    'cpd03422',
#    'cpd03423',
#    'cpd03426',
#    'cpd03443',
#    'cpd03444',
#    'cpd03445',
#    'cpd03446',
#    'cpd03447',
#    'cpd03451',
#    'cpd03453',
#    'cpd03456',
#    'cpd03470',
#    'cpd03471',
#    'cpd03480',
#    'cpd03488',
#    'cpd03491',
#    'cpd03492',
#    'cpd03494',
#    'cpd03495',
#    'cpd03496',
#    'cpd03517',
#    'cpd03518',
#    'cpd03519',
#    'cpd03520',
#    'cpd03524',
#    'cpd03525',
#    'cpd03526',
#    'cpd03559',
#    'cpd03572',
#    'cpd03584',
#    'cpd03585',
#    'cpd03586',
#    'cpd03593',
#    'cpd03606',
#    'cpd03608',
#    'cpd03646',
#    'cpd03666',
#    'cpd03697',
#    'cpd03698',
#    'cpd03704',
#    'cpd03708',
#    'cpd03726',
#    'cpd03752',
#    'cpd03761',
#    'cpd03762',
#    'cpd03813',
#    'cpd03830',
#    'cpd03832',
#    'cpd03833',
#    'cpd03834',
#    'cpd03835',
#    'cpd03839',
#    'cpd03847',
#    'cpd03897',
#    'cpd03914',
#    'cpd03915',
#    'cpd03916',
#    'cpd03917',
#    'cpd03918',
#    'cpd03919',
#    'cpd03920',
#    'cpd04122',
#    'cpd04242',
#    'cpd04539',
#    'cpd04920',
#    'cpd06227',
#    'cpd07924',
#    'cpd08210',
#    'cpd08211',
#    'cpd08287',
#    'cpd08288',
#    'cpd08289',
#    'cpd08301',
#    'cpd08316',
#    'cpd08372',
#    'cpd08449',
#    'cpd08615',
#    'cpd09027',
#    'cpd09254',
#    'cpd09255',
#    'cpd09843',
#    'cpd09844',
#    'cpd09879',
#    'cpd10162',
#    'cpd10515',
#    'cpd10516',
#    'cpd11206',
#    'cpd11225',
#    'cpd11255',
#    'cpd11295',
#    'cpd11296',
#    'cpd11310',
#    'cpd11312',
#    'cpd11313',
#    'cpd11341',
#    'cpd11416',
#    'cpd11420',
#    'cpd11421',
#    'cpd11432',
#    'cpd11434',
#    'cpd11435',
#    'cpd11437',
#    'cpd11439',
#    'cpd11441',
#    'cpd11461',
#    'cpd11462',
#    'cpd11463',
#    'cpd11465',
#    'cpd11467',
#    'cpd11468',
#    'cpd11469',
#    'cpd11470',
#    'cpd11471',
#    'cpd11473',
#    'cpd11474',
#    'cpd11475',
#    'cpd11477',
#    'cpd11484',
#    'cpd11485',
#    'cpd11486',
#    'cpd11487',
#    'cpd11488',
#    'cpd11489',
#    'cpd11490',
#    'cpd11491',
#    'cpd11492',
#    'cpd11493',
#    'cpd11494',
#    'cpd11497',
#    'cpd11498',
#    'cpd11501',
#    'cpd11502',
#    'cpd11505',
#    'cpd11506',
#    'cpd11509',
#    'cpd11510',
#    'cpd11513',
#    'cpd11514',
#    'cpd11517',
#    'cpd11518',
#    'cpd11522',
#    'cpd11523',
#    'cpd11526',
#    'cpd11527',
#    'cpd11530',
#    'cpd11531',
#    'cpd11534',
#    'cpd11535',
#    'cpd11538',
#    'cpd11539',
#    'cpd11542',
#    'cpd11543',
#    'cpd11547',
#    'cpd11551',
#    'cpd11555',
#    'cpd11559',
#    'cpd11563',
#    'cpd11567',
#    'cpd11570',
#    'cpd11571',
#    'cpd11572',
#    'cpd11620',
#    'cpd11621',
#    'cpd11830',
#    'cpd11959',
#    'cpd12005',
#    'cpd12139',
#    'cpd12225',
#    'cpd12370',
#    'cpd12489',
#    'cpd12543',
#    'cpd12689',
#    'cpd12712',
#    'cpd12848',
#    'cpd14507',
#    'cpd14545',
#    'cpd14548',
#    'cpd14698',
#    'cpd14699',
#    'cpd14700',
#    'cpd14702',
#    'cpd14703',
#    'cpd14718',
#    'cpd14720',
#    'cpd14874',
#    'cpd14875',
#    'cpd14876',
#    'cpd14955',
#    'cpd15170',
#    'cpd15237',
#    'cpd15238',
#    'cpd15239',
#    'cpd15269',
#    'cpd15274',
#    'cpd15277',
#    'cpd15294',
#    'cpd15298',
#    'cpd15302',
#    'cpd15325',
#    'cpd15326',
#    'cpd15327',
#    'cpd15328',
#    'cpd15329',
#    'cpd15330',
#    'cpd15331',
#    'cpd15339',
#    'cpd15346',
#    'cpd15352',
#    'cpd15353',
#    'cpd15358',
#    'cpd15359',
#    'cpd15360',
#    'cpd15361',
#    'cpd15378',
#    'cpd15386',
#    'cpd15387',
#    'cpd15391',
#    'cpd15396',
#    'cpd15399',
#    'cpd15401',
#    'cpd15417',
#    'cpd15418',
#    'cpd15419',
#    'cpd15420',
#    'cpd15421',
#    'cpd15422',
#    'cpd15423',
#    'cpd15441',
#    'cpd15479',
#    'cpd15480',
#    'cpd15484',
#    'cpd15485',
#    'cpd15492',
#    'cpd15494',
#    'cpd15495',
#    'cpd15499',
#    'cpd15500',
#    'cpd15504',
#    'cpd15505',
#    'cpd15506',
#    'cpd15507',
#    'cpd15510',
#    'cpd15521',
#    'cpd15522',
#    'cpd15523',
#    'cpd15524',
#    'cpd15525',
#    'cpd15526',
#    'cpd15527',
#    'cpd15528',
#    'cpd15529',
#    'cpd15530',
#    'cpd15531',
#    'cpd15532',
#    'cpd15533',
#    'cpd15534',
#    'cpd15535',
#    'cpd15536',
#    'cpd15537',
#    'cpd15538',
#    'cpd15539',
#    'cpd15540',
#    'cpd15541',
#    'cpd15542',
#    'cpd15543',
#    'cpd15544',
#    'cpd15545',
#    'cpd15546',
#    'cpd15547',
#    'cpd15548',
#    'cpd15549',
#    'cpd15552',
#    'cpd15553',
#    'cpd15554',
#    'cpd15555',
#    'cpd15556',
#    'cpd15557',
#    'cpd15558',
#    'cpd15560',
#    'cpd15561',
#    'cpd15568',
#    'cpd15569',
#    'cpd15570',
#    'cpd15571',
#    'cpd15572',
#    'cpd15579',
#    'cpd15665',
#    'cpd15666',
#    'cpd15667',
#    'cpd15668',
#    'cpd15669',
#    'cpd15671',
#    'cpd15672',
#    'cpd15673',
#    'cpd15674',
#    'cpd15675',
#    'cpd15676',
#    'cpd15677',
#    'cpd15678',
#    'cpd15679',
#    'cpd15680',
#    'cpd15681',
#    'cpd15682',
#    'cpd15683',
#    'cpd15684',
#    'cpd15685',
#    'cpd15686',
#    'cpd15687',
#    'cpd15688',
#    'cpd15689',
#    'cpd15690',
#    'cpd15691',
#    'cpd15692',
#    'cpd15693',
#    'cpd15694',
#    'cpd15695',
#    'cpd15696',
#    'cpd15697',
#    'cpd15698',
#    'cpd15699',
#    'cpd15700',
#    'cpd15716',
#    'cpd15717',
#    'cpd15718',
#    'cpd15719',
#    'cpd15720',
#    'cpd15721',
#    'cpd15722',
#    'cpd15723',
#    'cpd15724',
#    'cpd15725',
#    'cpd15726',
#    'cpd15727',
#    'cpd15764',
#    'cpd15765',
#    'cpd15766',
#    'cpd15769',
#    'cpd15770',
#    'cpd15771',
#    'cpd15772',
#    'cpd15793',
#    'cpd17564',
#    'cpd17565',
#    'cpd17566',
#    'cpd17567',
#    'cpd17568',
#    'cpd18057',
#    'cpd18076',
#    'cpd18078',
#    'cpd18082',
#    'cpd19006',
#    'cpd19019',
#    'cpd19020',
#    'cpd19047',
#    'cpd19245',
#    'cpd19442',
#    'cpd19503',
#    'cpd19505',
#    'cpd20940',
#    'cpd21032',
#    'cpd21087',
#    'cpd21088',
#    'cpd21124',
#    'cpd21167',
#    'cpd21288',
#    'cpd21301',
#    'cpd21472',
#    'cpd21479',
#    'cpd21481',
#    'cpd21488',
#    'cpd22022',
#    'cpd22027',
#    'cpd22028',
#    'cpd22065',
#    'cpd23005',
#    'cpd26672',
#    'cpd26760',
#    'cpd26761',
#    'cpd27020',
#    'cpd27021',
#    'cpd27180',
#    'cpd27484',
#    'cpd27713',
#    'cpd27735',
#    'cpd27744',
#    'cpd27758',
#    'cpd28060',
#    'cpd28083',
#    'cpd28205',
#    'cpd28253',
#    'cpd28259',
#    'cpd30750',
#    'cpd32452',
#    'cpd32550',
#    'cpd33647',
#    'cpd33930',
#    'cpd35194',
#    'cpd36635',
#    'cpd37010'}},
#  {'MRO metabolites': ['cpd10515',
#    'cpd00034',
#    'cpd00080',
#    'cpd00132',
#    'cpd00254',
#    'cpd15604',
#    'cpd00264',
#    'cpd00205',
#    'cpd00051',
#    'cpd00149',
#    'cpd00030',
#    'cpd00048',
#    'cpd00118',
#    'cpd10516',
#    'cpd00324',
#    'cpd00063',
#    'cpd00058',
#    'cpd00028',
#    'cpd00099',
#    'cpd00007',
#    'cpd00307'],
#   'CIP metabolites': ['cpd00122',
#    'cpd00067',
#    'cpd00029',
#    'cpd01981',
#    'cpd00971',
#    'cpd00013',
#    'cpd00130',
#    'cpd00011',
#    'cpd00020',
#    'cpd00001',
#    'cpd00036',
#    'cpd00117',
#    'cpd00024',
#    'cpd00092',
#    'cpd00129',
#    'cpd00047',
#    'cpd00064'],
#   'MIP model1 metabolites': ['cpd00067',
#    'cpd00071',
#    'cpd00239',
#    'cpd00324',
#    'cpd00024'],
#   'MIP model2 metabolites': ['cpd00239', 'cpd01080', 'cpd00100'],
#   'BSS model1 metabolites': {'cpd00001',
#    'cpd00002',
#    'cpd00003',
#    'cpd00004',
#    'cpd00005',
#    'cpd00006',
#    'cpd00007',
#    'cpd00008',
#    'cpd00009',
#    'cpd00010',
#    'cpd00011',
#    'cpd00012',
#    'cpd00013',
#    'cpd00014',
#    'cpd00015',
#    'cpd00016',
#    'cpd00017',
#    'cpd00018',
#    'cpd00019',
#    'cpd00020',
#    'cpd00022',
#    'cpd00023',
#    'cpd00024',
#    'cpd00025',
#    'cpd00026',
#    'cpd00027',
#    'cpd00028',
#    'cpd00029',
#    'cpd00031',
#    'cpd00032',
#    'cpd00033',
#    'cpd00035',
#    'cpd00036',
#    'cpd00037',
#    'cpd00038',
#    'cpd00039',
#    'cpd00040',
#    'cpd00041',
#    'cpd00042',
#    'cpd00043',
#    'cpd00044',
#    'cpd00045',
#    'cpd00046',
#    'cpd00047',
#    'cpd00048',
#    'cpd00050',
#    'cpd00051',
#    'cpd00052',
#    'cpd00053',
#    'cpd00054',
#    'cpd00055',
#    'cpd00056',
#    'cpd00060',
#    'cpd00061',
#    'cpd00062',
#    'cpd00064',
#    'cpd00065',
#    'cpd00066',
#    'cpd00067',
#    'cpd00068',
#    'cpd00069',
#    'cpd00070',
#    'cpd00071',
#    'cpd00072',
#    'cpd00073',
#    'cpd00075',
#    'cpd00076',
#    'cpd00078',
#    'cpd00079',
#    'cpd00080',
#    'cpd00081',
#    'cpd00082',
#    'cpd00084',
#    'cpd00085',
#    'cpd00086',
#    'cpd00087',
#    'cpd00089',
#    'cpd00090',
#    'cpd00091',
#    'cpd00092',
#    'cpd00093',
#    'cpd00094',
#    'cpd00095',
#    'cpd00096',
#    'cpd00098',
#    'cpd00100',
#    'cpd00101',
#    'cpd00102',
#    'cpd00103',
#    'cpd00104',
#    'cpd00105',
#    'cpd00106',
#    'cpd00107',
#    'cpd00108',
#    'cpd00109',
#    'cpd00110',
#    'cpd00111',
#    'cpd00113',
#    'cpd00114',
#    'cpd00115',
#    'cpd00116',
#    'cpd00117',
#    'cpd00118',
#    'cpd00119',
#    'cpd00121',
#    'cpd00122',
#    'cpd00123',
#    'cpd00125',
#    'cpd00126',
#    'cpd00128',
#    'cpd00129',
#    'cpd00132',
#    'cpd00133',
#    'cpd00134',
#    'cpd00135',
#    'cpd00136',
#    'cpd00138',
#    'cpd00139',
#    'cpd00142',
#    'cpd00143',
#    'cpd00144',
#    'cpd00146',
#    'cpd00147',
#    'cpd00151',
#    'cpd00153',
#    'cpd00157',
#    'cpd00159',
#    'cpd00161',
#    'cpd00162',
#    'cpd00164',
#    'cpd00166',
#    'cpd00169',
#    'cpd00170',
#    'cpd00171',
#    'cpd00176',
#    'cpd00177',
#    'cpd00179',
#    'cpd00180',
#    'cpd00182',
#    'cpd00184',
#    'cpd00186',
#    'cpd00190',
#    'cpd00191',
#    'cpd00193',
#    'cpd00196',
#    'cpd00197',
#    'cpd00198',
#    'cpd00199',
#    'cpd00200',
#    'cpd00201',
#    'cpd00202',
#    'cpd00203',
#    'cpd00204',
#    'cpd00207',
#    'cpd00209',
#    'cpd00213',
#    'cpd00214',
#    'cpd00215',
#    'cpd00216',
#    'cpd00218',
#    'cpd00219',
#    'cpd00220',
#    'cpd00221',
#    'cpd00222',
#    'cpd00223',
#    'cpd00224',
#    'cpd00226',
#    'cpd00229',
#    'cpd00231',
#    'cpd00233',
#    'cpd00235',
#    'cpd00236',
#    'cpd00239',
#    'cpd00241',
#    'cpd00242',
#    'cpd00246',
#    'cpd00247',
#    'cpd00249',
#    'cpd00259',
#    'cpd00262',
#    'cpd00264',
#    'cpd00274',
#    'cpd00277',
#    'cpd00279',
#    'cpd00281',
#    'cpd00283',
#    'cpd00284',
#    'cpd00286',
#    'cpd00287',
#    'cpd00288',
#    'cpd00289',
#    'cpd00290',
#    'cpd00293',
#    'cpd00295',
#    'cpd00296',
#    'cpd00297',
#    'cpd00298',
#    'cpd00299',
#    'cpd00300',
#    'cpd00307',
#    'cpd00309',
#    'cpd00311',
#    'cpd00318',
#    'cpd00320',
#    'cpd00321',
#    'cpd00324',
#    'cpd00327',
#    'cpd00330',
#    'cpd00331',
#    'cpd00334',
#    'cpd00339',
#    'cpd00340',
#    'cpd00343',
#    'cpd00344',
#    'cpd00346',
#    'cpd00347',
#    'cpd00348',
#    'cpd00349',
#    'cpd00350',
#    'cpd00355',
#    'cpd00356',
#    'cpd00357',
#    'cpd00358',
#    'cpd00359',
#    'cpd00362',
#    'cpd00367',
#    'cpd00374',
#    'cpd00379',
#    'cpd00382',
#    'cpd00387',
#    'cpd00388',
#    'cpd00390',
#    'cpd00393',
#    'cpd00397',
#    'cpd00412',
#    'cpd00415',
#    'cpd00421',
#    'cpd00424',
#    'cpd00425',
#    'cpd00426',
#    'cpd00428',
#    'cpd00430',
#    'cpd00438',
#    'cpd00443',
#    'cpd00446',
#    'cpd00447',
#    'cpd00448',
#    'cpd00452',
#    'cpd00461',
#    'cpd00465',
#    'cpd00475',
#    'cpd00477',
#    'cpd00482',
#    'cpd00483',
#    'cpd00484',
#    'cpd00485',
#    'cpd00491',
#    'cpd00492',
#    'cpd00497',
#    'cpd00498',
#    'cpd00504',
#    'cpd00506',
#    'cpd00508',
#    'cpd00509',
#    'cpd00516',
#    'cpd00518',
#    'cpd00519',
#    'cpd00520',
#    'cpd00521',
#    'cpd00522',
#    'cpd00523',
#    'cpd00524',
#    'cpd00525',
#    'cpd00533',
#    'cpd00540',
#    'cpd00579',
#    'cpd00581',
#    'cpd00585',
#    'cpd00588',
#    'cpd00626',
#    'cpd00630',
#    'cpd00638',
#    'cpd00641',
#    'cpd00644',
#    'cpd00646',
#    'cpd00649',
#    'cpd00650',
#    'cpd00654',
#    'cpd00655',
#    'cpd00658',
#    'cpd00683',
#    'cpd00689',
#    'cpd00699',
#    'cpd00703',
#    'cpd00706',
#    'cpd00712',
#    'cpd00719',
#    'cpd00724',
#    'cpd00729',
#    'cpd00731',
#    'cpd00755',
#    'cpd00757',
#    'cpd00759',
#    'cpd00762',
#    'cpd00763',
#    'cpd00764',
#    'cpd00770',
#    'cpd00774',
#    'cpd00780',
#    'cpd00781',
#    'cpd00793',
#    'cpd00794',
#    'cpd00800',
#    'cpd00802',
#    'cpd00808',
#    'cpd00809',
#    'cpd00817',
#    'cpd00831',
#    'cpd00834',
#    'cpd00836',
#    'cpd00840',
#    'cpd00843',
#    'cpd00856',
#    'cpd00858',
#    'cpd00860',
#    'cpd00861',
#    'cpd00863',
#    'cpd00868',
#    'cpd00873',
#    'cpd00875',
#    'cpd00876',
#    'cpd00890',
#    'cpd00906',
#    'cpd00908',
#    'cpd00911',
#    'cpd00918',
#    'cpd00922',
#    'cpd00930',
#    'cpd00932',
#    'cpd00946',
#    'cpd00954',
#    'cpd00956',
#    'cpd00957',
#    'cpd00977',
#    'cpd00978',
#    'cpd00982',
#    'cpd00988',
#    'cpd00989',
#    'cpd01011',
#    'cpd01017',
#    'cpd01046',
#    'cpd01067',
#    'cpd01080',
#    'cpd01092',
#    'cpd01150',
#    'cpd01155',
#    'cpd01211',
#    'cpd01217',
#    'cpd01221',
#    'cpd01242',
#    'cpd01262',
#    'cpd01294',
#    'cpd01311',
#    'cpd01324',
#    'cpd01329',
#    'cpd01399',
#    'cpd01401',
#    'cpd01476',
#    'cpd01504',
#    'cpd01507',
#    'cpd01553',
#    'cpd01562',
#    'cpd01567',
#    'cpd01620',
#    'cpd01679',
#    'cpd01693',
#    'cpd01695',
#    'cpd01700',
#    'cpd01710',
#    'cpd01716',
#    'cpd01720',
#    'cpd01741',
#    'cpd01749',
#    'cpd01777',
#    'cpd01831',
#    'cpd01844',
#    'cpd01914',
#    'cpd01919',
#    'cpd01966',
#    'cpd01977',
#    'cpd01981',
#    'cpd01997',
#    'cpd02021',
#    'cpd02030',
#    'cpd02060',
#    'cpd02068',
#    'cpd02069',
#    'cpd02074',
#    'cpd02083',
#    'cpd02090',
#    'cpd02095',
#    'cpd02096',
#    'cpd02097',
#    'cpd02098',
#    'cpd02120',
#    'cpd02124',
#    'cpd02125',
#    'cpd02140',
#    'cpd02152',
#    'cpd02168',
#    'cpd02172',
#    'cpd02175',
#    'cpd02183',
#    'cpd02187',
#    'cpd02197',
#    'cpd02201',
#    'cpd02210',
#    'cpd02211',
#    'cpd02227',
#    'cpd02229',
#    'cpd02234',
#    'cpd02235',
#    'cpd02255',
#    'cpd02258',
#    'cpd02295',
#    'cpd02333',
#    'cpd02345',
#    'cpd02357',
#    'cpd02361',
#    'cpd02371',
#    'cpd02375',
#    'cpd02394',
#    'cpd02431',
#    'cpd02441',
#    'cpd02456',
#    'cpd02465',
#    'cpd02484',
#    'cpd02498',
#    'cpd02501',
#    'cpd02506',
#    'cpd02507',
#    'cpd02522',
#    'cpd02546',
#    'cpd02547',
#    'cpd02552',
#    'cpd02566',
#    'cpd02569',
#    'cpd02574',
#    'cpd02590',
#    'cpd02591',
#    'cpd02605',
#    'cpd02611',
#    'cpd02612',
#    'cpd02626',
#    'cpd02631',
#    'cpd02654',
#    'cpd02656',
#    'cpd02663',
#    'cpd02666',
#    'cpd02678',
#    'cpd02679',
#    'cpd02692',
#    'cpd02700',
#    'cpd02701',
#    'cpd02711',
#    'cpd02721',
#    'cpd02724',
#    'cpd02731',
#    'cpd02740',
#    'cpd02746',
#    'cpd02775',
#    'cpd02791',
#    'cpd02820',
#    'cpd02826',
#    'cpd02851',
#    'cpd02857',
#    'cpd02861',
#    'cpd02862',
#    'cpd02882',
#    'cpd02884',
#    'cpd02886',
#    'cpd02893',
#    'cpd02894',
#    'cpd02904',
#    'cpd02920',
#    'cpd02921',
#    'cpd02930',
#    'cpd02948',
#    'cpd02961',
#    'cpd02964',
#    'cpd02968',
#    'cpd02978',
#    'cpd02979',
#    'cpd02991',
#    'cpd02993',
#    'cpd03002',
#    'cpd03034',
#    'cpd03091',
#    'cpd03114',
#    'cpd03117',
#    'cpd03119',
#    'cpd03121',
#    'cpd03123',
#    'cpd03124',
#    'cpd03125',
#    'cpd03126',
#    'cpd03127',
#    'cpd03129',
#    'cpd03130',
#    'cpd03161',
#    'cpd03171',
#    'cpd03187',
#    'cpd03189',
#    'cpd03198',
#    'cpd03205',
#    'cpd03211',
#    'cpd03279',
#    'cpd03285',
#    'cpd03326',
#    'cpd03362',
#    'cpd03392',
#    'cpd03407',
#    'cpd03413',
#    'cpd03416',
#    'cpd03421',
#    'cpd03422',
#    'cpd03423',
#    'cpd03426',
#    'cpd03431',
#    'cpd03443',
#    'cpd03444',
#    'cpd03445',
#    'cpd03446',
#    'cpd03447',
#    'cpd03448',
#    'cpd03449',
#    'cpd03451',
#    'cpd03453',
#    'cpd03454',
#    'cpd03470',
#    'cpd03471',
#    'cpd03480',
#    'cpd03488',
#    'cpd03491',
#    'cpd03492',
#    'cpd03494',
#    'cpd03495',
#    'cpd03496',
#    'cpd03517',
#    'cpd03518',
#    'cpd03519',
#    'cpd03520',
#    'cpd03524',
#    'cpd03559',
#    'cpd03572',
#    'cpd03584',
#    'cpd03585',
#    'cpd03586',
#    'cpd03593',
#    'cpd03606',
#    'cpd03608',
#    'cpd03641',
#    'cpd03646',
#    'cpd03666',
#    'cpd03697',
#    'cpd03698',
#    'cpd03701',
#    'cpd03704',
#    'cpd03726',
#    'cpd03727',
#    'cpd03752',
#    'cpd03761',
#    'cpd03813',
#    'cpd03847',
#    'cpd03861',
#    'cpd03862',
#    'cpd03914',
#    'cpd03916',
#    'cpd03917',
#    'cpd03918',
#    'cpd03919',
#    'cpd03920',
#    'cpd03969',
#    'cpd04073',
#    'cpd04122',
#    'cpd04242',
#    'cpd06227',
#    'cpd07924',
#    'cpd08210',
#    'cpd08287',
#    'cpd08288',
#    'cpd08289',
#    'cpd08301',
#    'cpd08353',
#    'cpd08368',
#    'cpd08369',
#    'cpd08370',
#    'cpd08371',
#    'cpd08375',
#    'cpd08405',
#    'cpd08615',
#    'cpd09027',
#    'cpd09253',
#    'cpd09254',
#    'cpd09843',
#    'cpd09879',
#    'cpd10162',
#    'cpd10515',
#    'cpd10516',
#    'cpd11206',
#    'cpd11225',
#    'cpd11310',
#    'cpd11312',
#    'cpd11313',
#    'cpd11416',
#    'cpd11420',
#    'cpd11421',
#    'cpd11432',
#    'cpd11434',
#    'cpd11435',
#    'cpd11437',
#    'cpd11439',
#    'cpd11441',
#    'cpd11459',
#    'cpd11461',
#    'cpd11462',
#    'cpd11463',
#    'cpd11465',
#    'cpd11467',
#    'cpd11468',
#    'cpd11469',
#    'cpd11471',
#    'cpd11473',
#    'cpd11474',
#    'cpd11475',
#    'cpd11477',
#    'cpd11484',
#    'cpd11485',
#    'cpd11486',
#    'cpd11487',
#    'cpd11488',
#    'cpd11489',
#    'cpd11490',
#    'cpd11491',
#    'cpd11492',
#    'cpd11493',
#    'cpd11494',
#    'cpd11497',
#    'cpd11499',
#    'cpd11501',
#    'cpd11503',
#    'cpd11505',
#    'cpd11507',
#    'cpd11509',
#    'cpd11511',
#    'cpd11513',
#    'cpd11515',
#    'cpd11517',
#    'cpd11519',
#    'cpd11522',
#    'cpd11524',
#    'cpd11526',
#    'cpd11528',
#    'cpd11530',
#    'cpd11532',
#    'cpd11534',
#    'cpd11536',
#    'cpd11538',
#    'cpd11540',
#    'cpd11542',
#    'cpd11544',
#    'cpd11547',
#    'cpd11549',
#    'cpd11551',
#    'cpd11553',
#    'cpd11555',
#    'cpd11557',
#    'cpd11559',
#    'cpd11561',
#    'cpd11563',
#    'cpd11565',
#    'cpd11567',
#    'cpd11569',
#    'cpd11570',
#    'cpd11571',
#    'cpd11573',
#    'cpd11609',
#    'cpd11620',
#    'cpd11621',
#    'cpd11830',
#    'cpd11959',
#    'cpd12005',
#    'cpd12225',
#    'cpd12370',
#    'cpd12543',
#    'cpd12689',
#    'cpd12848',
#    'cpd14507',
#    'cpd14545',
#    'cpd14548',
#    'cpd14589',
#    'cpd14698',
#    'cpd14699',
#    'cpd14700',
#    'cpd14702',
#    'cpd14703',
#    'cpd14960',
#    'cpd14961',
#    'cpd15170',
#    'cpd15237',
#    'cpd15238',
#    'cpd15239',
#    'cpd15268',
#    'cpd15269',
#    'cpd15274',
#    'cpd15294',
#    'cpd15298',
#    'cpd15302',
#    'cpd15325',
#    'cpd15327',
#    'cpd15330',
#    'cpd15339',
#    'cpd15346',
#    'cpd15352',
#    'cpd15353',
#    'cpd15378',
#    'cpd15386',
#    'cpd15387',
#    'cpd15391',
#    'cpd15396',
#    'cpd15399',
#    'cpd15401',
#    'cpd15417',
#    'cpd15418',
#    'cpd15419',
#    'cpd15420',
#    'cpd15421',
#    'cpd15422',
#    'cpd15423',
#    'cpd15494',
#    'cpd15495',
#    'cpd15499',
#    'cpd15500',
#    'cpd15505',
#    'cpd15506',
#    'cpd15507',
#    'cpd15522',
#    'cpd15526',
#    'cpd15527',
#    'cpd15528',
#    'cpd15529',
#    'cpd15530',
#    'cpd15531',
#    'cpd15532',
#    'cpd15533',
#    'cpd15534',
#    'cpd15540',
#    'cpd15542',
#    'cpd15543',
#    'cpd15544',
#    'cpd15545',
#    'cpd15546',
#    'cpd15547',
#    'cpd15548',
#    'cpd15552',
#    'cpd15553',
#    'cpd15554',
#    'cpd15555',
#    'cpd15556',
#    'cpd15557',
#    'cpd15558',
#    'cpd15560',
#    'cpd15561',
#    'cpd15611',
#    'cpd15665',
#    'cpd15666',
#    'cpd15683',
#    'cpd15684',
#    'cpd15685',
#    'cpd15686',
#    'cpd15687',
#    'cpd15688',
#    'cpd15689',
#    'cpd15690',
#    'cpd15691',
#    'cpd15692',
#    'cpd15693',
#    'cpd15694',
#    'cpd15695',
#    'cpd15696',
#    'cpd15697',
#    'cpd15698',
#    'cpd15699',
#    'cpd15700',
#    'cpd15716',
#    'cpd15717',
#    'cpd15718',
#    'cpd15719',
#    'cpd15720',
#    'cpd15721',
#    'cpd15793',
#    'cpd15807',
#    'cpd15839',
#    'cpd15889',
#    'cpd17150',
#    'cpd17270',
#    'cpd17278',
#    'cpd17281',
#    'cpd17282',
#    'cpd17535',
#    'cpd18076',
#    'cpd19001',
#    'cpd19006',
#    'cpd19008',
#    'cpd19019',
#    'cpd19020',
#    'cpd19047',
#    'cpd19503',
#    'cpd19505',
#    'cpd19587',
#    'cpd20412',
#    'cpd20413',
#    'cpd20940',
#    'cpd21037',
#    'cpd21088',
#    'cpd21090',
#    'cpd21167',
#    'cpd21288',
#    'cpd21301',
#    'cpd21464',
#    'cpd21479',
#    'cpd21488',
#    'cpd22022',
#    'cpd22027',
#    'cpd22065',
#    'cpd22312',
#    'cpd23005',
#    'cpd23834',
#    'cpd25679',
#    'cpd25981',
#    'cpd27180',
#    'cpd27484',
#    'cpd27713',
#    'cpd27735',
#    'cpd27744',
#    'cpd27758',
#    'cpd28060',
#    'cpd28083',
#    'cpd28253',
#    'cpd28297',
#    'cpd30750',
#    'cpd31338',
#    'cpd31434',
#    'cpd32452',
#    'cpd33647',
#    'cpd33930',
#    'cpd35194',
#    'cpd37010'},
#   'BSS model2 metabolites': {'cpd00001',
#    'cpd00002',
#    'cpd00003',
#    'cpd00004',
#    'cpd00005',
#    'cpd00006',
#    'cpd00007',
#    'cpd00008',
#    'cpd00009',
#    'cpd00010',
#    'cpd00011',
#    'cpd00012',
#    'cpd00013',
#    'cpd00014',
#    'cpd00015',
#    'cpd00016',
#    'cpd00017',
#    'cpd00018',
#    'cpd00019',
#    'cpd00020',
#    'cpd00022',
#    'cpd00023',
#    'cpd00024',
#    'cpd00025',
#    'cpd00026',
#    'cpd00027',
#    'cpd00028',
#    'cpd00029',
#    'cpd00031',
#    'cpd00032',
#    'cpd00033',
#    'cpd00035',
#    'cpd00036',
#    'cpd00037',
#    'cpd00038',
#    'cpd00039',
#    'cpd00040',
#    'cpd00041',
#    'cpd00042',
#    'cpd00043',
#    'cpd00044',
#    'cpd00045',
#    'cpd00046',
#    'cpd00047',
#    'cpd00048',
#    'cpd00050',
#    'cpd00051',
#    'cpd00052',
#    'cpd00053',
#    'cpd00054',
#    'cpd00055',
#    'cpd00056',
#    'cpd00060',
#    'cpd00061',
#    'cpd00062',
#    'cpd00064',
#    'cpd00065',
#    'cpd00066',
#    'cpd00067',
#    'cpd00068',
#    'cpd00069',
#    'cpd00070',
#    'cpd00071',
#    'cpd00072',
#    'cpd00073',
#    'cpd00075',
#    'cpd00078',
#    'cpd00079',
#    'cpd00080',
#    'cpd00081',
#    'cpd00082',
#    'cpd00084',
#    'cpd00085',
#    'cpd00086',
#    'cpd00087',
#    'cpd00089',
#    'cpd00090',
#    'cpd00091',
#    'cpd00092',
#    'cpd00093',
#    'cpd00094',
#    'cpd00095',
#    'cpd00096',
#    'cpd00098',
#    'cpd00100',
#    'cpd00101',
#    'cpd00102',
#    'cpd00103',
#    'cpd00104',
#    'cpd00105',
#    'cpd00106',
#    'cpd00107',
#    'cpd00108',
#    'cpd00109',
#    'cpd00110',
#    'cpd00111',
#    'cpd00113',
#    'cpd00114',
#    'cpd00115',
#    'cpd00116',
#    'cpd00117',
#    'cpd00118',
#    'cpd00119',
#    'cpd00121',
#    'cpd00122',
#    'cpd00123',
#    'cpd00125',
#    'cpd00126',
#    'cpd00128',
#    'cpd00129',
#    'cpd00132',
#    'cpd00133',
#    'cpd00134',
#    'cpd00135',
#    'cpd00139',
#    'cpd00143',
#    'cpd00144',
#    'cpd00145',
#    'cpd00146',
#    'cpd00147',
#    'cpd00151',
#    'cpd00152',
#    'cpd00153',
#    'cpd00155',
#    'cpd00157',
#    'cpd00159',
#    'cpd00161',
#    'cpd00162',
#    'cpd00166',
#    'cpd00168',
#    'cpd00169',
#    'cpd00171',
#    'cpd00176',
#    'cpd00177',
#    'cpd00180',
#    'cpd00182',
#    'cpd00184',
#    'cpd00186',
#    'cpd00190',
#    'cpd00191',
#    'cpd00193',
#    'cpd00196',
#    'cpd00198',
#    'cpd00199',
#    'cpd00200',
#    'cpd00201',
#    'cpd00202',
#    'cpd00203',
#    'cpd00204',
#    'cpd00207',
#    'cpd00209',
#    'cpd00213',
#    'cpd00214',
#    'cpd00215',
#    'cpd00216',
#    'cpd00218',
#    'cpd00219',
#    'cpd00220',
#    'cpd00221',
#    'cpd00222',
#    'cpd00223',
#    'cpd00226',
#    'cpd00229',
#    'cpd00233',
#    'cpd00235',
#    'cpd00236',
#    'cpd00239',
#    'cpd00241',
#    'cpd00246',
#    'cpd00247',
#    'cpd00249',
#    'cpd00259',
#    'cpd00264',
#    'cpd00274',
#    'cpd00277',
#    'cpd00279',
#    'cpd00281',
#    'cpd00283',
#    'cpd00284',
#    'cpd00286',
#    'cpd00288',
#    'cpd00289',
#    'cpd00290',
#    'cpd00293',
#    'cpd00295',
#    'cpd00296',
#    'cpd00297',
#    'cpd00298',
#    'cpd00299',
#    'cpd00300',
#    'cpd00307',
#    'cpd00309',
#    'cpd00311',
#    'cpd00320',
#    'cpd00324',
#    'cpd00327',
#    'cpd00330',
#    'cpd00331',
#    'cpd00334',
#    'cpd00338',
#    'cpd00339',
#    'cpd00343',
#    'cpd00344',
#    'cpd00346',
#    'cpd00347',
#    'cpd00348',
#    'cpd00349',
#    'cpd00350',
#    'cpd00355',
#    'cpd00356',
#    'cpd00357',
#    'cpd00358',
#    'cpd00359',
#    'cpd00362',
#    'cpd00367',
#    'cpd00387',
#    'cpd00393',
#    'cpd00397',
#    'cpd00412',
#    'cpd00415',
#    'cpd00421',
#    'cpd00424',
#    'cpd00426',
#    'cpd00428',
#    'cpd00430',
#    'cpd00437',
#    'cpd00438',
#    'cpd00443',
#    'cpd00446',
#    'cpd00447',
#    'cpd00448',
#    'cpd00455',
#    'cpd00470',
#    'cpd00475',
#    'cpd00477',
#    'cpd00478',
#    'cpd00480',
#    'cpd00485',
#    'cpd00491',
#    'cpd00492',
#    'cpd00493',
#    'cpd00497',
#    'cpd00498',
#    'cpd00504',
#    'cpd00506',
#    'cpd00508',
#    'cpd00509',
#    'cpd00510',
#    'cpd00515',
#    'cpd00516',
#    'cpd00521',
#    'cpd00523',
#    'cpd00524',
#    'cpd00525',
#    'cpd00533',
#    'cpd00540',
#    'cpd00581',
#    'cpd00585',
#    'cpd00596',
#    'cpd00626',
#    'cpd00638',
#    'cpd00641',
#    'cpd00642',
#    'cpd00644',
#    'cpd00646',
#    'cpd00650',
#    'cpd00654',
#    'cpd00655',
#    'cpd00658',
#    'cpd00672',
#    'cpd00683',
#    'cpd00689',
#    'cpd00693',
#    'cpd00699',
#    'cpd00703',
#    'cpd00706',
#    'cpd00712',
#    'cpd00722',
#    'cpd00724',
#    'cpd00731',
#    'cpd00739',
#    'cpd00755',
#    'cpd00758',
#    'cpd00759',
#    'cpd00762',
#    'cpd00763',
#    'cpd00764',
#    'cpd00768',
#    'cpd00770',
#    'cpd00774',
#    'cpd00780',
#    'cpd00781',
#    'cpd00791',
#    'cpd00793',
#    'cpd00794',
#    'cpd00800',
#    'cpd00802',
#    'cpd00808',
#    'cpd00809',
#    'cpd00817',
#    'cpd00822',
#    'cpd00831',
#    'cpd00834',
# ...
#    'cpd15325',
#    'cpd15326',
#    'cpd15327',
#    'cpd15328',
#    'cpd15329',
#    'cpd15330',
#    'cpd15331',
#    'cpd15339',
#    'cpd15346',
#    'cpd15352',
#    'cpd15353',
#    'cpd15358',
#    'cpd15361',
#    'cpd15386',
#    'cpd15387',
#    'cpd15388',
#    'cpd15391',
#    'cpd15396',
#    'cpd15399',
#    'cpd15401',
#    'cpd15417',
#    'cpd15418',
#    'cpd15419',
#    'cpd15420',
#    'cpd15421',
#    'cpd15422',
#    'cpd15423',
#    'cpd15454',
#    'cpd15479',
#    'cpd15480',
#    'cpd15484',
#    'cpd15485',
#    'cpd15488',
#    'cpd15494',
#    'cpd15495',
#    'cpd15499',
#    'cpd15500',
#    'cpd15504',
#    'cpd15505',
#    'cpd15506',
#    'cpd15507',
#    'cpd15510',
#    'cpd15521',
#    'cpd15522',
#    'cpd15523',
#    'cpd15524',
#    'cpd15525',
#    'cpd15526',
#    'cpd15527',
#    'cpd15528',
#    'cpd15529',
#    'cpd15530',
#    'cpd15531',
#    'cpd15532',
#    'cpd15533',
#    'cpd15534',
#    'cpd15535',
#    'cpd15536',
#    'cpd15537',
#    'cpd15538',
#    'cpd15539',
#    'cpd15540',
#    'cpd15541',
#    'cpd15542',
#    'cpd15543',
#    'cpd15544',
#    'cpd15545',
#    'cpd15546',
#    'cpd15547',
#    'cpd15548',
#    'cpd15552',
#    'cpd15553',
#    'cpd15554',
#    'cpd15555',
#    'cpd15556',
#    'cpd15557',
#    'cpd15558',
#    'cpd15560',
#    'cpd15561',
#    'cpd15568',
#    'cpd15569',
#    'cpd15570',
#    'cpd15571',
#    'cpd15572',
#    'cpd15579',
#    'cpd15581',
#    'cpd15582',
#    'cpd15665',
#    'cpd15666',
#    'cpd15667',
#    'cpd15668',
#    'cpd15669',
#    'cpd15671',
#    'cpd15672',
#    'cpd15673',
#    'cpd15674',
#    'cpd15675',
#    'cpd15676',
#    'cpd15677',
#    'cpd15678',
#    'cpd15679',
#    'cpd15680',
#    'cpd15681',
#    'cpd15682',
#    'cpd15683',
#    'cpd15684',
#    'cpd15685',
#    'cpd15686',
#    'cpd15687',
#    'cpd15688',
#    'cpd15689',
#    'cpd15690',
#    'cpd15691',
#    'cpd15692',
#    'cpd15693',
#    'cpd15694',
#    'cpd15695',
#    'cpd15696',
#    'cpd15697',
#    'cpd15698',
#    'cpd15699',
#    'cpd15700',
#    'cpd15716',
#    'cpd15717',
#    'cpd15718',
#    'cpd15719',
#    'cpd15720',
#    'cpd15721',
#    'cpd15722',
#    'cpd15723',
#    'cpd15724',
#    'cpd15725',
#    'cpd15726',
#    'cpd15727',
#    'cpd15764',
#    'cpd15765',
#    'cpd15766',
#    'cpd15769',
#    'cpd15770',
#    'cpd15771',
#    'cpd15772',
#    'cpd15793',
#    'cpd16335',
#    'cpd17564',
#    'cpd17565',
#    'cpd17566',
#    'cpd17567',
#    'cpd17568',
#    'cpd18057',
#    'cpd18076',
#    'cpd18078',
#    'cpd19001',
#    'cpd19006',
#    'cpd19019',
#    'cpd19020',
#    'cpd19047',
#    'cpd19245',
#    'cpd19503',
#    'cpd19505',
#    'cpd21087',
#    'cpd21088',
#    'cpd21090',
#    'cpd21118',
#    'cpd21124',
#    'cpd21167',
#    'cpd21464',
#    'cpd21472',
#    'cpd21479',
#    'cpd21481',
#    'cpd21482',
#    'cpd21486',
#    'cpd21488',
#    'cpd22022',
#    'cpd22027',
#    'cpd22028',
#    'cpd22065',
#    'cpd22312',
#    'cpd26481',
#    'cpd26508',
#    'cpd26518',
#    'cpd26519',
#    'cpd26672',
#    'cpd27020',
#    'cpd27021',
#    'cpd27180',
#    'cpd27484',
#    'cpd27713',
#    'cpd27735',
#    'cpd27744',
#    'cpd27758',
#    'cpd28060',
#    'cpd28083',
#    'cpd28205',
#    'cpd28253',
#    'cpd28259',
#    'cpd32452',
#    'cpd33647',
#    'cpd35194',
#    'cpd36635'},
#   'BSS model2 metabolites': {'cpd00001',
#    'cpd00002',
#    'cpd00003',
#    'cpd00004',
#    'cpd00005',
#    'cpd00006',
#    'cpd00007',
#    'cpd00008',
#    'cpd00009',
#    'cpd00010',
#    'cpd00011',
#    'cpd00012',
#    'cpd00013',
#    'cpd00014',
#    'cpd00015',
#    'cpd00016',
#    'cpd00017',
#    'cpd00018',
#    'cpd00019',
#    'cpd00020',
#    'cpd00022',
#    'cpd00023',
#    'cpd00024',
#    'cpd00025',
#    'cpd00026',
#    'cpd00027',
#    'cpd00028',
#    'cpd00029',
#    'cpd00031',
#    'cpd00032',
#    'cpd00033',
#    'cpd00035',
#    'cpd00036',
#    'cpd00037',
#    'cpd00038',
#    'cpd00039',
#    'cpd00040',
#    'cpd00041',
#    'cpd00042',
#    'cpd00043',
#    'cpd00044',
#    'cpd00045',
#    'cpd00046',
#    'cpd00047',
#    'cpd00048',
#    'cpd00050',
#    'cpd00051',
#    'cpd00052',
#    'cpd00053',
#    'cpd00054',
#    'cpd00055',
#    'cpd00056',
#    'cpd00060',
#    'cpd00061',
#    'cpd00062',
#    'cpd00064',
#    'cpd00065',
#    'cpd00066',
#    'cpd00067',
#    'cpd00068',
#    'cpd00069',
#    'cpd00070',
#    'cpd00071',
#    'cpd00072',
#    'cpd00073',
#    'cpd00075',
#    'cpd00076',
#    'cpd00077',
#    'cpd00078',
#    'cpd00079',
#    'cpd00080',
#    'cpd00081',
#    'cpd00082',
#    'cpd00083',
#    'cpd00084',
#    'cpd00085',
#    'cpd00086',
#    'cpd00087',
#    'cpd00089',
#    'cpd00091',
#    'cpd00092',
#    'cpd00093',
#    'cpd00094',
#    'cpd00095',
#    'cpd00096',
#    'cpd00098',
#    'cpd00100',
#    'cpd00101',
#    'cpd00102',
#    'cpd00103',
#    'cpd00104',
#    'cpd00105',
#    'cpd00106',
#    'cpd00107',
#    'cpd00108',
#    'cpd00109',
#    'cpd00110',
#    'cpd00111',
#    'cpd00113',
#    'cpd00114',
#    'cpd00115',
#    'cpd00116',
#    'cpd00117',
#    'cpd00118',
#    'cpd00119',
#    'cpd00121',
#    'cpd00122',
#    'cpd00123',
#    'cpd00125',
#    'cpd00126',
#    'cpd00128',
#    'cpd00129',
#    'cpd00132',
#    'cpd00133',
#    'cpd00134',
#    'cpd00135',
#    'cpd00138',
#    'cpd00139',
#    'cpd00142',
#    'cpd00143',
#    'cpd00144',
#    'cpd00145',
#    'cpd00146',
#    'cpd00147',
#    'cpd00151',
#    'cpd00153',
#    'cpd00155',
#    'cpd00157',
#    'cpd00159',
#    'cpd00161',
#    'cpd00162',
#    'cpd00163',
#    'cpd00166',
#    'cpd00169',
#    'cpd00171',
#    'cpd00176',
#    'cpd00177',
#    'cpd00179',
#    'cpd00180',
#    'cpd00182',
#    'cpd00184',
#    'cpd00186',
#    'cpd00190',
#    'cpd00193',
#    'cpd00196',
#    'cpd00197',
#    'cpd00198',
#    'cpd00200',
#    'cpd00201',
#    'cpd00202',
#    'cpd00203',
#    'cpd00207',
#    'cpd00209',
#    'cpd00213',
#    'cpd00214',
#    'cpd00215',
#    'cpd00216',
#    'cpd00218',
#    'cpd00219',
#    'cpd00220',
#    'cpd00221',
#    'cpd00222',
#    'cpd00223',
#    'cpd00226',
#    'cpd00229',
#    'cpd00231',
#    'cpd00236',
#    'cpd00241',
#    'cpd00246',
#    'cpd00247',
#    'cpd00249',
#    'cpd00258',
#    'cpd00259',
#    'cpd00264',
#    'cpd00269',
#    'cpd00274',
#    'cpd00277',
#    'cpd00279',
#    'cpd00281',
#    'cpd00283',
#    'cpd00284',
#    'cpd00286',
#    'cpd00287',
#    'cpd00288',
#    'cpd00295',
#    'cpd00296',
#    'cpd00297',
#    'cpd00298',
#    'cpd00299',
#    'cpd00300',
#    'cpd00309',
#    'cpd00311',
#    'cpd00320',
#    'cpd00324',
#    'cpd00327',
#    'cpd00330',
#    'cpd00331',
#    'cpd00334',
#    'cpd00338',
#    'cpd00339',
#    'cpd00340',
#    'cpd00343',
#    'cpd00344',
#    'cpd00346',
#    'cpd00347',
#    'cpd00350',
#    'cpd00355',
#    'cpd00356',
#    'cpd00357',
#    'cpd00358',
#    'cpd00359',
#    'cpd00362',
#    'cpd00367',
#    'cpd00382',
#    'cpd00387',
#    'cpd00388',
#    'cpd00393',
#    'cpd00412',
#    'cpd00421',
#    'cpd00424',
#    'cpd00426',
#    'cpd00428',
#    'cpd00430',
#    'cpd00437',
#    'cpd00438',
#    'cpd00443',
#    'cpd00446',
#    'cpd00447',
#    'cpd00448',
#    'cpd00465',
#    'cpd00475',
#    'cpd00477',
#    'cpd00478',
#    'cpd00482',
#    'cpd00485',
#    'cpd00492',
#    'cpd00493',
#    'cpd00497',
#    'cpd00498',
#    'cpd00504',
#    'cpd00506',
#    'cpd00508',
#    'cpd00509',
#    'cpd00510',
#    'cpd00516',
#    'cpd00518',
#    'cpd00519',
#    'cpd00520',
#    'cpd00523',
#    'cpd00524',
#    'cpd00525',
#    'cpd00533',
#    'cpd00540',
#    'cpd00581',
#    'cpd00585',
#    'cpd00588',
#    'cpd00589',
#    'cpd00596',
#    'cpd00630',
#    'cpd00638',
#    'cpd00641',
#    'cpd00642',
#    'cpd00644',
#    'cpd00646',
#    'cpd00650',
#    'cpd00654',
#    'cpd00655',
#    'cpd00658',
#    'cpd00659',
#    'cpd00672',
#    'cpd00683',
#    'cpd00689',
#    'cpd00697',
#    'cpd00699',
#    'cpd00703',
#    'cpd00706',
#    'cpd00712',
#    'cpd00719',
#    'cpd00722',
#    'cpd00724',
#    'cpd00726',
#    'cpd00731',
#    'cpd00755',
#    'cpd00759',
#    'cpd00762',
#    'cpd00763',
#    'cpd00764',
#    'cpd00768',
#    'cpd00770',
#    'cpd00774',
#    'cpd00778',
#    'cpd00780',
#    'cpd00781',
#    'cpd00790',
#    'cpd00791',
#    'cpd00793',
#    'cpd00794',
#    'cpd00800',
#    'cpd00805',
#    'cpd00809',
#    'cpd00817',
#    'cpd00822',
#    'cpd00834',
#    'cpd00836',
#    'cpd00837',
#    'cpd00840',
#    'cpd00843',
#    'cpd00854',
#    'cpd00856',
#    'cpd00858',
#    'cpd00860',
#    'cpd00868',
#    'cpd00873',
#    'cpd00875',
#    'cpd00876',
#    'cpd00890',
#    'cpd00894',
#    'cpd00900',
#    'cpd00906',
#    'cpd00908',
#    'cpd00911',
#    'cpd00918',
#    'cpd00922',
#    'cpd00930',
#    'cpd00931',
#    'cpd00932',
#    'cpd00939',
#    'cpd00945',
#    'cpd00954',
#    'cpd00956',
#    'cpd00957',
#    'cpd00977',
#    'cpd00978',
#    'cpd00982',
#    'cpd00988',
#    'cpd00989',
#    'cpd01011',
#    'cpd01017',
#    'cpd01024',
#    'cpd01046',
#    'cpd01067',
#    'cpd01080',
#    'cpd01092',
#    'cpd01123',
#    'cpd01150',
#    'cpd01155',
#    'cpd01217',
#    'cpd01242',
#    'cpd01262',
#    'cpd01311',
#    'cpd01324',
#    'cpd01399',
#    'cpd01441',
#    'cpd01504',
#    'cpd01507',
#    'cpd01562',
#    'cpd01567',
#    'cpd01620',
#    'cpd01630',
#    'cpd01679',
#    'cpd01695',
#    'cpd01700',
#    'cpd01710',
#    'cpd01715',
#    'cpd01716',
#    'cpd01720',
#    'cpd01741',
#    'cpd01777',
#    'cpd01793',
#    'cpd01831',
#    'cpd01871',
#    'cpd01914',
#    'cpd01932',
#    'cpd01966',
#    'cpd01977',
#    'cpd01981',
#    'cpd01997',
#    'cpd02016',
#    'cpd02021',
#    'cpd02030',
#    'cpd02060',
#    'cpd02068',
#    'cpd02069',
#    'cpd02083',
#    'cpd02090',
#    'cpd02096',
#    'cpd02097',
#    'cpd02120',
#    'cpd02124',
#    'cpd02125',
#    'cpd02140',
#    'cpd02143',
#    'cpd02147',
#    'cpd02152',
#    'cpd02168',
#    'cpd02175',
#    'cpd02187',
#    'cpd02197',
#    'cpd02201',
#    'cpd02210',
#    'cpd02211',
#    'cpd02227',
#    'cpd02229',
#    'cpd02234',
#    'cpd02255',
#    'cpd02258',
#    'cpd02295',
#    'cpd02333',
#    'cpd02361',
#    'cpd02375',
#    'cpd02386',
#    'cpd02394',
#    'cpd02419',
#    'cpd02431',
#    'cpd02439',
#    'cpd02441',
#    'cpd02465',
#    'cpd02498',
#    'cpd02506',
#    'cpd02507',
#    'cpd02546',
#    'cpd02547',
#    'cpd02552',
#    'cpd02555',
#    'cpd02566',
#    'cpd02569',
#    'cpd02572',
#    'cpd02590',
#    'cpd02597',
#    'cpd02605',
#    'cpd02611',
#    'cpd02612',
#    'cpd02631',
#    'cpd02636',
#    'cpd02654',
#    'cpd02656',
#    'cpd02663',
#    'cpd02666',
#    'cpd02678',
#    'cpd02692',
#    'cpd02700',
#    'cpd02701',
#    'cpd02711',
#    'cpd02720',
#    'cpd02721',
#    'cpd02724',
#    'cpd02740',
#    'cpd02746',
#    'cpd02775',
#    'cpd02782',
#    'cpd02820',
#    'cpd02826',
#    'cpd02828',
#    'cpd02851',
#    'cpd02857',
#    'cpd02862',
#    'cpd02882',
#    'cpd02884',
#    'cpd02886',
#    'cpd02893',
#    'cpd02894',
#    'cpd02904',
#    'cpd02920',
#    'cpd02921',
#    'cpd02930',
#    'cpd02948',
#    'cpd02961',
#    'cpd02964',
#    'cpd02967',
#    'cpd02968',
#    'cpd02978',
#    'cpd02979',
#    'cpd02991',
#    'cpd02993',
#    'cpd03002',
#    'cpd03034',
#    'cpd03063',
#    'cpd03091',
#    'cpd03114',
#    'cpd03117',
#    'cpd03119',
#    'cpd03121',
#    'cpd03123',
#    'cpd03124',
#    'cpd03125',
#    'cpd03126',
#    'cpd03127',
#    'cpd03129',
#    'cpd03130',
#    'cpd03187',
#    'cpd03189',
#    'cpd03198',
#    'cpd03205',
#    'cpd03211',
#    'cpd03279',
#    'cpd03285',
#    'cpd03289',
#    'cpd03326',
#    'cpd03392',
#    'cpd03407',
#    'cpd03416',
#    'cpd03420',
#    'cpd03422',
#    'cpd03423',
#    'cpd03426',
#    'cpd03443',
#    'cpd03444',
#    'cpd03445',
#    'cpd03446',
#    'cpd03447',
#    'cpd03448',
#    'cpd03450',
#    'cpd03451',
#    'cpd03454',
#    'cpd03470',
#    'cpd03471',
#    'cpd03480',
#    'cpd03488',
#    'cpd03491',
#    'cpd03492',
#    'cpd03494',
#    'cpd03495',
#    'cpd03496',
#    'cpd03517',
#    'cpd03518',
#    'cpd03519',
#    'cpd03520',
#    'cpd03524',
#    'cpd03559',
#    'cpd03572',
#    'cpd03584',
#    'cpd03585',
#    'cpd03586',
#    'cpd03588',
#    'cpd03593',
#    'cpd03606',
#    'cpd03608',
#    'cpd03641',
#    'cpd03646',
#    'cpd03666',
#    'cpd03701',
#    'cpd03704',
#    'cpd03708',
#    'cpd03726',
#    'cpd03761',
#    'cpd03802',
#    'cpd03813',
#    'cpd03832',
#    'cpd03833',
#    'cpd03834',
#    'cpd03835',
#    'cpd03839',
#    'cpd03847',
#    'cpd03897',
#    'cpd03913',
#    'cpd03914',
#    'cpd03915',
#    'cpd03916',
#    'cpd03917',
#    'cpd03918',
#    'cpd03919',
#    'cpd03920',
#    'cpd03969',
#    'cpd04073',
#    'cpd04117',
#    'cpd04122',
#    'cpd04242',
#    'cpd04539',
#    'cpd06227',
#    'cpd07924',
#    'cpd08210',
#    'cpd08211',
#    'cpd08287',
#    'cpd08288',
#    'cpd08289',
#    'cpd08301',
#    'cpd08353',
#    'cpd08449',
#    'cpd08615',
#    'cpd09027',
#    'cpd09813',
#    'cpd09879',
#    'cpd10162',
#    'cpd10515',
#    'cpd10516',
#    'cpd11206',
#    'cpd11225',
#    'cpd11310',
#    'cpd11312',
#    'cpd11313',
#    'cpd11416',
#    'cpd11420',
#    'cpd11421',
#    'cpd11432',
#    'cpd11434',
#    'cpd11435',
#    'cpd11437',
#    'cpd11439',
#    'cpd11441',
#    'cpd11461',
#    'cpd11462',
#    'cpd11463',
#    'cpd11465',
#    'cpd11467',
#    'cpd11468',
#    'cpd11469',
#    'cpd11471',
#    'cpd11473',
#    'cpd11474',
#    'cpd11475',
#    'cpd11477',
#    'cpd11484',
#    'cpd11485',
#    'cpd11486',
#    'cpd11487',
#    'cpd11488',
#    'cpd11489',
#    'cpd11490',
#    'cpd11491',
#    'cpd11492',
#    'cpd11493',
#    'cpd11494',
#    'cpd11497',
#    'cpd11498',
#    'cpd11499',
#    'cpd11501',
#    'cpd11502',
#    'cpd11503',
#    'cpd11505',
#    'cpd11506',
#    'cpd11507',
#    'cpd11509',
#    'cpd11510',
#    'cpd11511',
#    'cpd11513',
#    'cpd11514',
#    'cpd11515',
#    'cpd11517',
#    'cpd11518',
#    'cpd11519',
#    'cpd11522',
#    'cpd11523',
#    'cpd11524',
#    'cpd11526',
#    'cpd11527',
#    'cpd11528',
#    'cpd11530',
#    'cpd11531',
#    'cpd11532',
#    'cpd11534',
#    'cpd11535',
#    'cpd11536',
#    'cpd11538',
#    'cpd11539',
#    'cpd11540',
#    'cpd11542',
#    'cpd11543',
#    'cpd11544',
#    'cpd11547',
#    'cpd11549',
#    'cpd11551',
#    'cpd11553',
#    'cpd11555',
#    'cpd11557',
#    'cpd11559',
#    'cpd11561',
#    'cpd11563',
#    'cpd11565',
#    'cpd11567',
#    'cpd11569',
#    'cpd11570',
#    'cpd11571',
#    'cpd11572',
#    'cpd11573',
#    'cpd11621',
#    'cpd11830',
#    'cpd11959',
#    'cpd12225',
#    'cpd12370',
#    'cpd12489',
#    'cpd12543',
#    'cpd12689',
#    'cpd12712',
#    'cpd12848',
#    'cpd14507',
#    'cpd14545',
#    'cpd14548',
#    'cpd14698',
#    'cpd14699',
#    'cpd14700',
#    'cpd14702',
#    'cpd14703',
#    'cpd14718',
#    'cpd14720',
#    'cpd15170',
#    'cpd15237',
#    'cpd15238',
#    'cpd15239',
#    'cpd15268',
#    'cpd15269',
#    'cpd15274',
#    'cpd15294',
#    'cpd15298',
#    'cpd15302',
#    'cpd15325',
#    'cpd15327',
#    'cpd15330',
#    'cpd15339',
#    'cpd15346',
#    'cpd15352',
#    'cpd15353',
#    'cpd15358',
#    'cpd15359',
#    'cpd15360',
#    'cpd15361',
#    'cpd15386',
#    'cpd15387',
#    'cpd15388',
#    'cpd15391',
#    'cpd15396',
#    'cpd15399',
#    'cpd15401',
#    'cpd15417',
#    'cpd15418',
#    'cpd15419',
#    'cpd15420',
#    'cpd15421',
#    'cpd15422',
#    'cpd15423',
#    'cpd15441',
#    'cpd15495',
#    'cpd15499',
#    'cpd15500',
#    'cpd15505',
#    'cpd15506',
#    'cpd15507',
#    'cpd15521',
#    'cpd15522',
#    'cpd15523',
#    'cpd15524',
#    'cpd15525',
#    'cpd15526',
#    'cpd15527',
#    'cpd15528',
#    'cpd15529',
#    'cpd15530',
#    'cpd15531',
#    'cpd15532',
#    'cpd15533',
#    'cpd15534',
#    'cpd15535',
#    'cpd15536',
#    'cpd15537',
#    'cpd15538',
#    'cpd15539',
#    'cpd15540',
#    'cpd15541',
#    'cpd15542',
#    'cpd15543',
#    'cpd15544',
#    'cpd15545',
#    'cpd15546',
#    'cpd15547',
#    'cpd15548',
#    'cpd15552',
#    'cpd15553',
#    'cpd15554',
#    'cpd15555',
#    'cpd15556',
#    'cpd15557',
#    'cpd15558',
#    'cpd15560',
#    'cpd15561',
#    'cpd15568',
#    'cpd15569',
#    'cpd15570',
#    'cpd15571',
#    'cpd15572',
#    'cpd15581',
#    'cpd15665',
#    'cpd15666',
#    'cpd15677',
#    'cpd15678',
#    'cpd15679',
#    'cpd15680',
#    'cpd15681',
#    'cpd15682',
#    'cpd15683',
#    'cpd15684',
#    'cpd15685',
#    'cpd15686',
#    'cpd15687',
#    'cpd15688',
#    'cpd15689',
#    'cpd15690',
#    'cpd15691',
#    'cpd15692',
#    'cpd15693',
#    'cpd15694',
#    'cpd15695',
#    'cpd15696',
#    'cpd15697',
#    'cpd15698',
#    'cpd15699',
#    'cpd15700',
#    'cpd15716',
#    'cpd15717',
#    'cpd15718',
#    'cpd15719',
#    'cpd15720',
#    'cpd15721',
#    'cpd15722',
#    'cpd15723',
#    'cpd15724',
#    'cpd15725',
#    'cpd15726',
#    'cpd15727',
#    'cpd15793',
#    'cpd16741',
#    'cpd17564',
#    'cpd17565',
#    'cpd17566',
#    'cpd17567',
#    'cpd17568',
#    'cpd18076',
#    'cpd18078',
#    'cpd18082',
#    'cpd19001',
#    'cpd19006',
#    'cpd19019',
#    'cpd19020',
#    'cpd19047',
#    'cpd19503',
#    'cpd19505',
#    'cpd21088',
#    'cpd21167',
#    'cpd21288',
#    'cpd21472',
#    'cpd21481',
#    'cpd21488',
#    'cpd22022',
#    'cpd22027',
#    'cpd22028',
#    'cpd22065',
#    'cpd22795',
#    'cpd25981',
#    'cpd26508',
#    'cpd26518',
#    'cpd26519',
#    'cpd26672',
#    'cpd27020',
#    'cpd27021',
#    'cpd27180',
#    'cpd27484',
#    'cpd27713',
#    'cpd27735',
#    'cpd27744',
#    'cpd27758',
#    'cpd28060',
#    'cpd28083',
#    'cpd28253',
#    'cpd32452',
#    'cpd33647',
#    'cpd33930',
#    'cpd35194'}}]
