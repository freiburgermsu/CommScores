# %%
import pathlib

import pandas as pd

# %%
kchip_data_folder = pathlib.Path("../../data/raw/kchip/media")

# %%
met_profile = pd.read_csv(kchip_data_folder / "metabolic_profiles.csv", index_col=0).T
met_profile = met_profile.rename(index={"SF1": "SF"})
met_profile = met_profile.rename(columns={"ArabinoseD": "D-Arabinose", "ArabinoseL": "L-Arabinose"})
met_profile
# Out:
# carbon  D-Arabinose   L-Arabinose       Xylose       Ribose     Rhamnose  \
# BI        -6.838340    678.126215   806.426592   741.153819   405.193727
# CF        -1.925922   1534.581070  1304.696793   782.485409   664.199323
# EA        -6.523152     10.333066    -6.244411   603.453994     7.220658
# EC        13.082301  13685.071040  2611.395172   646.001024   658.922141
# EL         4.188936    653.272700   881.078540   789.553812   401.682993
# KA         7.211399   1350.362573  1361.967525  1254.338912   642.862501
# LA         5.215996    570.599462   554.364390   661.227422   528.600289
# PAg1       0.996728    685.527709   693.971844   921.483988  1029.934207
# PAg2     126.978597    432.106168   302.427343   758.364823   548.701154
# PAg3       4.516501    344.561137   209.524911   535.830633   786.702385
# PAl       -1.375435    757.672588   786.215195   361.040263    65.770485
# PAr       14.364483   3885.977679   330.773095   347.950915    26.084261
# ...

# %%
# labels extracted from heatmap image
row_labels = [
    "PAl", "PAg2", "PAg1", "PAg3", "LA", "EL", "RP2", "RP1", "SF", "BI",
    "KA", "CF", "EC", "EA", "PK", "PR1", "PAr", "PR2", "PH", "PP"
]
# ignore the diluted media conditions
column_labels = [
    "Glycerol", "Glutamine", "Cellobiose", "Rhamnose", "Maltose", "Mannose", "GlcNAc", "Trehalose",
    "Glucose", "Mix", "Pyruvate", "Alanine", "Fructose", "Galactose", "Ribose", "Xylose", "Mannitol", "L-Arabinose", "Sorbitol",
    "Lactose", "Sucrose",  "Raffinose", "Uridine", "Arabinogalactan", "Melezitose", "Water", "D-Arabinose", "Serine", "Isoleucine", "Arginine",
    "Acetate", "Citrate", "Fumarate", "Succinate", "Proline"
]

# %%
yield_df = met_profile.loc[row_labels, column_labels].apply(lambda row: row / row.max(), axis=1)
yield_df[yield_df < 0] = 0
yield_df
# Out:
# carbon  Glycerol  Glutamine  Cellobiose  Rhamnose   Maltose   Mannose  \
# PAl     0.884545   0.472493    0.979330  0.076346  0.000000  0.667145
# PAg2    0.466630   0.882585    0.023063  0.449342  0.479974  1.000000
# PAg1    1.000000   0.641512    0.970245  0.599984  0.469800  0.746721
# PAg3    1.000000   0.894069    0.917164  0.616330  0.409089  0.870600
# LA      0.458133   1.000000    0.635450  0.599255  0.705656  0.784547
# EL      0.664277   0.576646    0.524017  0.407766  0.687654  0.732975
# RP2     0.933715   0.075233    1.000000  0.788395  0.737741  0.778035
# RP1     0.828278   0.156260    0.857966  0.860824  0.749897  0.874341
# SF      0.550297   0.031386    0.000000  0.195987  0.842179  0.908989
# BI      0.272181   0.103689    0.853237  0.490058  0.834330  0.969720
# KA      0.249690   0.572140    0.972945  0.472010  0.759549  0.889546
# CF      0.129013   0.996079    0.560940  0.432821  0.655766  0.766180
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10, 5))
plot_data = yield_df.copy()
plot_data[plot_data < 0.2] = 0
sns.heatmap(yield_df, cmap="Blues", cbar_kws={"label": "Yield (normalized)"})
# Out:
# <Axes: xlabel='carbon'>

# %%
growth_df = yield_df.copy()
growth_df[growth_df < 0.2] = 0
growth_df[growth_df > 0] = 1
growth_df = growth_df.astype(int)
growth_df
# Out:
# carbon  Glycerol  Glutamine  Cellobiose  Rhamnose  Maltose  Mannose  GlcNAc  \
# PAl            1          1           1         0        0        1       0
# PAg2           1          1           0         1        1        1       1
# PAg1           1          1           1         1        1        1       1
# PAg3           1          1           1         1        1        1       1
# LA             1          1           1         1        1        1       1
# EL             1          1           1         1        1        1       1
# RP2            1          0           1         1        1        1       1
# RP1            1          0           1         1        1        1       1
# SF             1          0           0         0        1        1       1
# BI             1          0           1         1        1        1       1
# KA             1          1           1         1        1        1       1
# ...

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(growth_df, cmap="Blues", cbar=False)
# Out:
# <Axes: xlabel='carbon'>

# %%
result_dict = {row_label: growth_df.columns[row == 1].tolist() for row_label, row in growth_df.iterrows()}
result_dict
# Out:
# {'PAl': ['Glycerol',
#   'Glutamine',
#   'Cellobiose',
#   'Mannose',
#   'Trehalose',
#   'Glucose',
#   'Mix',
#   'Pyruvate',
#   'Alanine',
#   'Fructose',
#   'Ribose',
#   'Xylose',
#   'Mannitol',
#   'L-Arabinose',
#   'Sorbitol',
#   'Lactose',
#   'Sucrose',
#   'Citrate',
#   'Fumarate',
#   'Succinate',
#   'Proline'],
#  'PAg2': ['Glycerol',
#   'Glutamine',
#   'Rhamnose',
#   'Maltose',
#   'Mannose',
#   'GlcNAc',
#   'Trehalose',
#   'Glucose',
#   'Mix',
#   'Pyruvate',
#   'Alanine',
#   'Fructose',
#   'Ribose',
#   'Xylose',
#   'Mannitol',
#   'L-Arabinose',
#   'Sucrose',
#   'Fumarate',
#   'Succinate',
#   'Proline'],
#  'PAg1': ['Glycerol',
#   'Glutamine',
#   'Cellobiose',
#   'Rhamnose',
#   'Maltose',
#   'Mannose',
#   'GlcNAc',
#   'Trehalose',
#   'Glucose',
#   'Mix',
#   'Pyruvate',
#   'Alanine',
#   'Fructose',
#   'Galactose',
#   'Ribose',
#   'Xylose',
#   'Mannitol',
#   'L-Arabinose',
#   'Sucrose',
#   'Citrate',
#   'Fumarate',
# ...

# %% [markdown]
# ## Comparing metabolic models with experimental data

# %%
import cobra
from cobra.io import read_sbml_model

# %%
model_folder = pathlib.Path("../../data/processed/kchip/models")

# %%
media_names = growth_df.columns.tolist()
microbe_names = growth_df.index.tolist()

# %%
model_dict = {label: read_sbml_model(model_folder / f"{label}.genome.mdl.sbml") for label in microbe_names}
model_dict
# Out:
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# '' is not a valid SBML 'SId'.
# {'PAl': <Model  at 0x7f1587b6d890>,
#  'PAg2': <Model  at 0x7f1587263750>,
#  'PAg1': <Model  at 0x7f15861a3a50>,
#  'PAg3': <Model  at 0x7f15850b70d0>,
#  'LA': <Model  at 0x7f1583f7bbd0>,
#  'EL': <Model  at 0x7f1582e607d0>,
#  'RP2': <Model  at 0x7f1581dff0d0>,
#  'RP1': <Model  at 0x7f15809cf0d0>,
#  'SF': <Model  at 0x7f157f5a5e10>,
# ...

# %%
media_folder = pathlib.Path("../../data/processed/kchip/media")

# %%
media_dict = {label: list(pd.read_excel(media_folder / f"M9_{label}.xls")["compounds"]) for label in media_names}
media_dict
# Out:
# {'Glycerol': ['cpd00013',
#   'cpd00009',
#   'cpd00048',
#   'cpd00063',
#   'cpd00011',
#   'cpd10516',
#   'cpd00067',
#   'cpd00001',
#   'cpd00205',
#   'cpd00254',
#   'cpd00971',
#   'cpd00007',
#   'cpd00099',
#   'cpd00058',
#   'cpd00149',
#   'cpd00030',
#   'cpd00034',
#   'cpd10515',
#   'cpd00100'],
#  'Glutamine': ['cpd00013',
#   'cpd00009',
#   'cpd00048',
#   'cpd00063',
#   'cpd00011',
#   'cpd10516',
#   'cpd00067',
#   'cpd00001',
#   'cpd00205',
#   'cpd00254',
#   'cpd00971',
#   'cpd00007',
#   'cpd00099',
#   'cpd00058',
#   'cpd00149',
#   'cpd00030',
#   'cpd00034',
#   'cpd10515',
#   'cpd00053'],
#  'Cellobiose': ['cpd00013',
#   'cpd00009',
#   'cpd00048',
#   'cpd00063',
#   'cpd00011',
#   'cpd10516',
#   'cpd00067',
#   'cpd00001',
#   'cpd00205',
#   'cpd00254',
#   'cpd00971',
#   'cpd00007',
#   'cpd00099',
#   'cpd00058',
#   'cpd00149',
#   'cpd00030',
#   'cpd00034',
#   'cpd10515',
#   'cpd00158'],
#  'Rhamnose': ['cpd00013',
#   'cpd00009',
# ...

# %% [markdown]
# ### PAl in Glycerol test

# %%
model = model_dict["PAl"].copy()
media = [f"EX_{m}_e0" for m in media_dict["Glycerol"]]

# %%
old_medium = model.medium
for m in old_medium:
    if m in media:
        old_medium[m] = 1000
    else:
        old_medium[m] = 0
model.medium = old_medium
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# /home/dileep/Documents/Work/KBaseCollaborations/CommScores/.venv/lib/python3.11/site-packages/cobra/medium/boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# ...

# %%
model.slim_optimize()
# Out:
# 27.151508857251294

# %% [markdown]
# ### PP in Maltose

# %%
model = model_dict["PP"].copy()
media = [f"EX_{m}_e0" for m in media_dict["Maltose"]]

# %%
old_medium = model.medium
for m in old_medium:
    if m in media:
        old_medium[m] = 1000
    else:
        old_medium[m] = 0
model.medium = old_medium
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# /home/dileep/Documents/Work/KBaseCollaborations/CommScores/.venv/lib/python3.11/site-packages/cobra/medium/boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# ...

# %%
model.slim_optimize()
# Out:
# 33.58233770712856

# %% [markdown]
# Model should not grow in this condition, yet it does. This is a bug in the model.

# %% [markdown]
# ## Growth simulations of all models in all media conditions

# %%
carbon_sources = dict(sorted({k: v[18:] for k, v in media_dict.items()}.items()))
carbon_sources
# Out:
# {'Acetate': ['cpd00029'],
#  'Alanine': ['cpd00035'],
#  'Arabinogalactan': ['cpd11699'],
#  'Arginine': ['cpd00051'],
#  'Cellobiose': ['cpd00158'],
#  'Citrate': ['cpd00137'],
#  'D-Arabinose': ['cpd00185'],
#  'Fructose': ['cpd00082'],
#  'Fumarate': ['cpd00106'],
#  'Galactose': ['cpd00108'],
#  'GlcNAc': ['cpd00122'],
#  'Glucose': ['cpd00027'],
#  'Glutamine': ['cpd00053'],
#  'Glycerol': ['cpd00100'],
#  'Isoleucine': ['cpd00322'],
#  'L-Arabinose': ['cpd00224'],
#  'Lactose': ['cpd00208'],
#  'Maltose': ['cpd00179'],
#  'Mannitol': ['cpd00314'],
#  'Mannose': ['cpd00138'],
#  'Melezitose': ['cpd05161'],
#  'Mix': ['cpd00185',
#   'cpd00224',
#   'cpd26831',
#   'cpd00105',
#   'cpd30727',
#   'cpd00082',
#   'cpd26818',
#   'cpd00027',
#   'cpd00138',
#   'cpd00122',
#   'cpd26496',
#   'cpd26499',
#   'cpd30725',
#   'cpd00036',
#   'cpd19135',
#   'cpd00100',
#   'cpd00314',
#   'cpd00588',
#   'cpd00035',
#   'cpd00054',
#   'cpd00129',
#   'cpd00053',
#   'cpd00322',
# ...

# %%
predicted_growth_data = []
for model_name, model in model_dict.items():
    for media_name, media_list_names in media_dict.items():
        curr_model = model.copy()
        # update the medium
        curr_media = curr_model.medium
        media_list = [f"EX_{m}_e0" for m in media_list_names]
        for m in curr_media:
            if m in media_list:
                if m in carbon_sources[media_name]:
                    curr_media[m] = 10
                else:
                    curr_media[m] = 1000
            else:
                curr_media[m] = 0
        curr_model.medium = curr_media
        # simulate growth
        growth = curr_model.slim_optimize()
        data_item = {
            "model": model_name,
            "media": media_name,
            "growth": growth
        }
        predicted_growth_data.append(data_item)
# Out:
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# /home/dileep/Documents/Work/KBaseCollaborations/CommScores/.venv/lib/python3.11/site-packages/cobra/medium/boundary_types.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return most[0]
# Could not identify an external compartment by name and choosing one with the most boundary reactions. That might be complete nonsense or change suddenly. Consider renaming your compartments using `Model.compartments` to fix this.
# ...

# %%
predicted_growth = pd.DataFrame(predicted_growth_data).pivot_table(index="model", columns="media", values="growth")
predicted_growth
# Out:
# media    Acetate    Alanine  Arabinogalactan   Arginine  Cellobiose  \
# model
# BI     11.063139  22.126278         0.410242  18.193817   51.636832
# CF     11.166862  22.333724         0.410242  14.765084   52.121626
# EA     11.028280  22.056561         0.000000  14.287793   51.813117
# EC     10.976118  21.952236         0.000000  17.458098   59.392295
# EL     11.001818  22.003637         0.716811  18.084831   59.540877
# KA     11.063139  22.126278         0.410242  14.622908   51.636832
# LA     10.982460  21.964921         0.249045  18.053107   51.209240
# PAg1   14.869725   6.346003         0.825575  15.829319   38.991208
# PAg2   14.994913   6.377161         0.224911  15.992495   39.580470
# PAg3   14.817896   5.239651         0.000000  15.330023   38.861891
# PAl    14.801275   6.335583         0.824548  15.799878   38.782189
# PAr     7.705127   5.078241         0.000000  16.845205    0.000000
# PH      7.643048   0.000000         0.000000  16.641576    0.000000
# ...

# %%
predicted_yield_df = predicted_growth.loc[row_labels, column_labels].apply(lambda row: row / row.max(), axis=1)
predicted_yield_df[predicted_yield_df < 0.1] = 0
predicted_yield_df
# Out:
# media  Glycerol  Glutamine  Cellobiose  Rhamnose   Maltose   Mannose  \
# model
# PAl    0.494123   0.447176    0.705787  0.000000  0.705787  0.705787
# PAg2   0.488950   0.443003    0.704877  0.550295  0.704877  0.704877
# PAg1   0.494690   0.448144    0.707870  0.554484  0.707870  0.707870
# PAg3   0.494913   0.448129    0.707870  0.554511  0.707870  0.707870
# LA     0.380288   0.318241    0.734492  0.448840  0.734492  0.612942
# EL     0.357129   0.299285    0.801722  0.489537  0.801722  0.602548
# RP2    0.380710   0.320674    0.740005  0.452872  0.740005  0.617767
# RP1    0.380717   0.320674    0.740005  0.452872  0.740005  0.617767
# SF     0.381587   0.320621    0.869366  0.521258  0.869366  0.639195
# BI     0.382937   0.321007    0.741556  0.427134  0.741556  0.554229
# KA     0.384224   0.322085    0.744048  0.428569  0.744048  0.556092
# CF     0.382467   0.323489    0.747228  0.430700  0.747228  0.564727
# ...

# %%
predicted_growth.loc["PP", "Glucose"]
# Out:
# 30.346436770280174

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(predicted_yield_df, cmap="Blues", cbar_kws={"label": "Growth rate (normalized)"})
# Out:
# <Axes: xlabel='media', ylabel='model'>

# %% [markdown]
# ## Save experimental metabolic profile and predicted growth rate

# %%
exp_yield = met_profile.reset_index().melt(id_vars="index", var_name="carbon", value_name="exp_yield")
pred_growth = predicted_growth.reset_index().melt(id_vars="model", var_name="carbon", value_name="pred_growth")
pred_growth.rename(columns={"model": "index"}, inplace=True)
yield_growth_df = exp_yield.merge(pred_growth, left_on=["index", "carbon"], right_on=["index", "carbon"], how="inner")
yield_growth_df
# Out:
#     index       carbon  exp_yield  pred_growth
# 0      BI  D-Arabinose  -6.838340     0.410242
# 1      CF  D-Arabinose  -1.925922     0.410242
# 2      EA  D-Arabinose  -6.523152     0.000000
# 3      EC  D-Arabinose  13.082301     0.000000
# 4      EL  D-Arabinose   4.188936     0.716811
# ..    ...          ...        ...          ...
# 695   PR1        Water   0.000000     0.000000
# 696   PR2        Water   0.000000     0.000000
# 697   RP1        Water   0.000000     0.410067
# 698   RP2        Water   0.000000     0.249062
# 699    SF        Water   0.000000     0.381405
#
# [700 rows x 4 columns]

# %%
# yield_growth_df.to_csv("../../data/processed/kchip/monoculture_yield_growth.csv", index=False)

# %% [markdown]
# ## Confusion matrix for predicted growth for each model in all media conditions

# %%
predicted_growth_df = predicted_yield_df.copy()
predicted_growth_df[predicted_growth_df < 0.1] = 0
predicted_growth_df[predicted_growth_df > 0] = 1
predicted_growth_df = predicted_growth_df.astype(int)
predicted_growth_df
# Out:
# media  Glycerol  Glutamine  Cellobiose  Rhamnose  Maltose  Mannose  GlcNAc  \
# model
# PAl           1          1           1         0        1        1       1
# PAg2          1          1           1         1        1        1       1
# PAg1          1          1           1         1        1        1       1
# PAg3          1          1           1         1        1        1       1
# LA            1          1           1         1        1        1       1
# EL            1          1           1         1        1        1       1
# RP2           1          1           1         1        1        1       1
# RP1           1          1           1         1        1        1       1
# SF            1          1           1         1        1        1       1
# BI            1          1           1         1        1        1       1
# KA            1          1           1         1        1        1       1
# ...

# %%
# calculate tp, fp, tn, fn for every row for all columns between predicted_growth_df and growth_df
tp = ((predicted_growth_df > 0) & (growth_df > 0)).sum(axis=1)
fp = ((predicted_growth_df > 0) & (growth_df == 0)).sum(axis=1)
tn = ((predicted_growth_df == 0) & (growth_df == 0)).sum(axis=1)
fn = ((predicted_growth_df == 0) & (growth_df > 0)).sum(axis=1)

# %%
confusion_df = pd.DataFrame({"TP": tp, "FP": fp, "TN": tn, "FN": fn})
confusion_df
# Out:
#        TP  FP  TN  FN
# model
# PAl    20   6   8   1
# PAg2   19   6   9   1
# PAg1   22   3   9   1
# PAg3   20   4  10   1
# LA     18   8   6   3
# EL     23   4   5   3
# RP2    20   7   5   3
# RP1    20   7   5   3
# SF     16  10   7   2
# BI     17   9   7   2
# KA     20   6   7   2
# CF     18   8   7   2
# EC     13  14   8   0
# EA     17   6  12   0
# PK     15   4  12   4
# PR1    21   2  11   1
# PAr    20   3  11   1
# PR2    17   4  13   1
# PH     18   3  13   1
# PP     14   4  17   0

# %%
plot_data = confusion_df.reset_index().melt(id_vars="model", value_vars=["TP", "FP", "TN", "FN"], var_name="Type", value_name="Count")
g = sns.catplot(data=plot_data, x="model", y="Count", col="Type", kind="bar", aspect=2, col_wrap=2)
# change ylimit for each axis
for ax in g.axes:
    ax.set_ylim(0, predicted_growth_df.shape[1])

# %% [markdown]
# ## Correlation between yield and model growth rate predictions

# %%
# spearman correlation
from scipy.stats import spearmanr

# %%
predicted_yield_df
# Out:
# media  Glycerol  Glutamine  Cellobiose  Rhamnose   Maltose   Mannose  \
# model
# PAl    0.494123   0.447176    0.705787  0.000000  0.705787  0.705787
# PAg2   0.488950   0.443003    0.704877  0.550295  0.704877  0.704877
# PAg1   0.494690   0.448144    0.707870  0.554484  0.707870  0.707870
# PAg3   0.494913   0.448129    0.707870  0.554511  0.707870  0.707870
# LA     0.380288   0.318241    0.734492  0.448840  0.734492  0.612942
# EL     0.357129   0.299285    0.801722  0.489537  0.801722  0.602548
# RP2    0.380710   0.320674    0.740005  0.452872  0.740005  0.617767
# RP1    0.380717   0.320674    0.740005  0.452872  0.740005  0.617767
# SF     0.381587   0.320621    0.869366  0.521258  0.869366  0.639195
# BI     0.382937   0.321007    0.741556  0.427134  0.741556  0.554229
# KA     0.384224   0.322085    0.744048  0.428569  0.744048  0.556092
# CF     0.382467   0.323489    0.747228  0.430700  0.747228  0.564727
# ...

# %%
# calculate the spearman correlation between the yield_df and predicted_yield_df
spearman_corr = yield_df.apply(lambda row: row.corr(predicted_yield_df.loc[row.name], method="spearman"), axis=1).sort_values()
pearson_corr = yield_df.apply(lambda row: row.corr(predicted_yield_df.loc[row.name], method="pearson"), axis=1).sort_values()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=spearman_corr.index, y=spearman_corr)
plt.xticks(rotation=90);
plt.xlabel("Model")
plt.ylabel("Spearman correlation")
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=pearson_corr.index, y=pearson_corr)
plt.xticks(rotation=90);
plt.xlabel("Model")
plt.ylabel("Pearson correlation")
plt.ylim(0, 1)
# Out:
# (0.0, 1.0)

# %% [markdown]
# ## Misc. visualizations

# %%
import numpy as np

# %%
inds = growth_df.index
cols = growth_df.columns
exp_pred_diff = growth_df - predicted_growth_df.loc[inds, cols]
exp_pred_diff_abs = np.abs(growth_df - predicted_growth_df.loc[inds, cols])

# %%
row_correct = exp_pred_diff_abs.shape[1] - exp_pred_diff_abs.sum(axis=1)
row_labels = [f"{i}({v})" for i, v in row_correct.items()]
col_correct = exp_pred_diff_abs.shape[0] - exp_pred_diff_abs.sum(axis=0)
col_labels = [f"{i}({v})" for i, v in col_correct.items()]

# %%
sns.heatmap(exp_pred_diff, cmap="coolwarm", cbar_kws={"label": "Difference"}, xticklabels=col_labels, yticklabels=row_labels, linewidths=0.5)
# Out:
# <Axes: xlabel='carbon'>

# %%
sns.clustermap(exp_pred_diff, cmap="coolwarm", cbar_kws={"label": "Difference"}, xticklabels=col_labels, yticklabels=row_labels, linewidths=0.5)

# %%
confusion_df["accuracy"] = (confusion_df["TP"] + confusion_df["TN"]) / (confusion_df["TP"] + confusion_df["TN"] + confusion_df["FP"] + confusion_df["FN"])

# %%
confusion_df.reset_index()
# Out:
#    model  TP  FP  TN  FN  accuracy
# 0    PAl  20   6   8   1  0.800000
# 1   PAg2  19   6   9   1  0.800000
# 2   PAg1  22   3   9   1  0.885714
# 3   PAg3  20   4  10   1  0.857143
# 4     LA  18   8   6   3  0.685714
# 5     EL  23   4   5   3  0.800000
# 6    RP2  20   7   5   3  0.714286
# 7    RP1  20   7   5   3  0.714286
# 8     SF  16  10   7   2  0.657143
# 9     BI  17   9   7   2  0.685714
# 10    KA  20   6   7   2  0.771429
# 11    CF  18   8   7   2  0.714286
# 12    EC  13  14   8   0  0.600000
# 13    EA  17   6  12   0  0.828571
# 14    PK  15   4  12   4  0.771429
# 15   PR1  21   2  11   1  0.914286
# 16   PAr  20   3  11   1  0.885714
# 17   PR2  17   4  13   1  0.857143
# 18    PH  18   3  13   1  0.885714
# 19    PP  14   4  17   0  0.885714

# %%
fig, ax = plt.subplots()
fig.set_size_inches(10, 5)
plot_data = confusion_df.reset_index()
sns.barplot(x='model', y='TN', data=plot_data, color='b', ax=ax, label='TN')

# Plot the 'TP' bars on top of the 'TN' bars
sns.barplot(x='model', y='TP', data=plot_data, color='g', ax=ax, label='TP', bottom=plot_data['TN'])

# Add annotations for accuracy
for index, row in plot_data.iterrows():
    ax.annotate(f"{row['accuracy']:.2f}",
                xy=(index, row['TN'] + row['TP'] + 1),  # Position above the stacked bar
                ha='center', va='bottom')
plt.ylim(0, 35)
plt.ylabel("TN/TP")
plt.tight_layout()
